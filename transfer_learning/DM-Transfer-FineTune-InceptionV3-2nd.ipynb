# %% [markdown]
# # Clasificación de mamografías usando Transfer learning y Fine Tune con InceptionV3

# %% [markdown]
# ## Importación de librerías

# %%
import sys
import numpy as np
import tensorflow as tf
#import matplotlib.pyplot as plt
# Generacion del grafico de metricas de Perdidas y Accuracy
import pandas as pd
import matplotlib.pyplot as plt
#ML
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import GlobalAveragePooling2D
from keras.layers import Dropout, Dense
from keras.applications import *
from keras.optimizers import SGD
from keras.callbacks import ModelCheckpoint
from keras import backend as k
from keras.models import Model
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Parámetros iniciales

# %%
# fix seed for reproducible results (only works on CPU, not GPU)
#seed = 9
#np.random.seed(seed=seed)
#tf.set_random_seed(seed=seed)

# parameters dependent on your dataset: modified to your example
nb_train_samples = 690  # Total number of train samples. NOT including augmented images
nb_validation_samples = 346  # Total number of train samples. NOT including augmented images.
img_width, img_height = 299, 299  # change based on the shape/structure of your images

# hyper parameters for model
based_model_last_block_layer_number = 172  # value is based on based model selected.
batch_size = 64#8  # try 4, 8, 16, 32, 64, 128, 256 dependent on CPU/GPU memory capacity (powers of 2 values).
nb_epoch = 100#100  # number of iteration the algorithm gets trained.
learn_rate = 1e-4  # sgd learning rate
momentum = .9  # sgd momentum to avoid local minimum

#Dataset
data_dir = './data/DDSM Images'
#data_dir = './data/DM images'
train_dir = data_dir + '/train'  # change to your train path. Inside, each class should have it's own folder
validation_dir = data_dir + '/validation'  # validation path. Inside, each class should have it's own folder

# %% [markdown]
# ## Transfer Learning y Fine Tune

# %%
def train(train_data_dir, validation_data_dir):
    # Pre-Trained CNN Model using imagenet dataset for pre-trained weights
    base_model = InceptionV3(weights='imagenet', include_top=False)  # select from keras pre-built models library

    # Top Model Block
    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x = Dense(256, activation='relu')(x)
    x = Dropout(0.5)(x)
    predictions = Dense(1, activation='sigmoid')(x)  # softmax if multi-class classifiers
    #predictions = Dense(nb_classes, activation='softmax')(x) #new softmax layer

    # add your top layer block to your base model
    model = Model(base_model.input, predictions)

    # first: train only the top layers (which were randomly initialized)
    # i.e. freeze all convolution layers
    for layer in base_model.layers:
        layer.trainable = False

    # Read Data and Augment it: Make sure to select augmentations that are appropriate to your images.
    # To save augmentations un-comment save lines and add to your flow parameters.
    train_datagen = ImageDataGenerator(rescale=1. / 255,
                                       #rotation_range=10,
                                       shear_range=.1,
                                       zoom_range=.1,
                                       cval=.1,
                                       horizontal_flip=True)
                                       #vertical_flip=True)

    validation_datagen = ImageDataGenerator(rescale=1. / 255)

    train_generator = train_datagen.flow_from_directory(train_data_dir,
                                                        target_size=(img_height, img_width),
                                                        batch_size=batch_size,
                                                        class_mode='binary')
                                                        #save_to_dir=data_dir + '/preview',
                                                        #save_prefix='aug')#,
                                                        #save_format='jpeg')
    # use the above 3 commented lines if you want to save and look at how the data augmentations look like
    
    fig = plt.figure()
    fig.suptitle("Datos aumentados para entrenamiento", fontsize=14)
    x,y = train_generator.next()
    for i in range(0,4):
        image = x[i]
        #plt.imshow(image.transpose(2,1,0))
        #Plotea data aumentada
        ax1 = fig.add_subplot(2,2,i+1)
        ax1.imshow(image)
        #ax1.set_title("Clase %s"%y)
        #plt.show()
        #plt.imshow(image)
    
    plt.show()

    validation_generator = validation_datagen.flow_from_directory(validation_data_dir,
                                                            target_size=(img_height, img_width),
                                                            batch_size=batch_size,
                                                            class_mode='binary')
    fig = plt.figure()
    fig.suptitle("Datos para validación", fontsize=14)
    x,y = validation_generator.next()
    for i in range(0,4):
        image = x[i]
        #plt.imshow(image.transpose(2,1,0))
        #Plotea data aumentada
        ax1 = fig.add_subplot(2,2,i+1)
        ax1.imshow(image)
        #ax1.set_title("Clase %s"%y)
        #plt.show()
        #plt.imshow(image)
    
    plt.show()
    
    model.compile(optimizer='rmsprop',
                  loss='binary_crossentropy',  # categorical_crossentropy if multi-class classifier
                  metrics=['accuracy'])
    #  model.compile(optimizer=SGD(lr=0.0001, momentum=0.9), loss='categorical_crossentropy', metrics=['accuracy'])

    # save weights of best training epoch: monitor either val_loss or val_acc
    top_weights_path = 'model/top_model_weights.h5'
    checkpoint = ModelCheckpoint(top_weights_path, monitor='val_acc', verbose=1, save_best_only=True, mode='auto')
    callbacks_list = [checkpoint]

    # Train Simple CNN
    history_tl = model.fit_generator(train_generator,
                        samples_per_epoch=nb_train_samples,
                        nb_epoch=nb_epoch / 5,
                        validation_data=validation_generator,
                        nb_val_samples=nb_validation_samples,
                        callbacks=callbacks_list)

    # add the best weights from the train top model
    # at this point we have the pre-train weights of the base model and the trained weight of the new/added top model
    # we re-load model weights to ensure the best epoch is selected and not the last one.
    model.load_weights(top_weights_path)

    # verbose
    print("\nStarting to Fine Tune Model\n")

    # based_model_last_block_layer_number points to the layer in your model you want to train.
    # For example if you want to train the last block of a 19 layer VGG16 model this should be 15
    # If you want to train the last TWO blocks of an Inception model it should be 172
    # layers before this number will used the pre-trained weights, layers above and including this number
    # will be re-trained based on the new data.
    for layer in model.layers[:based_model_last_block_layer_number]:
        layer.trainable = False
    for layer in model.layers[based_model_last_block_layer_number:]:
        layer.trainable = True

    # compile the model with a SGD/momentum optimizer
    # and a very slow learning rate.
    model.compile(loss='binary_crossentropy',
                  optimizer=SGD(lr=learn_rate, momentum=momentum),
                  metrics=['accuracy'])

    # save weights of best training epoch: monitor either val_loss or val_acc
    final_weights_path = 'model/model_weights.h5'
    checkpoint = ModelCheckpoint(final_weights_path, monitor='val_loss', verbose=1, save_best_only=True, mode='mode')
    callbacks_list = [checkpoint]

    # fine-tune the model
    history_ft = model.fit_generator(train_generator,
                        samples_per_epoch=nb_train_samples,
                        nb_epoch=nb_epoch,
                        validation_data=validation_generator,
                        nb_val_samples=nb_validation_samples,
                        callbacks=callbacks_list)
    
    # save model
    model_json = model.to_json()
    with open('model/model.json', 'w') as json_file:
        json_file.write(model_json)
        
    return history_tl, history_ft, model.layers


hist_tl, hist_ft, model_layers = train(train_dir, validation_dir)  # train model
# Out:
# Found 690 images belonging to 2 classes.
# Found 346 images belonging to 2 classes.
# /home/grupoavatar/.local/lib/python3.5/site-packages/ipykernel_launcher.py:63: UserWarning: The semantics of the Keras 2 argument `steps_per_epoch` is not the same as the Keras 1 argument `samples_per_epoch`. `steps_per_epoch` is the number of batches to draw from the generator at each epoch. Basically steps_per_epoch = samples_per_epoch/batch_size. Similarly `nb_val_samples`->`validation_steps` and `val_samples`->`steps` arguments have changed. Update your method calls accordingly.
# /home/grupoavatar/.local/lib/python3.5/site-packages/ipykernel_launcher.py:63: UserWarning: Update your `fit_generator` call to the Keras 2 API: `fit_generator(<keras.pre..., epochs=20.0, validation_steps=346, steps_per_epoch=10, validation_data=<keras.pre..., callbacks=[<keras.ca...)`
# Epoch 1/20
#  9/10 [==========================>...] - ETA: 0s - loss: 0.8843 - acc: 0.8634Epoch 00001: val_acc improved from -inf to 0.85584, saving model to model/top_model_weights.h5
# 10/10 [==============================] - 142s 14s/step - loss: 0.8442 - acc: 0.8630 - val_loss: 0.3593 - val_acc: 0.8558
# Epoch 2/20
#  9/10 [==========================>...] - ETA: 0s - loss: 0.3338 - acc: 0.8599Epoch 00002: val_acc did not improve
# 10/10 [==============================] - 132s 13s/step - loss: 0.3332 - acc: 0.8567 - val_loss: 0.3129 - val_acc: 0.8552
# Epoch 3/20
#  9/10 [==========================>...] - ETA: 0s - loss: 0.3136 - acc: 0.8793Epoch 00003: val_acc did not improve
# 10/10 [==============================] - 132s 13s/step - loss: 0.3322 - acc: 0.8665 - val_loss: 0.6027 - val_acc: 0.8553
# Epoch 4/20
#  9/10 [==========================>...] - ETA: 0s - loss: 0.3175 - acc: 0.8681Epoch 00004: val_acc did not improve
# 10/10 [==============================] - 132s 13s/step - loss: 0.3075 - acc: 0.8732 - val_loss: 0.4471 - val_acc: 0.8557
# Epoch 5/20
#  9/10 [==========================>...] - ETA: 0s - loss: 0.2538 - acc: 0.8785Epoch 00005: val_acc did not improve
# 10/10 [==============================] - 132s 13s/step - loss: 0.2432 - acc: 0.8825 - val_loss: 0.4310 - val_acc: 0.8555
# Epoch 6/20
#  9/10 [==========================>...] - ETA: 0s - loss: 0.3056 - acc: 0.8701Epoch 00006: val_acc did not improve
# 10/10 [==============================] - 132s 13s/step - loss: 0.3010 - acc: 0.8755 - val_loss: 0.3768 - val_acc: 0.8555
# Epoch 7/20
#  9/10 [==========================>...] - ETA: 0s - loss: 0.2040 - acc: 0.9045Epoch 00007: val_acc improved from 0.85584 to 0.85594, saving model to model/top_model_weights.h5
# 10/10 [==============================] - 133s 13s/step - loss: 0.1967 - acc: 0.9109 - val_loss: 0.5610 - val_acc: 0.8559
# Epoch 8/20
#  9/10 [==========================>...] - ETA: 0s - loss: 0.2564 - acc: 0.8689Epoch 00008: val_acc did not improve
# 10/10 [==============================] - 132s 13s/step - loss: 0.2427 - acc: 0.8759 - val_loss: 0.3687 - val_acc: 0.8558
# Epoch 9/20
#  9/10 [==========================>...] - ETA: 0s - loss: 0.2285 - acc: 0.8910Epoch 00009: val_acc improved from 0.85594 to 0.86695, saving model to model/top_model_weights.h5
# 10/10 [==============================] - 132s 13s/step - loss: 0.2206 - acc: 0.8927 - val_loss: 0.2597 - val_acc: 0.8670
# Epoch 10/20
#  9/10 [==========================>...] - ETA: 0s - loss: 0.2052 - acc: 0.8962Epoch 00010: val_acc improved from 0.86695 to 0.87266, saving model to model/top_model_weights.h5
# 10/10 [==============================] - 132s 13s/step - loss: 0.2077 - acc: 0.8943 - val_loss: 0.2291 - val_acc: 0.8727
# Epoch 11/20
#  9/10 [==========================>...] - ETA: 0s - loss: 0.1456 - acc: 0.9239Epoch 00011: val_acc improved from 0.87266 to 0.87611, saving model to model/top_model_weights.h5
# 10/10 [==============================] - 132s 13s/step - loss: 0.1430 - acc: 0.9237 - val_loss: 0.2306 - val_acc: 0.8761
# Epoch 12/20
#  9/10 [==========================>...] - ETA: 0s - loss: 0.2048 - acc: 0.8885Epoch 00012: val_acc did not improve
# 10/10 [==============================] - 132s 13s/step - loss: 0.1959 - acc: 0.8950 - val_loss: 0.3694 - val_acc: 0.8558
# Epoch 13/20
#  9/10 [==========================>...] - ETA: 0s - loss: 0.1970 - acc: 0.9095Epoch 00013: val_acc improved from 0.87611 to 0.91355, saving model to model/top_model_weights.h5
# 10/10 [==============================] - 132s 13s/step - loss: 0.1994 - acc: 0.9076 - val_loss: 0.1912 - val_acc: 0.9136
# Epoch 14/20
#  9/10 [==========================>...] - ETA: 0s - loss: 0.1511 - acc: 0.9299Epoch 00014: val_acc did not improve
# 10/10 [==============================] - 132s 13s/step - loss: 0.1547 - acc: 0.9307 - val_loss: 0.2469 - val_acc: 0.8755
# Epoch 15/20
#  9/10 [==========================>...] - ETA: 0s - loss: 0.2061 - acc: 0.8957Epoch 00015: val_acc improved from 0.91355 to 0.93663, saving model to model/top_model_weights.h5
# 10/10 [==============================] - 132s 13s/step - loss: 0.2026 - acc: 0.8954 - val_loss: 0.1848 - val_acc: 0.9366
# Epoch 16/20
#  9/10 [==========================>...] - ETA: 0s - loss: 0.1497 - acc: 0.9358Epoch 00016: val_acc did not improve
# 10/10 [==============================] - 132s 13s/step - loss: 0.1501 - acc: 0.9406 - val_loss: 0.2724 - val_acc: 0.8607
# Epoch 17/20
#  9/10 [==========================>...] - ETA: 0s - loss: 0.1564 - acc: 0.9318Epoch 00017: val_acc did not improve
# 10/10 [==============================] - 132s 13s/step - loss: 0.1491 - acc: 0.9370 - val_loss: 0.3380 - val_acc: 0.8587
# Epoch 18/20
#  9/10 [==========================>...] - ETA: 0s - loss: 0.1659 - acc: 0.9226Epoch 00018: val_acc did not improve
# 10/10 [==============================] - 132s 13s/step - loss: 0.1603 - acc: 0.9241 - val_loss: 0.1748 - val_acc: 0.9277
# Epoch 19/20
#  9/10 [==========================>...] - ETA: 0s - loss: 0.1116 - acc: 0.9408Epoch 00019: val_acc improved from 0.93663 to 0.94214, saving model to model/top_model_weights.h5
# 10/10 [==============================] - 132s 13s/step - loss: 0.1138 - acc: 0.9373 - val_loss: 0.2140 - val_acc: 0.9421
# Epoch 20/20
#  9/10 [==========================>...] - ETA: 0s - loss: 0.1538 - acc: 0.9306Epoch 00020: val_acc improved from 0.94214 to 0.94519, saving model to model/top_model_weights.h5
# 10/10 [==============================] - 132s 13s/step - loss: 0.1592 - acc: 0.9283 - val_loss: 0.1794 - val_acc: 0.9452
#
# Starting to Fine Tune Model
# /home/grupoavatar/.local/lib/python3.5/site-packages/keras/callbacks.py:375: RuntimeWarning: ModelCheckpoint mode mode is unknown, fallback to auto mode.
#   RuntimeWarning)
# /home/grupoavatar/.local/lib/python3.5/site-packages/ipykernel_launcher.py:100: UserWarning: The semantics of the Keras 2 argument `steps_per_epoch` is not the same as the Keras 1 argument `samples_per_epoch`. `steps_per_epoch` is the number of batches to draw from the generator at each epoch. Basically steps_per_epoch = samples_per_epoch/batch_size. Similarly `nb_val_samples`->`validation_steps` and `val_samples`->`steps` arguments have changed. Update your method calls accordingly.
# /home/grupoavatar/.local/lib/python3.5/site-packages/ipykernel_launcher.py:100: UserWarning: Update your `fit_generator` call to the Keras 2 API: `fit_generator(<keras.pre..., epochs=100, validation_steps=346, steps_per_epoch=10, validation_data=<keras.pre..., callbacks=[<keras.ca...)`
# Epoch 1/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.1354 - acc: 0.9646Epoch 00001: val_loss improved from inf to 0.18202, saving model to model/model_weights.h5
# 10/10 [==============================] - 138s 14s/step - loss: 0.1351 - acc: 0.9620 - val_loss: 0.1820 - val_acc: 0.9478
# Epoch 2/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.1415 - acc: 0.9398Epoch 00002: val_loss did not improve
# 10/10 [==============================] - 134s 13s/step - loss: 0.1442 - acc: 0.9350 - val_loss: 0.1825 - val_acc: 0.9509
# Epoch 3/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.1195 - acc: 0.9631Epoch 00003: val_loss did not improve
# 10/10 [==============================] - 134s 13s/step - loss: 0.1203 - acc: 0.9620 - val_loss: 0.1823 - val_acc: 0.9481
# Epoch 4/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.1313 - acc: 0.9566Epoch 00004: val_loss did not improve
# 10/10 [==============================] - 134s 13s/step - loss: 0.1304 - acc: 0.9569 - val_loss: 0.1831 - val_acc: 0.9476
# Epoch 5/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.1220 - acc: 0.9601Epoch 00005: val_loss did not improve
# 10/10 [==============================] - 134s 13s/step - loss: 0.1224 - acc: 0.9594 - val_loss: 0.1829 - val_acc: 0.9448
# Epoch 6/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.1213 - acc: 0.9586Epoch 00006: val_loss did not improve
# 10/10 [==============================] - 134s 13s/step - loss: 0.1196 - acc: 0.9612 - val_loss: 0.1821 - val_acc: 0.9448
# Epoch 7/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.1000 - acc: 0.9809Epoch 00007: val_loss improved from 0.18202 to 0.18195, saving model to model/model_weights.h5
# 10/10 [==============================] - 135s 14s/step - loss: 0.1005 - acc: 0.9781 - val_loss: 0.1819 - val_acc: 0.9421
# Epoch 8/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.1282 - acc: 0.9509Epoch 00008: val_loss improved from 0.18195 to 0.18059, saving model to model/model_weights.h5
# 10/10 [==============================] - 134s 13s/step - loss: 0.1236 - acc: 0.9542 - val_loss: 0.1806 - val_acc: 0.9448
# Epoch 9/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0977 - acc: 0.9792Epoch 00009: val_loss improved from 0.18059 to 0.17912, saving model to model/model_weights.h5
# 10/10 [==============================] - 134s 13s/step - loss: 0.0982 - acc: 0.9781 - val_loss: 0.1791 - val_acc: 0.9538
# Epoch 10/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.1031 - acc: 0.9757Epoch 00010: val_loss improved from 0.17912 to 0.17729, saving model to model/model_weights.h5
# 10/10 [==============================] - 134s 13s/step - loss: 0.1049 - acc: 0.9749 - val_loss: 0.1773 - val_acc: 0.9625
# Epoch 11/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.1118 - acc: 0.9549Epoch 00011: val_loss improved from 0.17729 to 0.17496, saving model to model/model_weights.h5
# 10/10 [==============================] - 135s 13s/step - loss: 0.1060 - acc: 0.9593 - val_loss: 0.1750 - val_acc: 0.9652
# Epoch 12/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.1179 - acc: 0.9497Epoch 00012: val_loss improved from 0.17496 to 0.17231, saving model to model/model_weights.h5
# 10/10 [==============================] - 135s 13s/step - loss: 0.1188 - acc: 0.9487 - val_loss: 0.1723 - val_acc: 0.9598
# Epoch 13/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.1164 - acc: 0.9651Epoch 00013: val_loss improved from 0.17231 to 0.17047, saving model to model/model_weights.h5
# 10/10 [==============================] - 134s 13s/step - loss: 0.1151 - acc: 0.9671 - val_loss: 0.1705 - val_acc: 0.9622
# Epoch 14/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.1101 - acc: 0.9589Epoch 00014: val_loss improved from 0.17047 to 0.16777, saving model to model/model_weights.h5
# 10/10 [==============================] - 134s 13s/step - loss: 0.1086 - acc: 0.9616 - val_loss: 0.1678 - val_acc: 0.9625
# Epoch 15/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.1135 - acc: 0.9584Epoch 00015: val_loss improved from 0.16777 to 0.16568, saving model to model/model_weights.h5
# 10/10 [==============================] - 135s 14s/step - loss: 0.1139 - acc: 0.9596 - val_loss: 0.1657 - val_acc: 0.9627
# Epoch 16/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.1026 - acc: 0.9653Epoch 00016: val_loss improved from 0.16568 to 0.16542, saving model to model/model_weights.h5
# 10/10 [==============================] - 134s 13s/step - loss: 0.1016 - acc: 0.9648 - val_loss: 0.1654 - val_acc: 0.9624
# Epoch 17/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.1056 - acc: 0.9626Epoch 00017: val_loss improved from 0.16542 to 0.16475, saving model to model/model_weights.h5
# 10/10 [==============================] - 134s 13s/step - loss: 0.1047 - acc: 0.9648 - val_loss: 0.1648 - val_acc: 0.9626
# Epoch 18/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.1061 - acc: 0.9618Epoch 00018: val_loss improved from 0.16475 to 0.16325, saving model to model/model_weights.h5
# 10/10 [==============================] - 136s 14s/step - loss: 0.1061 - acc: 0.9641 - val_loss: 0.1633 - val_acc: 0.9622
# Epoch 19/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0940 - acc: 0.9757Epoch 00019: val_loss improved from 0.16325 to 0.16121, saving model to model/model_weights.h5
# 10/10 [==============================] - 134s 13s/step - loss: 0.0933 - acc: 0.9781 - val_loss: 0.1612 - val_acc: 0.9681
# Epoch 20/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.1124 - acc: 0.9544Epoch 00020: val_loss improved from 0.16121 to 0.15909, saving model to model/model_weights.h5
# 10/10 [==============================] - 134s 13s/step - loss: 0.1117 - acc: 0.9542 - val_loss: 0.1591 - val_acc: 0.9594
# Epoch 21/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.1014 - acc: 0.9695Epoch 00021: val_loss improved from 0.15909 to 0.15726, saving model to model/model_weights.h5
# 10/10 [==============================] - 134s 13s/step - loss: 0.1042 - acc: 0.9695 - val_loss: 0.1573 - val_acc: 0.9567
# Epoch 22/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.1035 - acc: 0.9676Epoch 00022: val_loss improved from 0.15726 to 0.15554, saving model to model/model_weights.h5
# 10/10 [==============================] - 134s 13s/step - loss: 0.1025 - acc: 0.9679 - val_loss: 0.1555 - val_acc: 0.9567
# Epoch 23/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0931 - acc: 0.9769Epoch 00023: val_loss improved from 0.15554 to 0.15466, saving model to model/model_weights.h5
# 10/10 [==============================] - 134s 13s/step - loss: 0.0917 - acc: 0.9777 - val_loss: 0.1547 - val_acc: 0.9536
# Epoch 24/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.1014 - acc: 0.9618Epoch 00024: val_loss improved from 0.15466 to 0.15366, saving model to model/model_weights.h5
# 10/10 [==============================] - 135s 13s/step - loss: 0.0976 - acc: 0.9656 - val_loss: 0.1537 - val_acc: 0.9565
# Epoch 25/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0995 - acc: 0.9700Epoch 00025: val_loss improved from 0.15366 to 0.15190, saving model to model/model_weights.h5
# 10/10 [==============================] - 134s 13s/step - loss: 0.1016 - acc: 0.9667 - val_loss: 0.1519 - val_acc: 0.9567
# Epoch 26/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0888 - acc: 0.9688Epoch 00026: val_loss improved from 0.15190 to 0.15158, saving model to model/model_weights.h5
# 10/10 [==============================] - 134s 13s/step - loss: 0.0890 - acc: 0.9718 - val_loss: 0.1516 - val_acc: 0.9540
# Epoch 27/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0861 - acc: 0.9792Epoch 00027: val_loss did not improve
# 10/10 [==============================] - 134s 13s/step - loss: 0.0851 - acc: 0.9797 - val_loss: 0.1521 - val_acc: 0.9537
# Epoch 28/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.1034 - acc: 0.9670Epoch 00028: val_loss improved from 0.15158 to 0.15109, saving model to model/model_weights.h5
# 10/10 [==============================] - 135s 13s/step - loss: 0.1018 - acc: 0.9671 - val_loss: 0.1511 - val_acc: 0.9539
# Epoch 29/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0961 - acc: 0.9660Epoch 00029: val_loss improved from 0.15109 to 0.14966, saving model to model/model_weights.h5
# 10/10 [==============================] - 134s 13s/step - loss: 0.0946 - acc: 0.9648 - val_loss: 0.1497 - val_acc: 0.9509
# Epoch 30/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0875 - acc: 0.9799Epoch 00030: val_loss improved from 0.14966 to 0.14836, saving model to model/model_weights.h5
# 10/10 [==============================] - 135s 13s/step - loss: 0.0874 - acc: 0.9819 - val_loss: 0.1484 - val_acc: 0.9541
# Epoch 31/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0955 - acc: 0.9730Epoch 00031: val_loss improved from 0.14836 to 0.14745, saving model to model/model_weights.h5
# 10/10 [==============================] - 134s 13s/step - loss: 0.0977 - acc: 0.9710 - val_loss: 0.1475 - val_acc: 0.9566
# Epoch 32/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0900 - acc: 0.9705Epoch 00032: val_loss improved from 0.14745 to 0.14644, saving model to model/model_weights.h5
# 10/10 [==============================] - 134s 13s/step - loss: 0.0883 - acc: 0.9719 - val_loss: 0.1464 - val_acc: 0.9565
# Epoch 33/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0820 - acc: 0.9844Epoch 00033: val_loss improved from 0.14644 to 0.14405, saving model to model/model_weights.h5
# 10/10 [==============================] - 134s 13s/step - loss: 0.0842 - acc: 0.9796 - val_loss: 0.1441 - val_acc: 0.9537
# Epoch 34/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0981 - acc: 0.9688Epoch 00034: val_loss improved from 0.14405 to 0.14200, saving model to model/model_weights.h5
# 10/10 [==============================] - 134s 13s/step - loss: 0.0983 - acc: 0.9703 - val_loss: 0.1420 - val_acc: 0.9539
# Epoch 35/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0934 - acc: 0.9648Epoch 00035: val_loss improved from 0.14200 to 0.13986, saving model to model/model_weights.h5
# 10/10 [==============================] - 134s 13s/step - loss: 0.0921 - acc: 0.9652 - val_loss: 0.1399 - val_acc: 0.9509
# Epoch 36/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0852 - acc: 0.9792Epoch 00036: val_loss improved from 0.13986 to 0.13761, saving model to model/model_weights.h5
# 10/10 [==============================] - 135s 14s/step - loss: 0.0881 - acc: 0.9781 - val_loss: 0.1376 - val_acc: 0.9509
# Epoch 37/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0990 - acc: 0.9760Epoch 00037: val_loss improved from 0.13761 to 0.13528, saving model to model/model_weights.h5
# 10/10 [==============================] - 134s 13s/step - loss: 0.0962 - acc: 0.9784 - val_loss: 0.1353 - val_acc: 0.9566
# Epoch 38/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0846 - acc: 0.9740Epoch 00038: val_loss improved from 0.13528 to 0.13248, saving model to model/model_weights.h5
# 10/10 [==============================] - 134s 13s/step - loss: 0.0878 - acc: 0.9734 - val_loss: 0.1325 - val_acc: 0.9538
# Epoch 39/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0834 - acc: 0.9740Epoch 00039: val_loss improved from 0.13248 to 0.13055, saving model to model/model_weights.h5
# 10/10 [==============================] - 135s 14s/step - loss: 0.0844 - acc: 0.9750 - val_loss: 0.1306 - val_acc: 0.9534
# Epoch 40/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0915 - acc: 0.9708Epoch 00040: val_loss improved from 0.13055 to 0.12834, saving model to model/model_weights.h5
# 10/10 [==============================] - 135s 13s/step - loss: 0.0970 - acc: 0.9659 - val_loss: 0.1283 - val_acc: 0.9508
# Epoch 41/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.1007 - acc: 0.9670Epoch 00041: val_loss improved from 0.12834 to 0.12626, saving model to model/model_weights.h5
# 10/10 [==============================] - 134s 13s/step - loss: 0.0956 - acc: 0.9703 - val_loss: 0.1263 - val_acc: 0.9508
# Epoch 42/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0888 - acc: 0.9740Epoch 00042: val_loss improved from 0.12626 to 0.12401, saving model to model/model_weights.h5
# 10/10 [==============================] - 135s 13s/step - loss: 0.0844 - acc: 0.9765 - val_loss: 0.1240 - val_acc: 0.9565
# Epoch 43/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0952 - acc: 0.9740Epoch 00043: val_loss improved from 0.12401 to 0.12130, saving model to model/model_weights.h5
# 10/10 [==============================] - 134s 13s/step - loss: 0.0959 - acc: 0.9749 - val_loss: 0.1213 - val_acc: 0.9597
# Epoch 44/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0868 - acc: 0.9700Epoch 00044: val_loss improved from 0.12130 to 0.11919, saving model to model/model_weights.h5
# 10/10 [==============================] - 134s 13s/step - loss: 0.0835 - acc: 0.9730 - val_loss: 0.1192 - val_acc: 0.9625
# Epoch 45/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0849 - acc: 0.9769Epoch 00045: val_loss improved from 0.11919 to 0.11702, saving model to model/model_weights.h5
# 10/10 [==============================] - 134s 13s/step - loss: 0.0870 - acc: 0.9746 - val_loss: 0.1170 - val_acc: 0.9597
# Epoch 46/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0763 - acc: 0.9792Epoch 00046: val_loss improved from 0.11702 to 0.11522, saving model to model/model_weights.h5
# 10/10 [==============================] - 135s 13s/step - loss: 0.0791 - acc: 0.9750 - val_loss: 0.1152 - val_acc: 0.9654
# Epoch 47/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0738 - acc: 0.9839Epoch 00047: val_loss improved from 0.11522 to 0.11275, saving model to model/model_weights.h5
# 10/10 [==============================] - 134s 13s/step - loss: 0.0793 - acc: 0.9808 - val_loss: 0.1128 - val_acc: 0.9653
# Epoch 48/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0823 - acc: 0.9804Epoch 00048: val_loss improved from 0.11275 to 0.11100, saving model to model/model_weights.h5
# 10/10 [==============================] - 134s 13s/step - loss: 0.0821 - acc: 0.9824 - val_loss: 0.1110 - val_acc: 0.9653
# Epoch 49/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0841 - acc: 0.9688Epoch 00049: val_loss improved from 0.11100 to 0.10961, saving model to model/model_weights.h5
# 10/10 [==============================] - 134s 13s/step - loss: 0.0823 - acc: 0.9686 - val_loss: 0.1096 - val_acc: 0.9654
# Epoch 50/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0911 - acc: 0.9826Epoch 00050: val_loss improved from 0.10961 to 0.10827, saving model to model/model_weights.h5
# 10/10 [==============================] - 134s 13s/step - loss: 0.0960 - acc: 0.9797 - val_loss: 0.1083 - val_acc: 0.9653
# Epoch 51/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0865 - acc: 0.9725Epoch 00051: val_loss improved from 0.10827 to 0.10702, saving model to model/model_weights.h5
# 10/10 [==============================] - 134s 13s/step - loss: 0.0870 - acc: 0.9738 - val_loss: 0.1070 - val_acc: 0.9683
# Epoch 52/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0746 - acc: 0.9817Epoch 00052: val_loss improved from 0.10702 to 0.10660, saving model to model/model_weights.h5
# 10/10 [==============================] - 134s 13s/step - loss: 0.0764 - acc: 0.9788 - val_loss: 0.1066 - val_acc: 0.9683
# Epoch 53/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0833 - acc: 0.9757Epoch 00053: val_loss improved from 0.10660 to 0.10655, saving model to model/model_weights.h5
# 10/10 [==============================] - 135s 13s/step - loss: 0.0855 - acc: 0.9719 - val_loss: 0.1066 - val_acc: 0.9654
# Epoch 54/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0781 - acc: 0.9787Epoch 00054: val_loss did not improve
# 10/10 [==============================] - 134s 13s/step - loss: 0.0774 - acc: 0.9808 - val_loss: 0.1068 - val_acc: 0.9622
# Epoch 55/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0846 - acc: 0.9822Epoch 00055: val_loss improved from 0.10655 to 0.10644, saving model to model/model_weights.h5
# 10/10 [==============================] - 135s 13s/step - loss: 0.0836 - acc: 0.9808 - val_loss: 0.1064 - val_acc: 0.9626
# Epoch 56/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0820 - acc: 0.9757Epoch 00056: val_loss did not improve
# 10/10 [==============================] - 134s 13s/step - loss: 0.0877 - acc: 0.9722 - val_loss: 0.1065 - val_acc: 0.9623
# Epoch 57/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0856 - acc: 0.9738Epoch 00057: val_loss improved from 0.10644 to 0.10621, saving model to model/model_weights.h5
# 10/10 [==============================] - 135s 13s/step - loss: 0.0839 - acc: 0.9749 - val_loss: 0.1062 - val_acc: 0.9624
# Epoch 58/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0807 - acc: 0.9740Epoch 00058: val_loss improved from 0.10621 to 0.10583, saving model to model/model_weights.h5
# 10/10 [==============================] - 135s 13s/step - loss: 0.0814 - acc: 0.9749 - val_loss: 0.1058 - val_acc: 0.9624
# Epoch 59/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0676 - acc: 0.9896Epoch 00059: val_loss improved from 0.10583 to 0.10547, saving model to model/model_weights.h5
# 10/10 [==============================] - 134s 13s/step - loss: 0.0702 - acc: 0.9875 - val_loss: 0.1055 - val_acc: 0.9625
# Epoch 60/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0887 - acc: 0.9700Epoch 00060: val_loss did not improve
# 10/10 [==============================] - 134s 13s/step - loss: 0.0858 - acc: 0.9730 - val_loss: 0.1057 - val_acc: 0.9596
# Epoch 61/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0707 - acc: 0.9822Epoch 00061: val_loss improved from 0.10547 to 0.10525, saving model to model/model_weights.h5
# 10/10 [==============================] - 134s 13s/step - loss: 0.0736 - acc: 0.9776 - val_loss: 0.1053 - val_acc: 0.9625
# Epoch 62/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0866 - acc: 0.9757Epoch 00062: val_loss improved from 0.10525 to 0.10445, saving model to model/model_weights.h5
# 10/10 [==============================] - 134s 13s/step - loss: 0.0893 - acc: 0.9766 - val_loss: 0.1044 - val_acc: 0.9627
# Epoch 63/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0850 - acc: 0.9869Epoch 00063: val_loss improved from 0.10445 to 0.10424, saving model to model/model_weights.h5
# 10/10 [==============================] - 135s 14s/step - loss: 0.0844 - acc: 0.9851 - val_loss: 0.1042 - val_acc: 0.9599
# Epoch 64/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0836 - acc: 0.9757Epoch 00064: val_loss did not improve
# 10/10 [==============================] - 134s 13s/step - loss: 0.0849 - acc: 0.9765 - val_loss: 0.1046 - val_acc: 0.9593
# Epoch 65/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0749 - acc: 0.9839Epoch 00065: val_loss improved from 0.10424 to 0.10405, saving model to model/model_weights.h5
# 10/10 [==============================] - 135s 14s/step - loss: 0.0741 - acc: 0.9824 - val_loss: 0.1040 - val_acc: 0.9594
# Epoch 66/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0764 - acc: 0.9878Epoch 00066: val_loss improved from 0.10405 to 0.10362, saving model to model/model_weights.h5
# 10/10 [==============================] - 134s 13s/step - loss: 0.0764 - acc: 0.9890 - val_loss: 0.1036 - val_acc: 0.9595
# Epoch 67/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0806 - acc: 0.9839Epoch 00067: val_loss improved from 0.10362 to 0.10345, saving model to model/model_weights.h5
# 10/10 [==============================] - 135s 14s/step - loss: 0.0778 - acc: 0.9855 - val_loss: 0.1034 - val_acc: 0.9592
# Epoch 68/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0713 - acc: 0.9903Epoch 00068: val_loss improved from 0.10345 to 0.10313, saving model to model/model_weights.h5
# 10/10 [==============================] - 135s 14s/step - loss: 0.0736 - acc: 0.9882 - val_loss: 0.1031 - val_acc: 0.9596
# Epoch 69/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0770 - acc: 0.9792Epoch 00069: val_loss did not improve
# 10/10 [==============================] - 134s 13s/step - loss: 0.0820 - acc: 0.9734 - val_loss: 0.1032 - val_acc: 0.9569
# Epoch 70/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0723 - acc: 0.9856Epoch 00070: val_loss improved from 0.10313 to 0.10313, saving model to model/model_weights.h5
# 10/10 [==============================] - 134s 13s/step - loss: 0.0714 - acc: 0.9871 - val_loss: 0.1031 - val_acc: 0.9567
# Epoch 71/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0740 - acc: 0.9839Epoch 00071: val_loss did not improve
# 10/10 [==============================] - 134s 13s/step - loss: 0.0736 - acc: 0.9855 - val_loss: 0.1032 - val_acc: 0.9565
# Epoch 72/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0750 - acc: 0.9757Epoch 00072: val_loss improved from 0.10313 to 0.10297, saving model to model/model_weights.h5
# 10/10 [==============================] - 135s 13s/step - loss: 0.0736 - acc: 0.9781 - val_loss: 0.1030 - val_acc: 0.9595
# Epoch 73/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0910 - acc: 0.9717Epoch 00073: val_loss did not improve
# 10/10 [==============================] - 134s 13s/step - loss: 0.0877 - acc: 0.9745 - val_loss: 0.1033 - val_acc: 0.9539
# Epoch 74/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0779 - acc: 0.9913Epoch 00074: val_loss did not improve
# 10/10 [==============================] - 134s 13s/step - loss: 0.0762 - acc: 0.9922 - val_loss: 0.1031 - val_acc: 0.9565
# Epoch 75/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0740 - acc: 0.9839Epoch 00075: val_loss did not improve
# 10/10 [==============================] - 134s 13s/step - loss: 0.0822 - acc: 0.9776 - val_loss: 0.1031 - val_acc: 0.9539
# Epoch 76/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0683 - acc: 0.9844Epoch 00076: val_loss improved from 0.10297 to 0.10256, saving model to model/model_weights.h5
# 10/10 [==============================] - 135s 13s/step - loss: 0.0669 - acc: 0.9859 - val_loss: 0.1026 - val_acc: 0.9596
# Epoch 77/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0732 - acc: 0.9896Epoch 00077: val_loss improved from 0.10256 to 0.10186, saving model to model/model_weights.h5
# 10/10 [==============================] - 134s 13s/step - loss: 0.0788 - acc: 0.9828 - val_loss: 0.1019 - val_acc: 0.9597
# Epoch 78/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0757 - acc: 0.9799Epoch 00078: val_loss did not improve
# 10/10 [==============================] - 134s 13s/step - loss: 0.0792 - acc: 0.9789 - val_loss: 0.1022 - val_acc: 0.9594
# Epoch 79/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0715 - acc: 0.9817Epoch 00079: val_loss improved from 0.10186 to 0.10151, saving model to model/model_weights.h5
# 10/10 [==============================] - 135s 13s/step - loss: 0.0703 - acc: 0.9835 - val_loss: 0.1015 - val_acc: 0.9593
# Epoch 80/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0687 - acc: 0.9931Epoch 00080: val_loss improved from 0.10151 to 0.10078, saving model to model/model_weights.h5
# 10/10 [==============================] - 135s 13s/step - loss: 0.0705 - acc: 0.9922 - val_loss: 0.1008 - val_acc: 0.9624
# Epoch 81/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0781 - acc: 0.9861Epoch 00081: val_loss improved from 0.10078 to 0.10037, saving model to model/model_weights.h5
# 10/10 [==============================] - 134s 13s/step - loss: 0.0806 - acc: 0.9812 - val_loss: 0.1004 - val_acc: 0.9597
# Epoch 82/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0665 - acc: 0.9878Epoch 00082: val_loss improved from 0.10037 to 0.09926, saving model to model/model_weights.h5
# 10/10 [==============================] - 135s 13s/step - loss: 0.0658 - acc: 0.9890 - val_loss: 0.0993 - val_acc: 0.9624
# Epoch 83/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0782 - acc: 0.9757Epoch 00083: val_loss improved from 0.09926 to 0.09866, saving model to model/model_weights.h5
# 10/10 [==============================] - 134s 13s/step - loss: 0.0772 - acc: 0.9766 - val_loss: 0.0987 - val_acc: 0.9654
# Epoch 84/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0687 - acc: 0.9861Epoch 00084: val_loss did not improve
# 10/10 [==============================] - 134s 13s/step - loss: 0.0692 - acc: 0.9843 - val_loss: 0.0988 - val_acc: 0.9681
# Epoch 85/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0790 - acc: 0.9720Epoch 00085: val_loss improved from 0.09866 to 0.09838, saving model to model/model_weights.h5
# 10/10 [==============================] - 134s 13s/step - loss: 0.0798 - acc: 0.9733 - val_loss: 0.0984 - val_acc: 0.9651
# Epoch 86/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0633 - acc: 0.9913Epoch 00086: val_loss improved from 0.09838 to 0.09778, saving model to model/model_weights.h5
# 10/10 [==============================] - 134s 13s/step - loss: 0.0626 - acc: 0.9922 - val_loss: 0.0978 - val_acc: 0.9681
# Epoch 87/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0724 - acc: 0.9844Epoch 00087: val_loss improved from 0.09778 to 0.09723, saving model to model/model_weights.h5
# 10/10 [==============================] - 135s 13s/step - loss: 0.0744 - acc: 0.9828 - val_loss: 0.0972 - val_acc: 0.9683
# Epoch 88/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0634 - acc: 0.9861Epoch 00088: val_loss did not improve
# 10/10 [==============================] - 134s 13s/step - loss: 0.0634 - acc: 0.9875 - val_loss: 0.0975 - val_acc: 0.9682
# Epoch 89/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0778 - acc: 0.9869Epoch 00089: val_loss improved from 0.09723 to 0.09721, saving model to model/model_weights.h5
# 10/10 [==============================] - 135s 13s/step - loss: 0.0739 - acc: 0.9882 - val_loss: 0.0972 - val_acc: 0.9655
# Epoch 90/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0821 - acc: 0.9834Epoch 00090: val_loss improved from 0.09721 to 0.09711, saving model to model/model_weights.h5
# 10/10 [==============================] - 134s 13s/step - loss: 0.0804 - acc: 0.9851 - val_loss: 0.0971 - val_acc: 0.9683
# Epoch 91/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0767 - acc: 0.9844Epoch 00091: val_loss improved from 0.09711 to 0.09662, saving model to model/model_weights.h5
# 10/10 [==============================] - 134s 13s/step - loss: 0.0777 - acc: 0.9859 - val_loss: 0.0966 - val_acc: 0.9684
# Epoch 92/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0607 - acc: 0.9874Epoch 00092: val_loss improved from 0.09662 to 0.09593, saving model to model/model_weights.h5
# 10/10 [==============================] - 135s 13s/step - loss: 0.0640 - acc: 0.9886 - val_loss: 0.0959 - val_acc: 0.9683
# Epoch 93/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0753 - acc: 0.9809Epoch 00093: val_loss improved from 0.09593 to 0.09516, saving model to model/model_weights.h5
# 10/10 [==============================] - 134s 13s/step - loss: 0.0754 - acc: 0.9812 - val_loss: 0.0952 - val_acc: 0.9711
# Epoch 94/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0816 - acc: 0.9792Epoch 00094: val_loss did not improve
# 10/10 [==============================] - 134s 13s/step - loss: 0.0837 - acc: 0.9797 - val_loss: 0.0959 - val_acc: 0.9679
# Epoch 95/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0654 - acc: 0.9876Epoch 00095: val_loss improved from 0.09516 to 0.09488, saving model to model/model_weights.h5
# 10/10 [==============================] - 134s 13s/step - loss: 0.0648 - acc: 0.9890 - val_loss: 0.0949 - val_acc: 0.9682
# Epoch 96/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0847 - acc: 0.9826Epoch 00096: val_loss improved from 0.09488 to 0.09482, saving model to model/model_weights.h5
# 10/10 [==============================] - 135s 14s/step - loss: 0.0824 - acc: 0.9843 - val_loss: 0.0948 - val_acc: 0.9684
# Epoch 97/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0606 - acc: 0.9931Epoch 00097: val_loss improved from 0.09482 to 0.09460, saving model to model/model_weights.h5
# 10/10 [==============================] - 134s 13s/step - loss: 0.0607 - acc: 0.9922 - val_loss: 0.0946 - val_acc: 0.9682
# Epoch 98/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0822 - acc: 0.9799Epoch 00098: val_loss did not improve
# 10/10 [==============================] - 134s 13s/step - loss: 0.0830 - acc: 0.9804 - val_loss: 0.0948 - val_acc: 0.9682
# Epoch 99/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0642 - acc: 0.9926Epoch 00099: val_loss improved from 0.09460 to 0.09390, saving model to model/model_weights.h5
# 10/10 [==============================] - 135s 13s/step - loss: 0.0649 - acc: 0.9902 - val_loss: 0.0939 - val_acc: 0.9711
# Epoch 100/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0697 - acc: 0.9856Epoch 00100: val_loss improved from 0.09390 to 0.09337, saving model to model/model_weights.h5
# 10/10 [==============================] - 135s 13s/step - loss: 0.0664 - acc: 0.9871 - val_loss: 0.0934 - val_acc: 0.9713

# %% [markdown]
# ## Modelo Inception V3

# %%
# let's visualize layer names and layer indices to see how many layers
# we should freeze: this is used to define based_model_last_block_layer_number
for i, layer in enumerate(model_layers):  # comment these two lines once the correct based_model_last_block_layer
    print(i, layer.name)  # has been selected
# Out:
# 0 input_1
# 1 conv2d_1
# 2 batch_normalization_1
# 3 activation_1
# 4 conv2d_2
# 5 batch_normalization_2
# 6 activation_2
# 7 conv2d_3
# 8 batch_normalization_3
# 9 activation_3
# 10 max_pooling2d_1
# 11 conv2d_4
# 12 batch_normalization_4
# 13 activation_4
# 14 conv2d_5
# 15 batch_normalization_5
# 16 activation_5
# 17 max_pooling2d_2
# 18 conv2d_9
# 19 batch_normalization_9
# 20 activation_9
# 21 conv2d_7
# 22 conv2d_10
# 23 batch_normalization_7
# 24 batch_normalization_10
# 25 activation_7
# 26 activation_10
# 27 average_pooling2d_1
# 28 conv2d_6
# 29 conv2d_8
# 30 conv2d_11
# 31 conv2d_12
# 32 batch_normalization_6
# 33 batch_normalization_8
# 34 batch_normalization_11
# 35 batch_normalization_12
# 36 activation_6
# 37 activation_8
# 38 activation_11
# 39 activation_12
# 40 mixed0
# 41 conv2d_16
# 42 batch_normalization_16
# 43 activation_16
# 44 conv2d_14
# 45 conv2d_17
# 46 batch_normalization_14
# 47 batch_normalization_17
# 48 activation_14
# 49 activation_17
# 50 average_pooling2d_2
# 51 conv2d_13
# 52 conv2d_15
# 53 conv2d_18
# 54 conv2d_19
# 55 batch_normalization_13
# 56 batch_normalization_15
# 57 batch_normalization_18
# 58 batch_normalization_19
# 59 activation_13
# 60 activation_15
# 61 activation_18
# 62 activation_19
# 63 mixed1
# 64 conv2d_23
# 65 batch_normalization_23
# 66 activation_23
# 67 conv2d_21
# 68 conv2d_24
# 69 batch_normalization_21
# 70 batch_normalization_24
# 71 activation_21
# 72 activation_24
# 73 average_pooling2d_3
# 74 conv2d_20
# 75 conv2d_22
# 76 conv2d_25
# 77 conv2d_26
# 78 batch_normalization_20
# 79 batch_normalization_22
# 80 batch_normalization_25
# 81 batch_normalization_26
# 82 activation_20
# 83 activation_22
# 84 activation_25
# 85 activation_26
# 86 mixed2
# 87 conv2d_28
# 88 batch_normalization_28
# 89 activation_28
# 90 conv2d_29
# 91 batch_normalization_29
# 92 activation_29
# 93 conv2d_27
# 94 conv2d_30
# 95 batch_normalization_27
# 96 batch_normalization_30
# 97 activation_27
# 98 activation_30
# 99 max_pooling2d_3
# 100 mixed3
# 101 conv2d_35
# 102 batch_normalization_35
# 103 activation_35
# 104 conv2d_36
# 105 batch_normalization_36
# 106 activation_36
# 107 conv2d_32
# 108 conv2d_37
# 109 batch_normalization_32
# 110 batch_normalization_37
# 111 activation_32
# 112 activation_37
# 113 conv2d_33
# 114 conv2d_38
# 115 batch_normalization_33
# 116 batch_normalization_38
# 117 activation_33
# 118 activation_38
# 119 average_pooling2d_4
# 120 conv2d_31
# 121 conv2d_34
# 122 conv2d_39
# 123 conv2d_40
# 124 batch_normalization_31
# 125 batch_normalization_34
# 126 batch_normalization_39
# 127 batch_normalization_40
# 128 activation_31
# 129 activation_34
# 130 activation_39
# 131 activation_40
# 132 mixed4
# 133 conv2d_45
# 134 batch_normalization_45
# 135 activation_45
# 136 conv2d_46
# 137 batch_normalization_46
# 138 activation_46
# 139 conv2d_42
# 140 conv2d_47
# 141 batch_normalization_42
# 142 batch_normalization_47
# 143 activation_42
# 144 activation_47
# 145 conv2d_43
# 146 conv2d_48
# 147 batch_normalization_43
# 148 batch_normalization_48
# 149 activation_43
# 150 activation_48
# 151 average_pooling2d_5
# 152 conv2d_41
# 153 conv2d_44
# 154 conv2d_49
# 155 conv2d_50
# 156 batch_normalization_41
# 157 batch_normalization_44
# 158 batch_normalization_49
# 159 batch_normalization_50
# 160 activation_41
# 161 activation_44
# 162 activation_49
# 163 activation_50
# 164 mixed5
# 165 conv2d_55
# 166 batch_normalization_55
# 167 activation_55
# 168 conv2d_56
# 169 batch_normalization_56
# 170 activation_56
# 171 conv2d_52
# 172 conv2d_57
# 173 batch_normalization_52
# 174 batch_normalization_57
# 175 activation_52
# 176 activation_57
# 177 conv2d_53
# 178 conv2d_58
# 179 batch_normalization_53
# 180 batch_normalization_58
# 181 activation_53
# 182 activation_58
# 183 average_pooling2d_6
# 184 conv2d_51
# 185 conv2d_54
# 186 conv2d_59
# 187 conv2d_60
# 188 batch_normalization_51
# 189 batch_normalization_54
# 190 batch_normalization_59
# 191 batch_normalization_60
# 192 activation_51
# 193 activation_54
# 194 activation_59
# 195 activation_60
# 196 mixed6
# 197 conv2d_65
# 198 batch_normalization_65
# 199 activation_65
# 200 conv2d_66
# 201 batch_normalization_66
# 202 activation_66
# 203 conv2d_62
# 204 conv2d_67
# 205 batch_normalization_62
# 206 batch_normalization_67
# 207 activation_62
# 208 activation_67
# 209 conv2d_63
# 210 conv2d_68
# 211 batch_normalization_63
# 212 batch_normalization_68
# 213 activation_63
# 214 activation_68
# 215 average_pooling2d_7
# 216 conv2d_61
# 217 conv2d_64
# 218 conv2d_69
# 219 conv2d_70
# 220 batch_normalization_61
# 221 batch_normalization_64
# 222 batch_normalization_69
# 223 batch_normalization_70
# 224 activation_61
# 225 activation_64
# 226 activation_69
# 227 activation_70
# 228 mixed7
# 229 conv2d_73
# 230 batch_normalization_73
# 231 activation_73
# 232 conv2d_74
# 233 batch_normalization_74
# 234 activation_74
# 235 conv2d_71
# 236 conv2d_75
# 237 batch_normalization_71
# 238 batch_normalization_75
# 239 activation_71
# 240 activation_75
# 241 conv2d_72
# 242 conv2d_76
# 243 batch_normalization_72
# 244 batch_normalization_76
# 245 activation_72
# 246 activation_76
# 247 max_pooling2d_4
# 248 mixed8
# 249 conv2d_81
# 250 batch_normalization_81
# 251 activation_81
# 252 conv2d_78
# 253 conv2d_82
# 254 batch_normalization_78
# 255 batch_normalization_82
# 256 activation_78
# 257 activation_82
# 258 conv2d_79
# 259 conv2d_80
# 260 conv2d_83
# 261 conv2d_84
# 262 average_pooling2d_8
# 263 conv2d_77
# 264 batch_normalization_79
# 265 batch_normalization_80
# 266 batch_normalization_83
# 267 batch_normalization_84
# 268 conv2d_85
# 269 batch_normalization_77
# 270 activation_79
# 271 activation_80
# 272 activation_83
# 273 activation_84
# 274 batch_normalization_85
# 275 activation_77
# 276 mixed9_0
# 277 concatenate_1
# 278 activation_85
# 279 mixed9
# 280 conv2d_90
# 281 batch_normalization_90
# 282 activation_90
# 283 conv2d_87
# 284 conv2d_91
# 285 batch_normalization_87
# 286 batch_normalization_91
# 287 activation_87
# 288 activation_91
# 289 conv2d_88
# 290 conv2d_89
# 291 conv2d_92
# 292 conv2d_93
# 293 average_pooling2d_9
# 294 conv2d_86
# 295 batch_normalization_88
# 296 batch_normalization_89
# 297 batch_normalization_92
# 298 batch_normalization_93
# 299 conv2d_94
# 300 batch_normalization_86
# 301 activation_88
# 302 activation_89
# 303 activation_92
# 304 activation_93
# 305 batch_normalization_94
# 306 activation_86
# 307 mixed9_1
# 308 concatenate_2
# 309 activation_94
# 310 mixed10
# 311 global_average_pooling2d_1
# 312 dense_1
# 313 dropout_1
# 314 dense_2

# %% [markdown]
# ## Resultados
#
# ### Transfer Learning

# %%
def plot_training2(history):
    #% matplotlib inline

    df = pd.DataFrame(history.history)
    # display(df)

    plot = df.plot(y=['loss', 'val_loss'], figsize=(8, 4), title='Training and validation loss', legend=True)
    plot.set_xlabel('Epochs')
    plot.set_ylabel('Loss binary_crossentropy')    
    fig = plot.get_figure()
    fig.savefig('loss_graph_t_cancer_t:'+str(nb_train_samples)+'smp_v:'+str(nb_validation_samples)+'smp_'+str(nb_epoch)+'epc.png')

    plot = df.plot(y=['acc', 'val_acc'], figsize=(8, 4), title='Training and validation accuracy', legend=True)
    plot.set_xlabel('Epochs')
    plot.set_ylabel('Accuracy')
    fig = plot.get_figure()
    fig.savefig('acc_graph_t_cancer_t:'+str(nb_train_samples)+'smp_v:'+str(nb_validation_samples)+'smp_'+str(nb_epoch)+'epc.png')
    
    plt.show()

#Transfer Learning    
plot_training2(hist_tl)
# Out:
# /home/grupoavatar/.local/lib/python3.5/site-packages/pandas/plotting/_core.py:1714: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   series.name = label
# /home/grupoavatar/.local/lib/python3.5/site-packages/pandas/plotting/_core.py:1714: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   series.name = label

# %% [markdown]
# ## Resultados
#
# ### Fine Tune

# %%
#Finetune
plot_training2(hist_ft)
# Out:
# /home/grupoavatar/.local/lib/python3.5/site-packages/pandas/plotting/_core.py:1714: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   series.name = label

# %% [markdown]
# ## Cierre

# %%
# release memory
k.clear_session()
