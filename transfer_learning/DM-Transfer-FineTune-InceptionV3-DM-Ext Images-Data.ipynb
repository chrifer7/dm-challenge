# %% [markdown]
# # Clasificación de mamografías usando Transfer learning y Fine Tune con InceptionV3

# %% [markdown]
# ## Importación de librerías

# %%
import sys
import numpy as np
import tensorflow as tf
#import matplotlib.pyplot as plt
# Generacion del grafico de metricas de Perdidas y Accuracy
import pandas as pd
import matplotlib.pyplot as plt
#ML
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import GlobalAveragePooling2D
from keras.layers import Dropout, Dense
from keras.applications import *
from keras.optimizers import SGD
from keras.callbacks import ModelCheckpoint
from keras import backend as k
from keras.models import Model
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Parámetros iniciales

# %%
# fix seed for reproducible results (only works on CPU, not GPU)
#seed = 9
#np.random.seed(seed=seed)
#tf.set_random_seed(seed=seed)

# parameters dependent on your dataset: modified to your example
nb_train_samples = 24+396  # Total number of train samples. NOT including augmented images
nb_validation_samples = 10+140  # Total number of train samples. NOT including augmented images.
img_width, img_height = 299, 299  # change based on the shape/structure of your images

# hyper parameters for model
based_model_last_block_layer_number = 172  # value is based on based model selected.
batch_size = 64#8  # try 4, 8, 16, 32, 64, 128, 256 dependent on CPU/GPU memory capacity (powers of 2 values).
nb_epoch = 100#100  # number of iteration the algorithm gets trained.
learn_rate = 1e-4  # sgd learning rate
momentum = .9  # sgd momentum to avoid local minimum

#Dataset
#data_dir = './data/DDSM Images'
data_dir = './data/DM-Ext Images'
train_dir = data_dir + '/train'  # change to your train path. Inside, each class should have it's own folder
validation_dir = data_dir + '/validation'  # validation path. Inside, each class should have it's own folder

# %% [markdown]
# ## Transfer Learning y Fine Tune

# %%
def train(train_data_dir, validation_data_dir):
    # Pre-Trained CNN Model using imagenet dataset for pre-trained weights
    base_model = InceptionV3(weights='imagenet', include_top=False)  # select from keras pre-built models library

    # Top Model Block
    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x = Dense(256, activation='relu')(x)
    x = Dropout(0.5)(x)
    predictions = Dense(1, activation='sigmoid')(x)  # softmax if multi-class classifiers
    #predictions = Dense(nb_classes, activation='softmax')(x) #new softmax layer

    # add your top layer block to your base model
    model = Model(base_model.input, predictions)

    # first: train only the top layers (which were randomly initialized)
    # i.e. freeze all convolution layers
    for layer in base_model.layers:
        layer.trainable = False

    # Read Data and Augment it: Make sure to select augmentations that are appropriate to your images.
    # To save augmentations un-comment save lines and add to your flow parameters.
    train_datagen = ImageDataGenerator(rescale=1. / 255,
                                       #rotation_range=10,
                                       shear_range=.1,
                                       zoom_range=.1,
                                       cval=.1,
                                       horizontal_flip=True)
                                       #vertical_flip=True)

    validation_datagen = ImageDataGenerator(rescale=1. / 255)

    train_generator = train_datagen.flow_from_directory(train_data_dir,
                                                        target_size=(img_height, img_width),
                                                        batch_size=batch_size,
                                                        class_mode='binary')
                                                        #save_to_dir=data_dir + '/preview',
                                                        #save_prefix='aug')#,
                                                        #save_format='jpeg')
    # use the above 3 commented lines if you want to save and look at how the data augmentations look like
    
    fig = plt.figure()
    fig.suptitle("Datos aumentados para entrenamiento", fontsize=14)
    x,y = train_generator.next()
    for i in range(0,4):
        image = x[i]
        #plt.imshow(image.transpose(2,1,0))
        #Plotea data aumentada
        ax1 = fig.add_subplot(2,2,i+1)
        ax1.imshow(image)
        #ax1.set_title("Clase %s"%y)
        #plt.show()
        #plt.imshow(image)
    
    plt.show()

    validation_generator = validation_datagen.flow_from_directory(validation_data_dir,
                                                            target_size=(img_height, img_width),
                                                            batch_size=batch_size,
                                                            class_mode='binary')
    fig = plt.figure()
    fig.suptitle("Datos para validación", fontsize=14)
    x,y = validation_generator.next()
    for i in range(0,4):
        image = x[i]
        #plt.imshow(image.transpose(2,1,0))
        #Plotea data aumentada
        ax1 = fig.add_subplot(2,2,i+1)
        ax1.imshow(image)
        #ax1.set_title("Clase %s"%y)
        #plt.show()
        #plt.imshow(image)
    
    plt.show()
    
    model.compile(optimizer='rmsprop',
                  loss='binary_crossentropy',  # categorical_crossentropy if multi-class classifier
                  metrics=['accuracy'])
    #  model.compile(optimizer=SGD(lr=0.0001, momentum=0.9), loss='categorical_crossentropy', metrics=['accuracy'])

    path_dir = data_dir.split('/')
    name_dir = path_dir[len(path_dir)-1]
    
    # save weights of best training epoch: monitor either val_loss or val_acc
    top_weights_path = 'model/top_model_weights'+name_dir+'.h5'
    checkpoint = ModelCheckpoint(top_weights_path, monitor='val_acc', verbose=1, save_best_only=True, mode='auto')
    callbacks_list = [checkpoint]

    print("\nStarting to Transfer Learning\n")
    # Train Simple CNN
    history_tl = model.fit_generator(train_generator,
                        samples_per_epoch=nb_train_samples,
                        nb_epoch=nb_epoch / 5,
                        validation_data=validation_generator,
                        nb_val_samples=nb_validation_samples,
                        callbacks=callbacks_list)

    # add the best weights from the train top model
    # at this point we have the pre-train weights of the base model and the trained weight of the new/added top model
    # we re-load model weights to ensure the best epoch is selected and not the last one.
    model.load_weights(top_weights_path)

    # verbose
    print("\nStarting to Fine Tune Model\n")

    # based_model_last_block_layer_number points to the layer in your model you want to train.
    # For example if you want to train the last block of a 19 layer VGG16 model this should be 15
    # If you want to train the last TWO blocks of an Inception model it should be 172
    # layers before this number will used the pre-trained weights, layers above and including this number
    # will be re-trained based on the new data.
    for layer in model.layers[:based_model_last_block_layer_number]:
        layer.trainable = False
    for layer in model.layers[based_model_last_block_layer_number:]:
        layer.trainable = True

    # compile the model with a SGD/momentum optimizer
    # and a very slow learning rate.
    model.compile(loss='binary_crossentropy',
                  optimizer=SGD(lr=learn_rate, momentum=momentum),
                  metrics=['accuracy'])

    # save weights of best training epoch: monitor either val_loss or val_acc
    
    final_weights_path = 'model/model_weights_'+name_dir+'.h5'
    checkpoint = ModelCheckpoint(final_weights_path, monitor='val_loss', verbose=1, save_best_only=True, mode='mode')
    callbacks_list = [checkpoint]

    # fine-tune the model
    history_ft = model.fit_generator(train_generator,
                        samples_per_epoch=nb_train_samples,
                        nb_epoch=nb_epoch,
                        validation_data=validation_generator,
                        nb_val_samples=nb_validation_samples,
                        callbacks=callbacks_list)
    
    # save model
    model_json = model.to_json()
    with open('model/model'+name_dir+'.json', 'w') as json_file:
        json_file.write(model_json)
        
    return history_tl, history_ft, model.layers


hist_tl, hist_ft, model_layers = train(train_dir, validation_dir)  # train model
# Out:
# Found 350 images belonging to 2 classes.
# Found 150 images belonging to 2 classes.
# Starting to Transfer Learning
#
# Epoch 1/20
# /home/grupoavatar/.local/lib/python3.5/site-packages/ipykernel_launcher.py:96: UserWarning: The semantics of the Keras 2 argument `steps_per_epoch` is not the same as the Keras 1 argument `samples_per_epoch`. `steps_per_epoch` is the number of batches to draw from the generator at each epoch. Basically steps_per_epoch = samples_per_epoch/batch_size. Similarly `nb_val_samples`->`validation_steps` and `val_samples`->`steps` arguments have changed. Update your method calls accordingly.
# /home/grupoavatar/.local/lib/python3.5/site-packages/ipykernel_launcher.py:96: UserWarning: Update your `fit_generator` call to the Keras 2 API: `fit_generator(<keras.pre..., validation_data=<keras.pre..., callbacks=[<keras.ca..., validation_steps=150, epochs=20.0, steps_per_epoch=6)`
# 5/6 [========================>.....] - ETA: 0s - loss: 0.6824 - acc: 0.9073Epoch 00001: val_acc improved from -inf to 0.93333, saving model to model/top_model_weightsDM-Ext Images.h5
# 6/6 [==============================] - 59s 10s/step - loss: 0.6592 - acc: 0.8870 - val_loss: 0.4180 - val_acc: 0.9333
# Epoch 2/20
# 5/6 [========================>.....] - ETA: 0s - loss: 0.2487 - acc: 0.9433Epoch 00002: val_acc did not improve
# 6/6 [==============================] - 51s 8s/step - loss: 0.2661 - acc: 0.9341 - val_loss: 0.2957 - val_acc: 0.9333
# Epoch 3/20
# 5/6 [========================>.....] - ETA: 0s - loss: 0.2737 - acc: 0.9308Epoch 00003: val_acc improved from 0.93333 to 0.93333, saving model to model/top_model_weightsDM-Ext Images.h5
# 6/6 [==============================] - 51s 9s/step - loss: 0.2574 - acc: 0.9341 - val_loss: 0.3057 - val_acc: 0.9333
# Epoch 4/20
# 5/6 [========================>.....] - ETA: 0s - loss: 0.2951 - acc: 0.9335Epoch 00004: val_acc did not improve
# 6/6 [==============================] - 51s 8s/step - loss: 0.2937 - acc: 0.9316 - val_loss: 0.2511 - val_acc: 0.9333
# Epoch 5/20
# 5/6 [========================>.....] - ETA: 0s - loss: 0.2294 - acc: 0.9371Epoch 00005: val_acc improved from 0.93333 to 0.93333, saving model to model/top_model_weightsDM-Ext Images.h5
# 6/6 [==============================] - 51s 9s/step - loss: 0.2970 - acc: 0.9288 - val_loss: 0.2487 - val_acc: 0.9333
# Epoch 6/20
# 5/6 [========================>.....] - ETA: 0s - loss: 0.2470 - acc: 0.9281Epoch 00006: val_acc did not improve
# 6/6 [==============================] - 51s 8s/step - loss: 0.2390 - acc: 0.9341 - val_loss: 0.3562 - val_acc: 0.9333
# Epoch 7/20
# 5/6 [========================>.....] - ETA: 0s - loss: 0.3328 - acc: 0.9175Epoch 00007: val_acc did not improve
# 6/6 [==============================] - 51s 9s/step - loss: 0.2949 - acc: 0.9290 - val_loss: 0.3612 - val_acc: 0.9333
# Epoch 8/20
# 5/6 [========================>.....] - ETA: 0s - loss: 0.2902 - acc: 0.9344Epoch 00008: val_acc improved from 0.93333 to 0.93347, saving model to model/top_model_weightsDM-Ext Images.h5
# 6/6 [==============================] - 51s 9s/step - loss: 0.3113 - acc: 0.9290 - val_loss: 0.2961 - val_acc: 0.9335
# Epoch 9/20
# 5/6 [========================>.....] - ETA: 0s - loss: 0.2644 - acc: 0.9313Epoch 00009: val_acc improved from 0.93347 to 0.93360, saving model to model/top_model_weightsDM-Ext Images.h5
# 6/6 [==============================] - 51s 9s/step - loss: 0.2594 - acc: 0.9314 - val_loss: 0.3209 - val_acc: 0.9336
# Epoch 10/20
# 5/6 [========================>.....] - ETA: 0s - loss: 0.2611 - acc: 0.9210Epoch 00010: val_acc did not improve
# 6/6 [==============================] - 51s 8s/step - loss: 0.2354 - acc: 0.9316 - val_loss: 0.3675 - val_acc: 0.9333
# Epoch 11/20
# 5/6 [========================>.....] - ETA: 0s - loss: 0.2320 - acc: 0.9344Epoch 00011: val_acc did not improve
# 6/6 [==============================] - 51s 8s/step - loss: 0.2487 - acc: 0.9239 - val_loss: 0.2687 - val_acc: 0.9332
# Epoch 12/20
# 5/6 [========================>.....] - ETA: 0s - loss: 0.3183 - acc: 0.9233Epoch 00012: val_acc did not improve
# 6/6 [==============================] - 51s 8s/step - loss: 0.3066 - acc: 0.9239 - val_loss: 0.2481 - val_acc: 0.9333
# Epoch 13/20
# 5/6 [========================>.....] - ETA: 0s - loss: 0.2721 - acc: 0.9281Epoch 00013: val_acc did not improve
# 6/6 [==============================] - 51s 8s/step - loss: 0.2598 - acc: 0.9289 - val_loss: 0.3155 - val_acc: 0.9333
# Epoch 14/20
# 5/6 [========================>.....] - ETA: 0s - loss: 0.1978 - acc: 0.9469Epoch 00014: val_acc did not improve
# 6/6 [==============================] - 51s 8s/step - loss: 0.2309 - acc: 0.9366 - val_loss: 0.2535 - val_acc: 0.9331
# Epoch 15/20
# 5/6 [========================>.....] - ETA: 0s - loss: 0.2918 - acc: 0.9281Epoch 00015: val_acc did not improve
# 6/6 [==============================] - 51s 8s/step - loss: 0.2827 - acc: 0.9393 - val_loss: 0.3281 - val_acc: 0.9333
# Epoch 16/20
# 5/6 [========================>.....] - ETA: 0s - loss: 0.2305 - acc: 0.9371Epoch 00016: val_acc did not improve
# 6/6 [==============================] - 51s 8s/step - loss: 0.2297 - acc: 0.9341 - val_loss: 0.2507 - val_acc: 0.9331
# Epoch 17/20
# 5/6 [========================>.....] - ETA: 0s - loss: 0.2516 - acc: 0.9340Epoch 00017: val_acc did not improve
# 6/6 [==============================] - 51s 8s/step - loss: 0.2462 - acc: 0.9341 - val_loss: 0.2587 - val_acc: 0.9328
# Epoch 18/20
# 5/6 [========================>.....] - ETA: 0s - loss: 0.1933 - acc: 0.9398Epoch 00018: val_acc did not improve
# 6/6 [==============================] - 51s 8s/step - loss: 0.2139 - acc: 0.9316 - val_loss: 0.2356 - val_acc: 0.9335
# Epoch 19/20
# 5/6 [========================>.....] - ETA: 0s - loss: 0.2377 - acc: 0.9406Epoch 00019: val_acc improved from 0.93360 to 0.93360, saving model to model/top_model_weightsDM-Ext Images.h5
# 6/6 [==============================] - 51s 9s/step - loss: 0.2416 - acc: 0.9366 - val_loss: 0.2395 - val_acc: 0.9336
# Epoch 20/20
# 5/6 [========================>.....] - ETA: 0s - loss: 0.2265 - acc: 0.9371Epoch 00020: val_acc did not improve
# 6/6 [==============================] - 51s 8s/step - loss: 0.2364 - acc: 0.9341 - val_loss: 0.2386 - val_acc: 0.9332
#
# Starting to Fine Tune Model
# /home/grupoavatar/.local/lib/python3.5/site-packages/keras/callbacks.py:375: RuntimeWarning: ModelCheckpoint mode mode is unknown, fallback to auto mode.
#   RuntimeWarning)
# /home/grupoavatar/.local/lib/python3.5/site-packages/ipykernel_launcher.py:134: UserWarning: The semantics of the Keras 2 argument `steps_per_epoch` is not the same as the Keras 1 argument `samples_per_epoch`. `steps_per_epoch` is the number of batches to draw from the generator at each epoch. Basically steps_per_epoch = samples_per_epoch/batch_size. Similarly `nb_val_samples`->`validation_steps` and `val_samples`->`steps` arguments have changed. Update your method calls accordingly.
# /home/grupoavatar/.local/lib/python3.5/site-packages/ipykernel_launcher.py:134: UserWarning: Update your `fit_generator` call to the Keras 2 API: `fit_generator(<keras.pre..., validation_data=<keras.pre..., callbacks=[<keras.ca..., validation_steps=150, epochs=100, steps_per_epoch=6)`
# Epoch 1/100
# 5/6 [========================>.....] - ETA: 1s - loss: 0.2088 - acc: 0.9402Epoch 00001: val_loss improved from inf to 0.24095, saving model to model/model_weights_DM-Ext Images.h5
# 6/6 [==============================] - 55s 9s/step - loss: 0.2108 - acc: 0.9341 - val_loss: 0.2409 - val_acc: 0.9333
# Epoch 2/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.2587 - acc: 0.9135Epoch 00002: val_loss did not improve
# 6/6 [==============================] - 52s 9s/step - loss: 0.2459 - acc: 0.9240 - val_loss: 0.2414 - val_acc: 0.9333
# Epoch 3/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.2676 - acc: 0.9135Epoch 00003: val_loss did not improve
# 6/6 [==============================] - 52s 9s/step - loss: 0.2510 - acc: 0.9240 - val_loss: 0.2413 - val_acc: 0.9336
# Epoch 4/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.1908 - acc: 0.9433Epoch 00004: val_loss did not improve
# 6/6 [==============================] - 52s 9s/step - loss: 0.2082 - acc: 0.9341 - val_loss: 0.2425 - val_acc: 0.9333
# Epoch 5/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.2287 - acc: 0.9269Epoch 00005: val_loss did not improve
# 6/6 [==============================] - 52s 9s/step - loss: 0.2211 - acc: 0.9290 - val_loss: 0.2426 - val_acc: 0.9335
# Epoch 6/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.2299 - acc: 0.9367Epoch 00006: val_loss did not improve
# 6/6 [==============================] - 52s 9s/step - loss: 0.2339 - acc: 0.9316 - val_loss: 0.2432 - val_acc: 0.9333
# Epoch 7/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.2211 - acc: 0.9313Epoch 00007: val_loss did not improve
# 6/6 [==============================] - 52s 9s/step - loss: 0.2139 - acc: 0.9316 - val_loss: 0.2441 - val_acc: 0.9328
# Epoch 8/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.2082 - acc: 0.9429Epoch 00008: val_loss did not improve
# 6/6 [==============================] - 52s 9s/step - loss: 0.2248 - acc: 0.9316 - val_loss: 0.2419 - val_acc: 0.9336
# Epoch 9/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.2042 - acc: 0.9371Epoch 00009: val_loss did not improve
# 6/6 [==============================] - 52s 9s/step - loss: 0.2001 - acc: 0.9341 - val_loss: 0.2428 - val_acc: 0.9333
# Epoch 10/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.2094 - acc: 0.9371Epoch 00010: val_loss did not improve
# 6/6 [==============================] - 52s 9s/step - loss: 0.2207 - acc: 0.9341 - val_loss: 0.2433 - val_acc: 0.9333
# Epoch 11/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.2265 - acc: 0.9296Epoch 00011: val_loss did not improve
# 6/6 [==============================] - 52s 9s/step - loss: 0.2286 - acc: 0.9265 - val_loss: 0.2460 - val_acc: 0.9325
# Epoch 12/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.2239 - acc: 0.9171Epoch 00012: val_loss did not improve
# 6/6 [==============================] - 52s 9s/step - loss: 0.2072 - acc: 0.9265 - val_loss: 0.2438 - val_acc: 0.9333
# Epoch 13/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.1801 - acc: 0.9429Epoch 00013: val_loss did not improve
# 6/6 [==============================] - 52s 9s/step - loss: 0.2086 - acc: 0.9316 - val_loss: 0.2439 - val_acc: 0.9333
# Epoch 14/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.2109 - acc: 0.9344Epoch 00014: val_loss did not improve
# 6/6 [==============================] - 52s 9s/step - loss: 0.2062 - acc: 0.9340 - val_loss: 0.2440 - val_acc: 0.9333
# Epoch 15/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.2097 - acc: 0.9371Epoch 00015: val_loss did not improve
# 6/6 [==============================] - 52s 9s/step - loss: 0.2144 - acc: 0.9341 - val_loss: 0.2442 - val_acc: 0.9333
# Epoch 16/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.2158 - acc: 0.9269Epoch 00016: val_loss did not improve
# 6/6 [==============================] - 52s 9s/step - loss: 0.2117 - acc: 0.9290 - val_loss: 0.2448 - val_acc: 0.9333
# Epoch 17/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.2109 - acc: 0.9362Epoch 00017: val_loss did not improve
# 6/6 [==============================] - 52s 9s/step - loss: 0.2143 - acc: 0.9290 - val_loss: 0.2452 - val_acc: 0.9335
# Epoch 18/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.2170 - acc: 0.9273Epoch 00018: val_loss did not improve
# 6/6 [==============================] - 52s 9s/step - loss: 0.2143 - acc: 0.9316 - val_loss: 0.2464 - val_acc: 0.9333
# Epoch 19/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.2206 - acc: 0.9281Epoch 00019: val_loss did not improve
# 6/6 [==============================] - 52s 9s/step - loss: 0.2106 - acc: 0.9341 - val_loss: 0.2471 - val_acc: 0.9335
# Epoch 20/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.2090 - acc: 0.9237Epoch 00020: val_loss did not improve
# 6/6 [==============================] - 52s 9s/step - loss: 0.2122 - acc: 0.9290 - val_loss: 0.2484 - val_acc: 0.9333
# Epoch 21/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.2561 - acc: 0.9198Epoch 00021: val_loss did not improve
# 6/6 [==============================] - 52s 9s/step - loss: 0.2475 - acc: 0.9240 - val_loss: 0.2488 - val_acc: 0.9333
# Epoch 22/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.2265 - acc: 0.9281Epoch 00022: val_loss did not improve
# 6/6 [==============================] - 52s 9s/step - loss: 0.2135 - acc: 0.9341 - val_loss: 0.2496 - val_acc: 0.9333
# Epoch 23/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.2054 - acc: 0.9398Epoch 00023: val_loss did not improve
# 6/6 [==============================] - 52s 9s/step - loss: 0.2197 - acc: 0.9316 - val_loss: 0.2499 - val_acc: 0.9332
# Epoch 24/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.2253 - acc: 0.9281Epoch 00024: val_loss did not improve
# 6/6 [==============================] - 52s 9s/step - loss: 0.2053 - acc: 0.9393 - val_loss: 0.2506 - val_acc: 0.9331
# Epoch 25/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.2196 - acc: 0.9269Epoch 00025: val_loss did not improve
# 6/6 [==============================] - 52s 9s/step - loss: 0.2100 - acc: 0.9290 - val_loss: 0.2503 - val_acc: 0.9333
# Epoch 26/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.2018 - acc: 0.9406Epoch 00026: val_loss did not improve
# 6/6 [==============================] - 52s 9s/step - loss: 0.2045 - acc: 0.9366 - val_loss: 0.2508 - val_acc: 0.9335
# Epoch 27/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.2596 - acc: 0.9304Epoch 00027: val_loss did not improve
# 6/6 [==============================] - 52s 9s/step - loss: 0.2496 - acc: 0.9316 - val_loss: 0.2517 - val_acc: 0.9333
# Epoch 28/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.2172 - acc: 0.9273Epoch 00028: val_loss did not improve
# 6/6 [==============================] - 52s 9s/step - loss: 0.2209 - acc: 0.9316 - val_loss: 0.2523 - val_acc: 0.9333
# Epoch 29/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.2126 - acc: 0.9300Epoch 00029: val_loss did not improve
# 6/6 [==============================] - 52s 9s/step - loss: 0.2126 - acc: 0.9290 - val_loss: 0.2527 - val_acc: 0.9333
# Epoch 30/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.1951 - acc: 0.9367Epoch 00030: val_loss did not improve
# 6/6 [==============================] - 52s 9s/step - loss: 0.2085 - acc: 0.9316 - val_loss: 0.2541 - val_acc: 0.9331
# Epoch 31/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.2044 - acc: 0.9265Epoch 00031: val_loss did not improve
# 6/6 [==============================] - 52s 9s/step - loss: 0.2045 - acc: 0.9265 - val_loss: 0.2541 - val_acc: 0.9333
# Epoch 32/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.2143 - acc: 0.9313Epoch 00032: val_loss did not improve
# 6/6 [==============================] - 52s 9s/step - loss: 0.2138 - acc: 0.9316 - val_loss: 0.2546 - val_acc: 0.9332
# Epoch 33/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.1945 - acc: 0.9402Epoch 00033: val_loss did not improve
# 6/6 [==============================] - 52s 9s/step - loss: 0.2064 - acc: 0.9367 - val_loss: 0.2542 - val_acc: 0.9333
# Epoch 34/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.2043 - acc: 0.9273Epoch 00034: val_loss did not improve
# 6/6 [==============================] - 52s 9s/step - loss: 0.1987 - acc: 0.9316 - val_loss: 0.2532 - val_acc: 0.9337
# Epoch 35/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.2299 - acc: 0.9242Epoch 00035: val_loss did not improve
# 6/6 [==============================] - 52s 9s/step - loss: 0.2147 - acc: 0.9316 - val_loss: 0.2565 - val_acc: 0.9327
# Epoch 36/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.2209 - acc: 0.9281Epoch 00036: val_loss did not improve
# 6/6 [==============================] - 52s 9s/step - loss: 0.2046 - acc: 0.9341 - val_loss: 0.2545 - val_acc: 0.9336
# Epoch 37/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.1983 - acc: 0.9375Epoch 00037: val_loss did not improve
# 6/6 [==============================] - 52s 9s/step - loss: 0.2019 - acc: 0.9366 - val_loss: 0.2557 - val_acc: 0.9333
# Epoch 38/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.2198 - acc: 0.9273Epoch 00038: val_loss did not improve
# 6/6 [==============================] - 52s 9s/step - loss: 0.2124 - acc: 0.9316 - val_loss: 0.2548 - val_acc: 0.9337
# Epoch 39/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.2433 - acc: 0.9206Epoch 00039: val_loss did not improve
# 6/6 [==============================] - 52s 9s/step - loss: 0.2259 - acc: 0.9290 - val_loss: 0.2567 - val_acc: 0.9333
# Epoch 40/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.1963 - acc: 0.9340Epoch 00040: val_loss did not improve
# 6/6 [==============================] - 52s 9s/step - loss: 0.1919 - acc: 0.9341 - val_loss: 0.2569 - val_acc: 0.9333
# Epoch 41/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.2153 - acc: 0.9269Epoch 00041: val_loss did not improve
# 6/6 [==============================] - 52s 9s/step - loss: 0.2144 - acc: 0.9290 - val_loss: 0.2576 - val_acc: 0.9332
# Epoch 42/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.2283 - acc: 0.9304Epoch 00042: val_loss did not improve
# 6/6 [==============================] - 52s 9s/step - loss: 0.2115 - acc: 0.9369 - val_loss: 0.2576 - val_acc: 0.9333
# Epoch 43/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.1962 - acc: 0.9340Epoch 00043: val_loss did not improve
# 6/6 [==============================] - 52s 9s/step - loss: 0.1920 - acc: 0.9341 - val_loss: 0.2587 - val_acc: 0.9332
# Epoch 44/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.1997 - acc: 0.9313Epoch 00044: val_loss did not improve
# 6/6 [==============================] - 52s 9s/step - loss: 0.2051 - acc: 0.9316 - val_loss: 0.2594 - val_acc: 0.9332
# Epoch 45/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.2044 - acc: 0.9281Epoch 00045: val_loss did not improve
# 6/6 [==============================] - 52s 9s/step - loss: 0.1973 - acc: 0.9341 - val_loss: 0.2595 - val_acc: 0.9333
# Epoch 46/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.2208 - acc: 0.9265Epoch 00046: val_loss did not improve
# 6/6 [==============================] - 52s 9s/step - loss: 0.2215 - acc: 0.9265 - val_loss: 0.2613 - val_acc: 0.9328
# Epoch 47/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.2050 - acc: 0.9269Epoch 00047: val_loss did not improve
# 6/6 [==============================] - 52s 9s/step - loss: 0.2040 - acc: 0.9264 - val_loss: 0.2595 - val_acc: 0.9335
# Epoch 48/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.1910 - acc: 0.9367Epoch 00048: val_loss did not improve
# 6/6 [==============================] - 52s 9s/step - loss: 0.2067 - acc: 0.9289 - val_loss: 0.2590 - val_acc: 0.9336
# Epoch 49/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.1971 - acc: 0.9313Epoch 00049: val_loss did not improve
# 6/6 [==============================] - 52s 9s/step - loss: 0.2064 - acc: 0.9316 - val_loss: 0.2583 - val_acc: 0.9335
# Epoch 50/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.2177 - acc: 0.9135Epoch 00050: val_loss did not improve
# 6/6 [==============================] - 52s 9s/step - loss: 0.2028 - acc: 0.9240 - val_loss: 0.2585 - val_acc: 0.9333
# Epoch 51/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.1967 - acc: 0.9304Epoch 00051: val_loss did not improve
# 6/6 [==============================] - 52s 9s/step - loss: 0.1913 - acc: 0.9316 - val_loss: 0.2578 - val_acc: 0.9333
# Epoch 52/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.1977 - acc: 0.9344Epoch 00052: val_loss did not improve
# 6/6 [==============================] - 52s 9s/step - loss: 0.2114 - acc: 0.9290 - val_loss: 0.2583 - val_acc: 0.9331
# Epoch 53/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.1959 - acc: 0.9362Epoch 00053: val_loss did not improve
# 6/6 [==============================] - 52s 9s/step - loss: 0.2117 - acc: 0.9290 - val_loss: 0.2569 - val_acc: 0.9335
# Epoch 54/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.1880 - acc: 0.9300Epoch 00054: val_loss did not improve
# 6/6 [==============================] - 52s 9s/step - loss: 0.1919 - acc: 0.9290 - val_loss: 0.2585 - val_acc: 0.9327
# Epoch 55/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.2026 - acc: 0.9281Epoch 00055: val_loss did not improve
# 6/6 [==============================] - 52s 9s/step - loss: 0.1857 - acc: 0.9341 - val_loss: 0.2562 - val_acc: 0.9333
# Epoch 56/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.2116 - acc: 0.9300Epoch 00056: val_loss did not improve
# 6/6 [==============================] - 52s 9s/step - loss: 0.2153 - acc: 0.9290 - val_loss: 0.2565 - val_acc: 0.9331
# Epoch 57/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.2059 - acc: 0.9300Epoch 00057: val_loss did not improve
# 6/6 [==============================] - 52s 9s/step - loss: 0.2052 - acc: 0.9290 - val_loss: 0.2544 - val_acc: 0.9336
# Epoch 58/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.1857 - acc: 0.9394Epoch 00058: val_loss did not improve
# 6/6 [==============================] - 52s 9s/step - loss: 0.2093 - acc: 0.9290 - val_loss: 0.2546 - val_acc: 0.9332
# Epoch 59/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.2106 - acc: 0.9313Epoch 00059: val_loss did not improve
# 6/6 [==============================] - 52s 9s/step - loss: 0.2043 - acc: 0.9316 - val_loss: 0.2531 - val_acc: 0.9336
# Epoch 60/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.2052 - acc: 0.9331Epoch 00060: val_loss did not improve
# 6/6 [==============================] - 52s 9s/step - loss: 0.2092 - acc: 0.9290 - val_loss: 0.2525 - val_acc: 0.9336
# Epoch 61/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.1886 - acc: 0.9371Epoch 00061: val_loss did not improve
# 6/6 [==============================] - 52s 9s/step - loss: 0.1887 - acc: 0.9341 - val_loss: 0.2525 - val_acc: 0.9333
# Epoch 62/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.1662 - acc: 0.9394Epoch 00062: val_loss did not improve
# 6/6 [==============================] - 52s 9s/step - loss: 0.1930 - acc: 0.9290 - val_loss: 0.2525 - val_acc: 0.9333
# Epoch 63/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.1886 - acc: 0.9308Epoch 00063: val_loss did not improve
# 6/6 [==============================] - 52s 9s/step - loss: 0.1819 - acc: 0.9341 - val_loss: 0.2522 - val_acc: 0.9333
# Epoch 64/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.2102 - acc: 0.9277Epoch 00064: val_loss did not improve
# 6/6 [==============================] - 52s 9s/step - loss: 0.1923 - acc: 0.9341 - val_loss: 0.2514 - val_acc: 0.9333
# Epoch 65/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.2045 - acc: 0.9277Epoch 00065: val_loss did not improve
# 6/6 [==============================] - 52s 9s/step - loss: 0.1941 - acc: 0.9341 - val_loss: 0.2510 - val_acc: 0.9333
# Epoch 66/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.2014 - acc: 0.9242Epoch 00066: val_loss did not improve
# 6/6 [==============================] - 52s 9s/step - loss: 0.1930 - acc: 0.9316 - val_loss: 0.2505 - val_acc: 0.9332
# Epoch 67/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.1737 - acc: 0.9469Epoch 00067: val_loss did not improve
# 6/6 [==============================] - 52s 9s/step - loss: 0.1812 - acc: 0.9393 - val_loss: 0.2495 - val_acc: 0.9333
# Epoch 68/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.2441 - acc: 0.9104Epoch 00068: val_loss did not improve
# 6/6 [==============================] - 52s 9s/step - loss: 0.2141 - acc: 0.9240 - val_loss: 0.2491 - val_acc: 0.9332
# Epoch 69/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.1927 - acc: 0.9304Epoch 00069: val_loss did not improve
# 6/6 [==============================] - 52s 9s/step - loss: 0.1878 - acc: 0.9342 - val_loss: 0.2480 - val_acc: 0.9333
# Epoch 70/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.2209 - acc: 0.9273Epoch 00070: val_loss did not improve
# 6/6 [==============================] - 52s 9s/step - loss: 0.2236 - acc: 0.9289 - val_loss: 0.2473 - val_acc: 0.9335
# Epoch 71/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.1535 - acc: 0.9429Epoch 00071: val_loss did not improve
# 6/6 [==============================] - 52s 9s/step - loss: 0.1778 - acc: 0.9316 - val_loss: 0.2471 - val_acc: 0.9333
# Epoch 72/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.1841 - acc: 0.9313Epoch 00072: val_loss did not improve
# 6/6 [==============================] - 52s 9s/step - loss: 0.1982 - acc: 0.9316 - val_loss: 0.2462 - val_acc: 0.9335
# Epoch 73/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.1835 - acc: 0.9375Epoch 00073: val_loss did not improve
# 6/6 [==============================] - 52s 9s/step - loss: 0.1992 - acc: 0.9265 - val_loss: 0.2459 - val_acc: 0.9333
# Epoch 74/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.1838 - acc: 0.9335Epoch 00074: val_loss did not improve
# 6/6 [==============================] - 52s 9s/step - loss: 0.1817 - acc: 0.9342 - val_loss: 0.2461 - val_acc: 0.9331
# Epoch 75/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.2040 - acc: 0.9246Epoch 00075: val_loss did not improve
# 6/6 [==============================] - 52s 9s/step - loss: 0.1855 - acc: 0.9341 - val_loss: 0.2456 - val_acc: 0.9331
# Epoch 76/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.1924 - acc: 0.9296Epoch 00076: val_loss did not improve
# 6/6 [==============================] - 52s 9s/step - loss: 0.1974 - acc: 0.9292 - val_loss: 0.2443 - val_acc: 0.9335
# Epoch 77/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.2074 - acc: 0.9269Epoch 00077: val_loss did not improve
# 6/6 [==============================] - 52s 9s/step - loss: 0.1975 - acc: 0.9317 - val_loss: 0.2447 - val_acc: 0.9333
# Epoch 78/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.2017 - acc: 0.9269Epoch 00078: val_loss did not improve
# 6/6 [==============================] - 52s 9s/step - loss: 0.1908 - acc: 0.9317 - val_loss: 0.2449 - val_acc: 0.9333
# Epoch 79/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.1888 - acc: 0.9273Epoch 00079: val_loss did not improve
# 6/6 [==============================] - 52s 9s/step - loss: 0.1788 - acc: 0.9316 - val_loss: 0.2450 - val_acc: 0.9333
# Epoch 80/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.1631 - acc: 0.9465Epoch 00080: val_loss did not improve
# 6/6 [==============================] - 52s 9s/step - loss: 0.1871 - acc: 0.9341 - val_loss: 0.2447 - val_acc: 0.9335
# Epoch 81/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.2027 - acc: 0.9242Epoch 00081: val_loss did not improve
# 6/6 [==============================] - 52s 9s/step - loss: 0.1967 - acc: 0.9289 - val_loss: 0.2452 - val_acc: 0.9333
# Epoch 82/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.2037 - acc: 0.9308Epoch 00082: val_loss did not improve
# 6/6 [==============================] - 52s 9s/step - loss: 0.1921 - acc: 0.9367 - val_loss: 0.2458 - val_acc: 0.9332
# Epoch 83/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.1674 - acc: 0.9394Epoch 00083: val_loss did not improve
# 6/6 [==============================] - 52s 9s/step - loss: 0.1777 - acc: 0.9317 - val_loss: 0.2465 - val_acc: 0.9332
# Epoch 84/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.1700 - acc: 0.9340Epoch 00084: val_loss did not improve
# 6/6 [==============================] - 52s 9s/step - loss: 0.1698 - acc: 0.9341 - val_loss: 0.2459 - val_acc: 0.9335
# Epoch 85/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.1764 - acc: 0.9406Epoch 00085: val_loss did not improve
# 6/6 [==============================] - 52s 9s/step - loss: 0.1965 - acc: 0.9292 - val_loss: 0.2456 - val_acc: 0.9336
# Epoch 86/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.2063 - acc: 0.9304Epoch 00086: val_loss did not improve
# 6/6 [==============================] - 52s 9s/step - loss: 0.1943 - acc: 0.9316 - val_loss: 0.2471 - val_acc: 0.9331
# Epoch 87/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.1847 - acc: 0.9331Epoch 00087: val_loss did not improve
# 6/6 [==============================] - 52s 9s/step - loss: 0.1942 - acc: 0.9264 - val_loss: 0.2463 - val_acc: 0.9333
# Epoch 88/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.2047 - acc: 0.9229Epoch 00088: val_loss did not improve
# 6/6 [==============================] - 52s 9s/step - loss: 0.2014 - acc: 0.9266 - val_loss: 0.2462 - val_acc: 0.9333
# Epoch 89/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.1379 - acc: 0.9558Epoch 00089: val_loss did not improve
# 6/6 [==============================] - 52s 9s/step - loss: 0.1745 - acc: 0.9367 - val_loss: 0.2462 - val_acc: 0.9335
# Epoch 90/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.1988 - acc: 0.9327Epoch 00090: val_loss did not improve
# 6/6 [==============================] - 52s 9s/step - loss: 0.2044 - acc: 0.9292 - val_loss: 0.2477 - val_acc: 0.9331
# Epoch 91/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.1667 - acc: 0.9465Epoch 00091: val_loss did not improve
# 6/6 [==============================] - 52s 9s/step - loss: 0.1825 - acc: 0.9367 - val_loss: 0.2474 - val_acc: 0.9333
# Epoch 92/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.1832 - acc: 0.9340Epoch 00092: val_loss did not improve
# 6/6 [==============================] - 52s 9s/step - loss: 0.1817 - acc: 0.9341 - val_loss: 0.2477 - val_acc: 0.9332
# Epoch 93/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.1795 - acc: 0.9429Epoch 00093: val_loss did not improve
# 6/6 [==============================] - 52s 9s/step - loss: 0.1979 - acc: 0.9342 - val_loss: 0.2476 - val_acc: 0.9331
# Epoch 94/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.1841 - acc: 0.9206Epoch 00094: val_loss did not improve
# 6/6 [==============================] - 52s 9s/step - loss: 0.1760 - acc: 0.9290 - val_loss: 0.2470 - val_acc: 0.9333
# Epoch 95/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.1925 - acc: 0.9242Epoch 00095: val_loss did not improve
# 6/6 [==============================] - 52s 9s/step - loss: 0.1845 - acc: 0.9289 - val_loss: 0.2473 - val_acc: 0.9333
# Epoch 96/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.1971 - acc: 0.9194Epoch 00096: val_loss did not improve
# 6/6 [==============================] - 52s 9s/step - loss: 0.1992 - acc: 0.9215 - val_loss: 0.2476 - val_acc: 0.9333
# Epoch 97/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.1979 - acc: 0.9394Epoch 00097: val_loss did not improve
# 6/6 [==============================] - 52s 9s/step - loss: 0.2112 - acc: 0.9343 - val_loss: 0.2481 - val_acc: 0.9333
# Epoch 98/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.1584 - acc: 0.9375Epoch 00098: val_loss did not improve
# 6/6 [==============================] - 52s 9s/step - loss: 0.1606 - acc: 0.9366 - val_loss: 0.2479 - val_acc: 0.9335
# Epoch 99/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.1656 - acc: 0.9304Epoch 00099: val_loss did not improve
# 6/6 [==============================] - 52s 9s/step - loss: 0.1759 - acc: 0.9316 - val_loss: 0.2488 - val_acc: 0.9333
# Epoch 100/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.2072 - acc: 0.9202Epoch 00100: val_loss did not improve
# 6/6 [==============================] - 52s 9s/step - loss: 0.1987 - acc: 0.9265 - val_loss: 0.2490 - val_acc: 0.9333

# %% [markdown]
# ## Modelo Inception V3

# %%
# let's visualize layer names and layer indices to see how many layers
# we should freeze: this is used to define based_model_last_block_layer_number
for i, layer in enumerate(model_layers):  # comment these two lines once the correct based_model_last_block_layer
    print(i, layer.name)  # has been selected
# Out:
# 0 input_1
# 1 conv2d_1
# 2 batch_normalization_1
# 3 activation_1
# 4 conv2d_2
# 5 batch_normalization_2
# 6 activation_2
# 7 conv2d_3
# 8 batch_normalization_3
# 9 activation_3
# 10 max_pooling2d_1
# 11 conv2d_4
# 12 batch_normalization_4
# 13 activation_4
# 14 conv2d_5
# 15 batch_normalization_5
# 16 activation_5
# 17 max_pooling2d_2
# 18 conv2d_9
# 19 batch_normalization_9
# 20 activation_9
# 21 conv2d_7
# 22 conv2d_10
# 23 batch_normalization_7
# 24 batch_normalization_10
# 25 activation_7
# 26 activation_10
# 27 average_pooling2d_1
# 28 conv2d_6
# 29 conv2d_8
# 30 conv2d_11
# 31 conv2d_12
# 32 batch_normalization_6
# 33 batch_normalization_8
# 34 batch_normalization_11
# 35 batch_normalization_12
# 36 activation_6
# 37 activation_8
# 38 activation_11
# 39 activation_12
# 40 mixed0
# 41 conv2d_16
# 42 batch_normalization_16
# 43 activation_16
# 44 conv2d_14
# 45 conv2d_17
# 46 batch_normalization_14
# 47 batch_normalization_17
# 48 activation_14
# 49 activation_17
# 50 average_pooling2d_2
# 51 conv2d_13
# 52 conv2d_15
# 53 conv2d_18
# 54 conv2d_19
# 55 batch_normalization_13
# 56 batch_normalization_15
# 57 batch_normalization_18
# 58 batch_normalization_19
# 59 activation_13
# 60 activation_15
# 61 activation_18
# 62 activation_19
# 63 mixed1
# 64 conv2d_23
# 65 batch_normalization_23
# 66 activation_23
# 67 conv2d_21
# 68 conv2d_24
# 69 batch_normalization_21
# 70 batch_normalization_24
# 71 activation_21
# 72 activation_24
# 73 average_pooling2d_3
# 74 conv2d_20
# 75 conv2d_22
# 76 conv2d_25
# 77 conv2d_26
# 78 batch_normalization_20
# 79 batch_normalization_22
# 80 batch_normalization_25
# 81 batch_normalization_26
# 82 activation_20
# 83 activation_22
# 84 activation_25
# 85 activation_26
# 86 mixed2
# 87 conv2d_28
# 88 batch_normalization_28
# 89 activation_28
# 90 conv2d_29
# 91 batch_normalization_29
# 92 activation_29
# 93 conv2d_27
# 94 conv2d_30
# 95 batch_normalization_27
# 96 batch_normalization_30
# 97 activation_27
# 98 activation_30
# 99 max_pooling2d_3
# 100 mixed3
# 101 conv2d_35
# 102 batch_normalization_35
# 103 activation_35
# 104 conv2d_36
# 105 batch_normalization_36
# 106 activation_36
# 107 conv2d_32
# 108 conv2d_37
# 109 batch_normalization_32
# 110 batch_normalization_37
# 111 activation_32
# 112 activation_37
# 113 conv2d_33
# 114 conv2d_38
# 115 batch_normalization_33
# 116 batch_normalization_38
# 117 activation_33
# 118 activation_38
# 119 average_pooling2d_4
# 120 conv2d_31
# 121 conv2d_34
# 122 conv2d_39
# 123 conv2d_40
# 124 batch_normalization_31
# 125 batch_normalization_34
# 126 batch_normalization_39
# 127 batch_normalization_40
# 128 activation_31
# 129 activation_34
# 130 activation_39
# 131 activation_40
# 132 mixed4
# 133 conv2d_45
# 134 batch_normalization_45
# 135 activation_45
# 136 conv2d_46
# 137 batch_normalization_46
# 138 activation_46
# 139 conv2d_42
# 140 conv2d_47
# 141 batch_normalization_42
# 142 batch_normalization_47
# 143 activation_42
# 144 activation_47
# 145 conv2d_43
# 146 conv2d_48
# 147 batch_normalization_43
# 148 batch_normalization_48
# 149 activation_43
# 150 activation_48
# 151 average_pooling2d_5
# 152 conv2d_41
# 153 conv2d_44
# 154 conv2d_49
# 155 conv2d_50
# 156 batch_normalization_41
# 157 batch_normalization_44
# 158 batch_normalization_49
# 159 batch_normalization_50
# 160 activation_41
# 161 activation_44
# 162 activation_49
# 163 activation_50
# 164 mixed5
# 165 conv2d_55
# 166 batch_normalization_55
# 167 activation_55
# 168 conv2d_56
# 169 batch_normalization_56
# 170 activation_56
# 171 conv2d_52
# 172 conv2d_57
# 173 batch_normalization_52
# 174 batch_normalization_57
# 175 activation_52
# 176 activation_57
# 177 conv2d_53
# 178 conv2d_58
# 179 batch_normalization_53
# 180 batch_normalization_58
# 181 activation_53
# 182 activation_58
# 183 average_pooling2d_6
# 184 conv2d_51
# 185 conv2d_54
# 186 conv2d_59
# 187 conv2d_60
# 188 batch_normalization_51
# 189 batch_normalization_54
# 190 batch_normalization_59
# 191 batch_normalization_60
# 192 activation_51
# 193 activation_54
# 194 activation_59
# 195 activation_60
# 196 mixed6
# 197 conv2d_65
# 198 batch_normalization_65
# 199 activation_65
# 200 conv2d_66
# 201 batch_normalization_66
# 202 activation_66
# 203 conv2d_62
# 204 conv2d_67
# 205 batch_normalization_62
# 206 batch_normalization_67
# 207 activation_62
# 208 activation_67
# 209 conv2d_63
# 210 conv2d_68
# 211 batch_normalization_63
# 212 batch_normalization_68
# 213 activation_63
# 214 activation_68
# 215 average_pooling2d_7
# 216 conv2d_61
# 217 conv2d_64
# 218 conv2d_69
# 219 conv2d_70
# 220 batch_normalization_61
# 221 batch_normalization_64
# 222 batch_normalization_69
# 223 batch_normalization_70
# 224 activation_61
# 225 activation_64
# 226 activation_69
# 227 activation_70
# 228 mixed7
# 229 conv2d_73
# 230 batch_normalization_73
# 231 activation_73
# 232 conv2d_74
# 233 batch_normalization_74
# 234 activation_74
# 235 conv2d_71
# 236 conv2d_75
# 237 batch_normalization_71
# 238 batch_normalization_75
# 239 activation_71
# 240 activation_75
# 241 conv2d_72
# 242 conv2d_76
# 243 batch_normalization_72
# 244 batch_normalization_76
# 245 activation_72
# 246 activation_76
# 247 max_pooling2d_4
# 248 mixed8
# 249 conv2d_81
# 250 batch_normalization_81
# 251 activation_81
# 252 conv2d_78
# 253 conv2d_82
# 254 batch_normalization_78
# 255 batch_normalization_82
# 256 activation_78
# 257 activation_82
# 258 conv2d_79
# 259 conv2d_80
# 260 conv2d_83
# 261 conv2d_84
# 262 average_pooling2d_8
# 263 conv2d_77
# 264 batch_normalization_79
# 265 batch_normalization_80
# 266 batch_normalization_83
# 267 batch_normalization_84
# 268 conv2d_85
# 269 batch_normalization_77
# 270 activation_79
# 271 activation_80
# 272 activation_83
# 273 activation_84
# 274 batch_normalization_85
# 275 activation_77
# 276 mixed9_0
# 277 concatenate_1
# 278 activation_85
# 279 mixed9
# 280 conv2d_90
# 281 batch_normalization_90
# 282 activation_90
# 283 conv2d_87
# 284 conv2d_91
# 285 batch_normalization_87
# 286 batch_normalization_91
# 287 activation_87
# 288 activation_91
# 289 conv2d_88
# 290 conv2d_89
# 291 conv2d_92
# 292 conv2d_93
# 293 average_pooling2d_9
# 294 conv2d_86
# 295 batch_normalization_88
# 296 batch_normalization_89
# 297 batch_normalization_92
# 298 batch_normalization_93
# 299 conv2d_94
# 300 batch_normalization_86
# 301 activation_88
# 302 activation_89
# 303 activation_92
# 304 activation_93
# 305 batch_normalization_94
# 306 activation_86
# 307 mixed9_1
# 308 concatenate_2
# 309 activation_94
# 310 mixed10
# 311 global_average_pooling2d_1
# 312 dense_1
# 313 dropout_1
# 314 dense_2

# %% [markdown]
# ## Resultados
#
# ### Transfer Learning

# %%
def plot_training2(history):
    #% matplotlib inline

    df = pd.DataFrame(history.history)
    # display(df)

    plot = df.plot(y=['loss', 'val_loss'], figsize=(8, 4), title='Training and validation loss', legend=True)
    plot.set_xlabel('Epochs')
    plot.set_ylabel('Loss binary_crossentropy')    
    fig = plot.get_figure()
    fig.savefig('loss_graph_t_cancer_t:'+str(nb_train_samples)+'smp_v:'+str(nb_validation_samples)+'smp_'+str(nb_epoch)+'epc.png')

    plot = df.plot(y=['acc', 'val_acc'], figsize=(8, 4), title='Training and validation accuracy', legend=True)
    plot.set_xlabel('Epochs')
    plot.set_ylabel('Accuracy')
    fig = plot.get_figure()
    fig.savefig('acc_graph_t_cancer_t:'+str(nb_train_samples)+'smp_v:'+str(nb_validation_samples)+'smp_'+str(nb_epoch)+'epc.png')
    
    plt.show()

#Transfer Learning    
plot_training2(hist_tl)
# Out:
# /home/grupoavatar/.local/lib/python3.5/site-packages/pandas/plotting/_core.py:1714: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   series.name = label
# /home/grupoavatar/.local/lib/python3.5/site-packages/pandas/plotting/_core.py:1714: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   series.name = label

# %% [markdown]
# ## Resultados
#
# ### Fine Tune

# %%
#Finetune
plot_training2(hist_ft)
# Out:
# /home/grupoavatar/.local/lib/python3.5/site-packages/pandas/plotting/_core.py:1714: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   series.name = label

# %% [markdown]
# ## Cierre

# %%
# release memory
k.clear_session()
