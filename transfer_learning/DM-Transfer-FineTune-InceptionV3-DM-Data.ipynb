# %% [markdown]
# # Clasificación de mamografías usando Transfer learning y Fine Tune con InceptionV3

# %% [markdown]
# ## Importación de librerías

# %%
import sys
import numpy as np
import tensorflow as tf
#import matplotlib.pyplot as plt
# Generacion del grafico de metricas de Perdidas y Accuracy
import pandas as pd
import matplotlib.pyplot as plt
#ML
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import GlobalAveragePooling2D
from keras.layers import Dropout, Dense
from keras.applications import *
from keras.optimizers import SGD
from keras.callbacks import ModelCheckpoint
from keras import backend as k
from keras.models import Model
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Parámetros iniciales

# %%
# fix seed for reproducible results (only works on CPU, not GPU)
#seed = 9
#np.random.seed(seed=seed)
#tf.set_random_seed(seed=seed)

# parameters dependent on your dataset: modified to your example
nb_train_samples = 690  # Total number of train samples. NOT including augmented images
nb_validation_samples = 346  # Total number of train samples. NOT including augmented images.
img_width, img_height = 299, 299  # change based on the shape/structure of your images

# hyper parameters for model
based_model_last_block_layer_number = 172  # value is based on based model selected.
batch_size = 64#8  # try 4, 8, 16, 32, 64, 128, 256 dependent on CPU/GPU memory capacity (powers of 2 values).
nb_epoch = 100#100  # number of iteration the algorithm gets trained.
learn_rate = 1e-4  # sgd learning rate
momentum = .9  # sgd momentum to avoid local minimum

#Dataset
#data_dir = './data/DDSM Images'
data_dir = './data/DM images'
train_dir = data_dir + '/train'  # change to your train path. Inside, each class should have it's own folder
validation_dir = data_dir + '/validation'  # validation path. Inside, each class should have it's own folder

# %% [markdown]
# ## Transfer Learning y Fine Tune

# %%
def train(train_data_dir, validation_data_dir):
    # Pre-Trained CNN Model using imagenet dataset for pre-trained weights
    base_model = InceptionV3(weights='imagenet', include_top=False)  # select from keras pre-built models library

    # Top Model Block
    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x = Dense(256, activation='relu')(x)
    x = Dropout(0.5)(x)
    predictions = Dense(1, activation='sigmoid')(x)  # softmax if multi-class classifiers
    #predictions = Dense(nb_classes, activation='softmax')(x) #new softmax layer

    # add your top layer block to your base model
    model = Model(base_model.input, predictions)

    # first: train only the top layers (which were randomly initialized)
    # i.e. freeze all convolution layers
    for layer in base_model.layers:
        layer.trainable = False

    # Read Data and Augment it: Make sure to select augmentations that are appropriate to your images.
    # To save augmentations un-comment save lines and add to your flow parameters.
    train_datagen = ImageDataGenerator(rescale=1. / 255,
                                       #rotation_range=10,
                                       shear_range=.1,
                                       zoom_range=.1,
                                       cval=.1,
                                       horizontal_flip=True)
                                       #vertical_flip=True)

    validation_datagen = ImageDataGenerator(rescale=1. / 255)

    train_generator = train_datagen.flow_from_directory(train_data_dir,
                                                        target_size=(img_height, img_width),
                                                        batch_size=batch_size,
                                                        class_mode='binary')
                                                        #save_to_dir=data_dir + '/preview',
                                                        #save_prefix='aug')#,
                                                        #save_format='jpeg')
    # use the above 3 commented lines if you want to save and look at how the data augmentations look like
    
    fig = plt.figure()
    fig.suptitle("Datos aumentados para entrenamiento", fontsize=14)
    x,y = train_generator.next()
    for i in range(0,4):
        image = x[i]
        #plt.imshow(image.transpose(2,1,0))
        #Plotea data aumentada
        ax1 = fig.add_subplot(2,2,i+1)
        ax1.imshow(image)
        #ax1.set_title("Clase %s"%y)
        #plt.show()
        #plt.imshow(image)
    
    plt.show()

    validation_generator = validation_datagen.flow_from_directory(validation_data_dir,
                                                            target_size=(img_height, img_width),
                                                            batch_size=batch_size,
                                                            class_mode='binary')
    fig = plt.figure()
    fig.suptitle("Datos para validación", fontsize=14)
    x,y = validation_generator.next()
    for i in range(0,4):
        image = x[i]
        #plt.imshow(image.transpose(2,1,0))
        #Plotea data aumentada
        ax1 = fig.add_subplot(2,2,i+1)
        ax1.imshow(image)
        #ax1.set_title("Clase %s"%y)
        #plt.show()
        #plt.imshow(image)
    
    plt.show()
    
    model.compile(optimizer='rmsprop',
                  loss='binary_crossentropy',  # categorical_crossentropy if multi-class classifier
                  metrics=['accuracy'])
    #  model.compile(optimizer=SGD(lr=0.0001, momentum=0.9), loss='categorical_crossentropy', metrics=['accuracy'])

    # save weights of best training epoch: monitor either val_loss or val_acc
    top_weights_path = 'model/top_model_weights.h5'
    checkpoint = ModelCheckpoint(top_weights_path, monitor='val_acc', verbose=1, save_best_only=True, mode='auto')
    callbacks_list = [checkpoint]

    # Train Simple CNN
    history_tl = model.fit_generator(train_generator,
                        samples_per_epoch=nb_train_samples,
                        nb_epoch=nb_epoch / 5,
                        validation_data=validation_generator,
                        nb_val_samples=nb_validation_samples,
                        callbacks=callbacks_list)

    # add the best weights from the train top model
    # at this point we have the pre-train weights of the base model and the trained weight of the new/added top model
    # we re-load model weights to ensure the best epoch is selected and not the last one.
    model.load_weights(top_weights_path)

    # verbose
    print("\nStarting to Fine Tune Model\n")

    # based_model_last_block_layer_number points to the layer in your model you want to train.
    # For example if you want to train the last block of a 19 layer VGG16 model this should be 15
    # If you want to train the last TWO blocks of an Inception model it should be 172
    # layers before this number will used the pre-trained weights, layers above and including this number
    # will be re-trained based on the new data.
    for layer in model.layers[:based_model_last_block_layer_number]:
        layer.trainable = False
    for layer in model.layers[based_model_last_block_layer_number:]:
        layer.trainable = True

    # compile the model with a SGD/momentum optimizer
    # and a very slow learning rate.
    model.compile(loss='binary_crossentropy',
                  optimizer=SGD(lr=learn_rate, momentum=momentum),
                  metrics=['accuracy'])

    # save weights of best training epoch: monitor either val_loss or val_acc
    path_dir = data_dir.split('/')
    name_dir = path_dir[len(path_dir)-1]
    final_weights_path = 'model/model_weights_'+name_dir+'.h5'
    checkpoint = ModelCheckpoint(final_weights_path, monitor='val_loss', verbose=1, save_best_only=True, mode='mode')
    callbacks_list = [checkpoint]

    # fine-tune the model
    history_ft = model.fit_generator(train_generator,
                        samples_per_epoch=nb_train_samples,
                        nb_epoch=nb_epoch,
                        validation_data=validation_generator,
                        nb_val_samples=nb_validation_samples,
                        callbacks=callbacks_list)
    
    # save model
    model_json = model.to_json()
    with open('model/model'+name_dir+'.json', 'w') as json_file:
        json_file.write(model_json)
        
    return history_tl, history_ft, model.layers


hist_tl, hist_ft, model_layers = train(train_dir, validation_dir)  # train model
# Out:
# Found 80 images belonging to 2 classes.
# Found 56 images belonging to 2 classes.
# /home/grupoavatar/.local/lib/python3.5/site-packages/ipykernel_launcher.py:92: UserWarning: The semantics of the Keras 2 argument `steps_per_epoch` is not the same as the Keras 1 argument `samples_per_epoch`. `steps_per_epoch` is the number of batches to draw from the generator at each epoch. Basically steps_per_epoch = samples_per_epoch/batch_size. Similarly `nb_val_samples`->`validation_steps` and `val_samples`->`steps` arguments have changed. Update your method calls accordingly.
# /home/grupoavatar/.local/lib/python3.5/site-packages/ipykernel_launcher.py:92: UserWarning: Update your `fit_generator` call to the Keras 2 API: `fit_generator(<keras.pre..., validation_data=<keras.pre..., validation_steps=346, steps_per_epoch=10, epochs=20.0, callbacks=[<keras.ca...)`
# Epoch 1/20
#  9/10 [==========================>...] - ETA: 0s - loss: 1.3578 - acc: 0.6476Epoch 00001: val_acc improved from -inf to 0.75000, saving model to model/top_model_weights.h5
# 10/10 [==============================] - 136s 14s/step - loss: 1.3285 - acc: 0.6578 - val_loss: 0.7506 - val_acc: 0.7500
# Epoch 2/20
#  9/10 [==========================>...] - ETA: 0s - loss: 0.8338 - acc: 0.6337Epoch 00002: val_acc did not improve
# 10/10 [==============================] - 127s 13s/step - loss: 0.8258 - acc: 0.6420 - val_loss: 0.6575 - val_acc: 0.7321
# Epoch 3/20
#  9/10 [==========================>...] - ETA: 0s - loss: 0.5904 - acc: 0.7274Epoch 00003: val_acc did not improve
# 10/10 [==============================] - 127s 13s/step - loss: 0.6010 - acc: 0.7049 - val_loss: 1.2337 - val_acc: 0.7500
# Epoch 4/20
#  9/10 [==========================>...] - ETA: 0s - loss: 0.5864 - acc: 0.7240Epoch 00004: val_acc did not improve
# 10/10 [==============================] - 127s 13s/step - loss: 0.6383 - acc: 0.7176 - val_loss: 0.8309 - val_acc: 0.3393
# Epoch 5/20
#  9/10 [==========================>...] - ETA: 0s - loss: 0.6155 - acc: 0.7135Epoch 00005: val_acc did not improve
# 10/10 [==============================] - 127s 13s/step - loss: 0.6017 - acc: 0.7201 - val_loss: 0.6355 - val_acc: 0.7143
# Epoch 6/20
#  9/10 [==========================>...] - ETA: 0s - loss: 0.5463 - acc: 0.7535Epoch 00006: val_acc did not improve
# 10/10 [==============================] - 127s 13s/step - loss: 0.5416 - acc: 0.7566 - val_loss: 0.6127 - val_acc: 0.7143
# Epoch 7/20
#  9/10 [==========================>...] - ETA: 0s - loss: 0.5091 - acc: 0.7691Epoch 00007: val_acc did not improve
# 10/10 [==============================] - 127s 13s/step - loss: 0.5035 - acc: 0.7720 - val_loss: 0.6283 - val_acc: 0.7500
# Epoch 8/20
#  9/10 [==========================>...] - ETA: 0s - loss: 0.4199 - acc: 0.8212Epoch 00008: val_acc did not improve
# 10/10 [==============================] - 127s 13s/step - loss: 0.4517 - acc: 0.8151 - val_loss: 0.7032 - val_acc: 0.5893
# Epoch 9/20
#  9/10 [==========================>...] - ETA: 0s - loss: 0.5706 - acc: 0.7205Epoch 00009: val_acc did not improve
# 10/10 [==============================] - 127s 13s/step - loss: 0.5603 - acc: 0.7268 - val_loss: 0.6952 - val_acc: 0.5893
# Epoch 10/20
#  9/10 [==========================>...] - ETA: 0s - loss: 0.4442 - acc: 0.8056Epoch 00010: val_acc did not improve
# 10/10 [==============================] - 127s 13s/step - loss: 0.4508 - acc: 0.8010 - val_loss: 0.6697 - val_acc: 0.6429
# Epoch 11/20
#  9/10 [==========================>...] - ETA: 0s - loss: 0.4879 - acc: 0.8090Epoch 00011: val_acc did not improve
# 10/10 [==============================] - 127s 13s/step - loss: 0.4858 - acc: 0.8085 - val_loss: 1.0576 - val_acc: 0.7500
# Epoch 12/20
#  9/10 [==========================>...] - ETA: 0s - loss: 0.4705 - acc: 0.8073Epoch 00012: val_acc did not improve
# 10/10 [==============================] - 127s 13s/step - loss: 0.4791 - acc: 0.7898 - val_loss: 0.7826 - val_acc: 0.5179
# Epoch 13/20
#  9/10 [==========================>...] - ETA: 0s - loss: 0.4811 - acc: 0.7917Epoch 00013: val_acc did not improve
# 10/10 [==============================] - 127s 13s/step - loss: 0.4609 - acc: 0.8039 - val_loss: 0.9644 - val_acc: 0.7500
# Epoch 14/20
#  9/10 [==========================>...] - ETA: 0s - loss: 0.4563 - acc: 0.8073Epoch 00014: val_acc did not improve
# 10/10 [==============================] - 127s 13s/step - loss: 0.4463 - acc: 0.8069 - val_loss: 0.6781 - val_acc: 0.6786
# Epoch 15/20
#  9/10 [==========================>...] - ETA: 0s - loss: 0.5028 - acc: 0.8038Epoch 00015: val_acc did not improve
# 10/10 [==============================] - 127s 13s/step - loss: 0.5022 - acc: 0.7924 - val_loss: 0.7209 - val_acc: 0.6250
# Epoch 16/20
#  9/10 [==========================>...] - ETA: 0s - loss: 0.3961 - acc: 0.8264Epoch 00016: val_acc did not improve
# 10/10 [==============================] - 127s 13s/step - loss: 0.4030 - acc: 0.8210 - val_loss: 0.8190 - val_acc: 0.7321
# Epoch 17/20
#  9/10 [==========================>...] - ETA: 0s - loss: 0.4356 - acc: 0.7882Epoch 00017: val_acc did not improve
# 10/10 [==============================] - 127s 13s/step - loss: 0.4329 - acc: 0.7908 - val_loss: 0.7596 - val_acc: 0.6429
# Epoch 18/20
#  9/10 [==========================>...] - ETA: 0s - loss: 0.4375 - acc: 0.8229Epoch 00018: val_acc did not improve
# 10/10 [==============================] - 127s 13s/step - loss: 0.4498 - acc: 0.8144 - val_loss: 0.7049 - val_acc: 0.6429
# Epoch 19/20
#  9/10 [==========================>...] - ETA: 0s - loss: 0.3884 - acc: 0.8385Epoch 00019: val_acc did not improve
# 10/10 [==============================] - 127s 13s/step - loss: 0.3802 - acc: 0.8401 - val_loss: 0.7203 - val_acc: 0.6786
# Epoch 20/20
#  9/10 [==========================>...] - ETA: 0s - loss: 0.4675 - acc: 0.8073Epoch 00020: val_acc did not improve
# 10/10 [==============================] - 127s 13s/step - loss: 0.4745 - acc: 0.8026 - val_loss: 0.9045 - val_acc: 0.7321
#
# Starting to Fine Tune Model
# /home/grupoavatar/.local/lib/python3.5/site-packages/keras/callbacks.py:375: RuntimeWarning: ModelCheckpoint mode mode is unknown, fallback to auto mode.
#   RuntimeWarning)
# /home/grupoavatar/.local/lib/python3.5/site-packages/ipykernel_launcher.py:129: UserWarning: The semantics of the Keras 2 argument `steps_per_epoch` is not the same as the Keras 1 argument `samples_per_epoch`. `steps_per_epoch` is the number of batches to draw from the generator at each epoch. Basically steps_per_epoch = samples_per_epoch/batch_size. Similarly `nb_val_samples`->`validation_steps` and `val_samples`->`steps` arguments have changed. Update your method calls accordingly.
# /home/grupoavatar/.local/lib/python3.5/site-packages/ipykernel_launcher.py:129: UserWarning: Update your `fit_generator` call to the Keras 2 API: `fit_generator(<keras.pre..., validation_data=<keras.pre..., validation_steps=346, steps_per_epoch=10, epochs=100, callbacks=[<keras.ca...)`
# Epoch 1/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.6068 - acc: 0.7552Epoch 00001: val_loss improved from inf to 0.73080, saving model to model/model_weights.h5
# 10/10 [==============================] - 131s 13s/step - loss: 0.6488 - acc: 0.7411 - val_loss: 0.7308 - val_acc: 0.7500
# Epoch 2/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.7098 - acc: 0.7170Epoch 00002: val_loss improved from 0.73080 to 0.69242, saving model to model/model_weights.h5
# 10/10 [==============================] - 129s 13s/step - loss: 0.6900 - acc: 0.7201 - val_loss: 0.6924 - val_acc: 0.7500
# Epoch 3/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.6594 - acc: 0.6962Epoch 00003: val_loss improved from 0.69242 to 0.65771, saving model to model/model_weights.h5
# 10/10 [==============================] - 129s 13s/step - loss: 0.6723 - acc: 0.6860 - val_loss: 0.6577 - val_acc: 0.7500
# Epoch 4/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.5710 - acc: 0.7396Epoch 00004: val_loss improved from 0.65771 to 0.63743, saving model to model/model_weights.h5
# 10/10 [==============================] - 128s 13s/step - loss: 0.5770 - acc: 0.7391 - val_loss: 0.6374 - val_acc: 0.7500
# Epoch 5/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.5979 - acc: 0.7170Epoch 00005: val_loss improved from 0.63743 to 0.62826, saving model to model/model_weights.h5
# 10/10 [==============================] - 129s 13s/step - loss: 0.5996 - acc: 0.7177 - val_loss: 0.6283 - val_acc: 0.7500
# Epoch 6/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.5891 - acc: 0.7344Epoch 00006: val_loss improved from 0.62826 to 0.62804, saving model to model/model_weights.h5
# 10/10 [==============================] - 129s 13s/step - loss: 0.5909 - acc: 0.7332 - val_loss: 0.6280 - val_acc: 0.7500
# Epoch 7/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.6094 - acc: 0.7135Epoch 00007: val_loss improved from 0.62804 to 0.62113, saving model to model/model_weights.h5
# 10/10 [==============================] - 128s 13s/step - loss: 0.6044 - acc: 0.7188 - val_loss: 0.6211 - val_acc: 0.7500
# Epoch 8/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.5749 - acc: 0.7500Epoch 00008: val_loss improved from 0.62113 to 0.61167, saving model to model/model_weights.h5
# 10/10 [==============================] - 129s 13s/step - loss: 0.5786 - acc: 0.7500 - val_loss: 0.6117 - val_acc: 0.7500
# Epoch 9/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.4843 - acc: 0.7708Epoch 00009: val_loss improved from 0.61167 to 0.60861, saving model to model/model_weights.h5
# 10/10 [==============================] - 129s 13s/step - loss: 0.5014 - acc: 0.7631 - val_loss: 0.6086 - val_acc: 0.7500
# Epoch 10/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.5662 - acc: 0.7274Epoch 00010: val_loss did not improve
# 10/10 [==============================] - 128s 13s/step - loss: 0.5610 - acc: 0.7306 - val_loss: 0.6091 - val_acc: 0.7500
# Epoch 11/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.6312 - acc: 0.7170Epoch 00011: val_loss improved from 0.60861 to 0.60642, saving model to model/model_weights.h5
# 10/10 [==============================] - 129s 13s/step - loss: 0.6198 - acc: 0.7231 - val_loss: 0.6064 - val_acc: 0.7500
# Epoch 12/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.5319 - acc: 0.7691Epoch 00012: val_loss improved from 0.60642 to 0.60524, saving model to model/model_weights.h5
# 10/10 [==============================] - 129s 13s/step - loss: 0.5324 - acc: 0.7654 - val_loss: 0.6052 - val_acc: 0.7500
# Epoch 13/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.5357 - acc: 0.7691Epoch 00013: val_loss improved from 0.60524 to 0.60353, saving model to model/model_weights.h5
# 10/10 [==============================] - 129s 13s/step - loss: 0.5627 - acc: 0.7609 - val_loss: 0.6035 - val_acc: 0.7500
# Epoch 14/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.5381 - acc: 0.7413Epoch 00014: val_loss improved from 0.60353 to 0.60080, saving model to model/model_weights.h5
# 10/10 [==============================] - 128s 13s/step - loss: 0.5238 - acc: 0.7470 - val_loss: 0.6008 - val_acc: 0.7500
# Epoch 15/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.5352 - acc: 0.7674Epoch 00015: val_loss improved from 0.60080 to 0.59830, saving model to model/model_weights.h5
# 10/10 [==============================] - 128s 13s/step - loss: 0.5278 - acc: 0.7685 - val_loss: 0.5983 - val_acc: 0.7500
# Epoch 16/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.5049 - acc: 0.7604Epoch 00016: val_loss improved from 0.59830 to 0.59557, saving model to model/model_weights.h5
# 10/10 [==============================] - 128s 13s/step - loss: 0.5179 - acc: 0.7516 - val_loss: 0.5956 - val_acc: 0.7500
# Epoch 17/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.5477 - acc: 0.7830Epoch 00017: val_loss improved from 0.59557 to 0.59394, saving model to model/model_weights.h5
# 10/10 [==============================] - 129s 13s/step - loss: 0.5569 - acc: 0.7727 - val_loss: 0.5939 - val_acc: 0.7500
# Epoch 18/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.5761 - acc: 0.7517Epoch 00018: val_loss improved from 0.59394 to 0.59165, saving model to model/model_weights.h5
# 10/10 [==============================] - 128s 13s/step - loss: 0.5679 - acc: 0.7507 - val_loss: 0.5916 - val_acc: 0.7500
# Epoch 19/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.4864 - acc: 0.7847Epoch 00019: val_loss did not improve
# 10/10 [==============================] - 128s 13s/step - loss: 0.4825 - acc: 0.7861 - val_loss: 0.5921 - val_acc: 0.7500
# Epoch 20/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.4848 - acc: 0.7726Epoch 00020: val_loss did not improve
# 10/10 [==============================] - 128s 13s/step - loss: 0.4742 - acc: 0.7790 - val_loss: 0.5925 - val_acc: 0.7500
# Epoch 21/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.4852 - acc: 0.7778Epoch 00021: val_loss did not improve
# 10/10 [==============================] - 128s 13s/step - loss: 0.4872 - acc: 0.7809 - val_loss: 0.5935 - val_acc: 0.7500
# Epoch 22/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.5451 - acc: 0.7517Epoch 00022: val_loss did not improve
# 10/10 [==============================] - 128s 13s/step - loss: 0.5330 - acc: 0.7589 - val_loss: 0.5949 - val_acc: 0.7500
# Epoch 23/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.4314 - acc: 0.7934Epoch 00023: val_loss did not improve
# 10/10 [==============================] - 128s 13s/step - loss: 0.4489 - acc: 0.7887 - val_loss: 0.5964 - val_acc: 0.7500
# Epoch 24/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.4818 - acc: 0.7604Epoch 00024: val_loss did not improve
# 10/10 [==============================] - 128s 13s/step - loss: 0.4798 - acc: 0.7665 - val_loss: 0.5964 - val_acc: 0.7500
# Epoch 25/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.5349 - acc: 0.7552Epoch 00025: val_loss did not improve
# 10/10 [==============================] - 128s 13s/step - loss: 0.5193 - acc: 0.7615 - val_loss: 0.5958 - val_acc: 0.7321
# Epoch 26/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.4517 - acc: 0.7899Epoch 00026: val_loss did not improve
# 10/10 [==============================] - 128s 13s/step - loss: 0.4517 - acc: 0.7931 - val_loss: 0.5969 - val_acc: 0.7143
# Epoch 27/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.5304 - acc: 0.7205Epoch 00027: val_loss did not improve
# 10/10 [==============================] - 128s 13s/step - loss: 0.5184 - acc: 0.7306 - val_loss: 0.5978 - val_acc: 0.7143
# Epoch 28/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.4751 - acc: 0.7865Epoch 00028: val_loss did not improve
# 10/10 [==============================] - 128s 13s/step - loss: 0.4552 - acc: 0.8010 - val_loss: 0.5990 - val_acc: 0.7143
# Epoch 29/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.4723 - acc: 0.7830Epoch 00029: val_loss did not improve
# 10/10 [==============================] - 128s 13s/step - loss: 0.4797 - acc: 0.7852 - val_loss: 0.6004 - val_acc: 0.7321
# Epoch 30/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.4376 - acc: 0.8073Epoch 00030: val_loss did not improve
# 10/10 [==============================] - 128s 13s/step - loss: 0.4466 - acc: 0.8023 - val_loss: 0.6014 - val_acc: 0.7321
# Epoch 31/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.4930 - acc: 0.7361Epoch 00031: val_loss did not improve
# 10/10 [==============================] - 128s 13s/step - loss: 0.4853 - acc: 0.7426 - val_loss: 0.6019 - val_acc: 0.7321
# Epoch 32/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.4371 - acc: 0.8194Epoch 00032: val_loss did not improve
# 10/10 [==============================] - 128s 13s/step - loss: 0.4432 - acc: 0.8111 - val_loss: 0.6037 - val_acc: 0.7321
# Epoch 33/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.4557 - acc: 0.7899Epoch 00033: val_loss did not improve
# 10/10 [==============================] - 128s 13s/step - loss: 0.4493 - acc: 0.7938 - val_loss: 0.6048 - val_acc: 0.7321
# Epoch 34/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.4272 - acc: 0.8264Epoch 00034: val_loss did not improve
# 10/10 [==============================] - 128s 13s/step - loss: 0.4269 - acc: 0.8286 - val_loss: 0.6064 - val_acc: 0.7321
# Epoch 35/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.4424 - acc: 0.7795Epoch 00035: val_loss did not improve
# 10/10 [==============================] - 128s 13s/step - loss: 0.4301 - acc: 0.7905 - val_loss: 0.6078 - val_acc: 0.7143
# Epoch 36/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.3888 - acc: 0.8142Epoch 00036: val_loss did not improve
# 10/10 [==============================] - 128s 13s/step - loss: 0.3975 - acc: 0.8194 - val_loss: 0.6094 - val_acc: 0.7143
# Epoch 37/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.4210 - acc: 0.8003Epoch 00037: val_loss did not improve
# 10/10 [==============================] - 128s 13s/step - loss: 0.4247 - acc: 0.8000 - val_loss: 0.6104 - val_acc: 0.7143
# Epoch 38/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.3987 - acc: 0.8021Epoch 00038: val_loss did not improve
# 10/10 [==============================] - 128s 13s/step - loss: 0.4071 - acc: 0.8019 - val_loss: 0.6122 - val_acc: 0.7143
# Epoch 39/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.4164 - acc: 0.8056Epoch 00039: val_loss did not improve
# 10/10 [==============================] - 128s 13s/step - loss: 0.4204 - acc: 0.8059 - val_loss: 0.6147 - val_acc: 0.7143
# Epoch 40/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.4245 - acc: 0.8021Epoch 00040: val_loss did not improve
# 10/10 [==============================] - 128s 13s/step - loss: 0.4188 - acc: 0.7988 - val_loss: 0.6166 - val_acc: 0.7143
# Epoch 41/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.4072 - acc: 0.8021Epoch 00041: val_loss did not improve
# 10/10 [==============================] - 128s 13s/step - loss: 0.4080 - acc: 0.8014 - val_loss: 0.6183 - val_acc: 0.7143
# Epoch 42/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.3865 - acc: 0.8351Epoch 00042: val_loss did not improve
# 10/10 [==============================] - 128s 13s/step - loss: 0.3912 - acc: 0.8316 - val_loss: 0.6212 - val_acc: 0.7143
# Epoch 43/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.3918 - acc: 0.8281Epoch 00043: val_loss did not improve
# 10/10 [==============================] - 128s 13s/step - loss: 0.3929 - acc: 0.8273 - val_loss: 0.6239 - val_acc: 0.7143
# Epoch 44/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.4080 - acc: 0.8142Epoch 00044: val_loss did not improve
# 10/10 [==============================] - 128s 13s/step - loss: 0.3892 - acc: 0.8326 - val_loss: 0.6260 - val_acc: 0.7143
# Epoch 45/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.3808 - acc: 0.8368Epoch 00045: val_loss did not improve
# 10/10 [==============================] - 128s 13s/step - loss: 0.3794 - acc: 0.8335 - val_loss: 0.6281 - val_acc: 0.7143
# Epoch 46/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.3864 - acc: 0.8385Epoch 00046: val_loss did not improve
# 10/10 [==============================] - 128s 13s/step - loss: 0.3993 - acc: 0.8313 - val_loss: 0.6281 - val_acc: 0.7143
# Epoch 47/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.3676 - acc: 0.8420Epoch 00047: val_loss did not improve
# 10/10 [==============================] - 128s 13s/step - loss: 0.3654 - acc: 0.8408 - val_loss: 0.6283 - val_acc: 0.7143
# Epoch 48/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.3385 - acc: 0.8576Epoch 00048: val_loss did not improve
# 10/10 [==============================] - 128s 13s/step - loss: 0.3458 - acc: 0.8529 - val_loss: 0.6297 - val_acc: 0.7143
# Epoch 49/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.3349 - acc: 0.8628Epoch 00049: val_loss did not improve
# 10/10 [==============================] - 128s 13s/step - loss: 0.3468 - acc: 0.8576 - val_loss: 0.6322 - val_acc: 0.7143
# Epoch 50/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.3927 - acc: 0.8368Epoch 00050: val_loss did not improve
# 10/10 [==============================] - 128s 13s/step - loss: 0.4105 - acc: 0.8231 - val_loss: 0.6352 - val_acc: 0.7143
# Epoch 51/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.3838 - acc: 0.8247Epoch 00051: val_loss did not improve
# 10/10 [==============================] - 128s 13s/step - loss: 0.3848 - acc: 0.8247 - val_loss: 0.6359 - val_acc: 0.7143
# Epoch 52/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.3459 - acc: 0.8472Epoch 00052: val_loss did not improve
# 10/10 [==============================] - 128s 13s/step - loss: 0.3418 - acc: 0.8460 - val_loss: 0.6359 - val_acc: 0.7143
# Epoch 53/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.3564 - acc: 0.8368Epoch 00053: val_loss did not improve
# 10/10 [==============================] - 128s 13s/step - loss: 0.3575 - acc: 0.8339 - val_loss: 0.6339 - val_acc: 0.7143
# Epoch 54/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.3284 - acc: 0.8368Epoch 00054: val_loss did not improve
# 10/10 [==============================] - 128s 13s/step - loss: 0.3342 - acc: 0.8408 - val_loss: 0.6337 - val_acc: 0.7143
# Epoch 55/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.3133 - acc: 0.8750Epoch 00055: val_loss did not improve
# 10/10 [==============================] - 128s 13s/step - loss: 0.3152 - acc: 0.8734 - val_loss: 0.6346 - val_acc: 0.7143
# Epoch 56/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.3404 - acc: 0.8507Epoch 00056: val_loss did not improve
# 10/10 [==============================] - 128s 13s/step - loss: 0.3621 - acc: 0.8401 - val_loss: 0.6366 - val_acc: 0.7143
# Epoch 57/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.3516 - acc: 0.8403Epoch 00057: val_loss did not improve
# 10/10 [==============================] - 128s 13s/step - loss: 0.3446 - acc: 0.8455 - val_loss: 0.6383 - val_acc: 0.7143
# Epoch 58/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.3374 - acc: 0.8594Epoch 00058: val_loss did not improve
# 10/10 [==============================] - 128s 13s/step - loss: 0.3312 - acc: 0.8674 - val_loss: 0.6408 - val_acc: 0.7143
# Epoch 59/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.3572 - acc: 0.8316Epoch 00059: val_loss did not improve
# 10/10 [==============================] - 128s 13s/step - loss: 0.3522 - acc: 0.8363 - val_loss: 0.6427 - val_acc: 0.7143
# Epoch 60/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.3898 - acc: 0.8073Epoch 00060: val_loss did not improve
# 10/10 [==============================] - 128s 13s/step - loss: 0.3749 - acc: 0.8218 - val_loss: 0.6441 - val_acc: 0.7143
# Epoch 61/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.3105 - acc: 0.8906Epoch 00061: val_loss did not improve
# 10/10 [==============================] - 128s 13s/step - loss: 0.3125 - acc: 0.8885 - val_loss: 0.6483 - val_acc: 0.7143
# Epoch 62/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.2702 - acc: 0.9010Epoch 00062: val_loss did not improve
# 10/10 [==============================] - 128s 13s/step - loss: 0.2768 - acc: 0.8920 - val_loss: 0.6552 - val_acc: 0.7143
# Epoch 63/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.3202 - acc: 0.8733Epoch 00063: val_loss did not improve
# 10/10 [==============================] - 128s 13s/step - loss: 0.3163 - acc: 0.8727 - val_loss: 0.6593 - val_acc: 0.7143
# Epoch 64/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.2732 - acc: 0.8750Epoch 00064: val_loss did not improve
# 10/10 [==============================] - 128s 13s/step - loss: 0.2945 - acc: 0.8625 - val_loss: 0.6625 - val_acc: 0.7143
# Epoch 65/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.3100 - acc: 0.8438Epoch 00065: val_loss did not improve
# 10/10 [==============================] - 128s 13s/step - loss: 0.3064 - acc: 0.8488 - val_loss: 0.6636 - val_acc: 0.7143
# Epoch 66/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.2621 - acc: 0.9045Epoch 00066: val_loss did not improve
# 10/10 [==============================] - 128s 13s/step - loss: 0.2666 - acc: 0.9062 - val_loss: 0.6661 - val_acc: 0.7143
# Epoch 67/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.2954 - acc: 0.8472Epoch 00067: val_loss did not improve
# 10/10 [==============================] - 128s 13s/step - loss: 0.2926 - acc: 0.8504 - val_loss: 0.6687 - val_acc: 0.7143
# Epoch 68/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.2805 - acc: 0.8715Epoch 00068: val_loss did not improve
# 10/10 [==============================] - 128s 13s/step - loss: 0.2806 - acc: 0.8698 - val_loss: 0.6697 - val_acc: 0.7143
# Epoch 69/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.2762 - acc: 0.9062Epoch 00069: val_loss did not improve
# 10/10 [==============================] - 128s 13s/step - loss: 0.2750 - acc: 0.9036 - val_loss: 0.6712 - val_acc: 0.7143
# Epoch 70/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.2811 - acc: 0.8542Epoch 00070: val_loss did not improve
# 10/10 [==============================] - 128s 13s/step - loss: 0.2799 - acc: 0.8596 - val_loss: 0.6720 - val_acc: 0.7143
# Epoch 71/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.2757 - acc: 0.8594Epoch 00071: val_loss did not improve
# 10/10 [==============================] - 128s 13s/step - loss: 0.2718 - acc: 0.8688 - val_loss: 0.6729 - val_acc: 0.7143
# Epoch 72/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.3051 - acc: 0.8628Epoch 00072: val_loss did not improve
# 10/10 [==============================] - 128s 13s/step - loss: 0.2985 - acc: 0.8705 - val_loss: 0.6754 - val_acc: 0.7143
# Epoch 73/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.2418 - acc: 0.9097Epoch 00073: val_loss did not improve
# 10/10 [==============================] - 128s 13s/step - loss: 0.2541 - acc: 0.9059 - val_loss: 0.6786 - val_acc: 0.7143
# Epoch 74/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.2362 - acc: 0.9288Epoch 00074: val_loss did not improve
# 10/10 [==============================] - 128s 13s/step - loss: 0.2318 - acc: 0.9359 - val_loss: 0.6802 - val_acc: 0.7143
# Epoch 75/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.2524 - acc: 0.9062Epoch 00075: val_loss did not improve
# 10/10 [==============================] - 128s 13s/step - loss: 0.2409 - acc: 0.9141 - val_loss: 0.6841 - val_acc: 0.7143
# Epoch 76/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.2728 - acc: 0.8472Epoch 00076: val_loss did not improve
# 10/10 [==============================] - 128s 13s/step - loss: 0.2656 - acc: 0.8586 - val_loss: 0.6868 - val_acc: 0.7143
# Epoch 77/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.2458 - acc: 0.9062Epoch 00077: val_loss did not improve
# 10/10 [==============================] - 128s 13s/step - loss: 0.2361 - acc: 0.9099 - val_loss: 0.6855 - val_acc: 0.7143
# Epoch 78/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.2577 - acc: 0.8941Epoch 00078: val_loss did not improve
# 10/10 [==============================] - 128s 13s/step - loss: 0.2582 - acc: 0.8908 - val_loss: 0.6856 - val_acc: 0.7143
# Epoch 79/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.2503 - acc: 0.8958Epoch 00079: val_loss did not improve
# 10/10 [==============================] - 128s 13s/step - loss: 0.2473 - acc: 0.8988 - val_loss: 0.6848 - val_acc: 0.7143
# Epoch 80/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.2651 - acc: 0.8733Epoch 00080: val_loss did not improve
# 10/10 [==============================] - 128s 13s/step - loss: 0.2555 - acc: 0.8869 - val_loss: 0.6859 - val_acc: 0.7143
# Epoch 81/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.2247 - acc: 0.9358Epoch 00081: val_loss did not improve
# 10/10 [==============================] - 128s 13s/step - loss: 0.2241 - acc: 0.9352 - val_loss: 0.6870 - val_acc: 0.7143
# Epoch 82/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.2401 - acc: 0.9080Epoch 00082: val_loss did not improve
# 10/10 [==============================] - 128s 13s/step - loss: 0.2473 - acc: 0.9056 - val_loss: 0.6902 - val_acc: 0.7143
# Epoch 83/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.2042 - acc: 0.9392Epoch 00083: val_loss did not improve
# 10/10 [==============================] - 128s 13s/step - loss: 0.2061 - acc: 0.9398 - val_loss: 0.6894 - val_acc: 0.7143
# Epoch 84/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.2189 - acc: 0.9358Epoch 00084: val_loss did not improve
# 10/10 [==============================] - 128s 13s/step - loss: 0.2273 - acc: 0.9254 - val_loss: 0.6904 - val_acc: 0.7143
# Epoch 85/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.1969 - acc: 0.9288Epoch 00085: val_loss did not improve
# 10/10 [==============================] - 128s 13s/step - loss: 0.1931 - acc: 0.9323 - val_loss: 0.6903 - val_acc: 0.6964
# Epoch 86/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.2077 - acc: 0.9497Epoch 00086: val_loss did not improve
# 10/10 [==============================] - 128s 13s/step - loss: 0.2050 - acc: 0.9484 - val_loss: 0.6927 - val_acc: 0.6964
# Epoch 87/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.2356 - acc: 0.9253Epoch 00087: val_loss did not improve
# 10/10 [==============================] - 128s 13s/step - loss: 0.2329 - acc: 0.9287 - val_loss: 0.6926 - val_acc: 0.6964
# Epoch 88/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.2108 - acc: 0.9219Epoch 00088: val_loss did not improve
# 10/10 [==============================] - 128s 13s/step - loss: 0.2072 - acc: 0.9273 - val_loss: 0.6956 - val_acc: 0.6964
# Epoch 89/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.1873 - acc: 0.9479Epoch 00089: val_loss did not improve
# 10/10 [==============================] - 128s 13s/step - loss: 0.1841 - acc: 0.9484 - val_loss: 0.6989 - val_acc: 0.6964
# Epoch 90/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.1882 - acc: 0.9497Epoch 00090: val_loss did not improve
# 10/10 [==============================] - 128s 13s/step - loss: 0.1862 - acc: 0.9490 - val_loss: 0.7044 - val_acc: 0.6964
# Epoch 91/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.1931 - acc: 0.9132Epoch 00091: val_loss did not improve
# 10/10 [==============================] - 128s 13s/step - loss: 0.1915 - acc: 0.9172 - val_loss: 0.7055 - val_acc: 0.6964
# Epoch 92/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.1565 - acc: 0.9688Epoch 00092: val_loss did not improve
# 10/10 [==============================] - 128s 13s/step - loss: 0.1590 - acc: 0.9644 - val_loss: 0.7068 - val_acc: 0.6964
# Epoch 93/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.1946 - acc: 0.9392Epoch 00093: val_loss did not improve
# 10/10 [==============================] - 128s 13s/step - loss: 0.1969 - acc: 0.9339 - val_loss: 0.7070 - val_acc: 0.6964
# Epoch 94/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.1724 - acc: 0.9653Epoch 00094: val_loss did not improve
# 10/10 [==============================] - 128s 13s/step - loss: 0.1725 - acc: 0.9641 - val_loss: 0.7058 - val_acc: 0.6786
# Epoch 95/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.1742 - acc: 0.9340Epoch 00095: val_loss did not improve
# 10/10 [==============================] - 128s 13s/step - loss: 0.1813 - acc: 0.9349 - val_loss: 0.7070 - val_acc: 0.6786
# Epoch 96/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.1617 - acc: 0.9635Epoch 00096: val_loss did not improve
# 10/10 [==============================] - 128s 13s/step - loss: 0.1679 - acc: 0.9549 - val_loss: 0.7104 - val_acc: 0.6964
# Epoch 97/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.1661 - acc: 0.9549Epoch 00097: val_loss did not improve
# 10/10 [==============================] - 128s 13s/step - loss: 0.1634 - acc: 0.9526 - val_loss: 0.7123 - val_acc: 0.6964
# Epoch 98/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.1850 - acc: 0.9462Epoch 00098: val_loss did not improve
# 10/10 [==============================] - 128s 13s/step - loss: 0.1755 - acc: 0.9514 - val_loss: 0.7144 - val_acc: 0.6964
# Epoch 99/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.1333 - acc: 0.9826Epoch 00099: val_loss did not improve
# 10/10 [==============================] - 128s 13s/step - loss: 0.1334 - acc: 0.9809 - val_loss: 0.7157 - val_acc: 0.6786
# Epoch 100/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.1676 - acc: 0.9444Epoch 00100: val_loss did not improve
# 10/10 [==============================] - 128s 13s/step - loss: 0.1595 - acc: 0.9493 - val_loss: 0.7189 - val_acc: 0.6786

# %% [markdown]
# ## Modelo Inception V3

# %%
# let's visualize layer names and layer indices to see how many layers
# we should freeze: this is used to define based_model_last_block_layer_number
for i, layer in enumerate(model_layers):  # comment these two lines once the correct based_model_last_block_layer
    print(i, layer.name)  # has been selected
# Out:
# 0 input_1
# 1 conv2d_1
# 2 batch_normalization_1
# 3 activation_1
# 4 conv2d_2
# 5 batch_normalization_2
# 6 activation_2
# 7 conv2d_3
# 8 batch_normalization_3
# 9 activation_3
# 10 max_pooling2d_1
# 11 conv2d_4
# 12 batch_normalization_4
# 13 activation_4
# 14 conv2d_5
# 15 batch_normalization_5
# 16 activation_5
# 17 max_pooling2d_2
# 18 conv2d_9
# 19 batch_normalization_9
# 20 activation_9
# 21 conv2d_7
# 22 conv2d_10
# 23 batch_normalization_7
# 24 batch_normalization_10
# 25 activation_7
# 26 activation_10
# 27 average_pooling2d_1
# 28 conv2d_6
# 29 conv2d_8
# 30 conv2d_11
# 31 conv2d_12
# 32 batch_normalization_6
# 33 batch_normalization_8
# 34 batch_normalization_11
# 35 batch_normalization_12
# 36 activation_6
# 37 activation_8
# 38 activation_11
# 39 activation_12
# 40 mixed0
# 41 conv2d_16
# 42 batch_normalization_16
# 43 activation_16
# 44 conv2d_14
# 45 conv2d_17
# 46 batch_normalization_14
# 47 batch_normalization_17
# 48 activation_14
# 49 activation_17
# 50 average_pooling2d_2
# 51 conv2d_13
# 52 conv2d_15
# 53 conv2d_18
# 54 conv2d_19
# 55 batch_normalization_13
# 56 batch_normalization_15
# 57 batch_normalization_18
# 58 batch_normalization_19
# 59 activation_13
# 60 activation_15
# 61 activation_18
# 62 activation_19
# 63 mixed1
# 64 conv2d_23
# 65 batch_normalization_23
# 66 activation_23
# 67 conv2d_21
# 68 conv2d_24
# 69 batch_normalization_21
# 70 batch_normalization_24
# 71 activation_21
# 72 activation_24
# 73 average_pooling2d_3
# 74 conv2d_20
# 75 conv2d_22
# 76 conv2d_25
# 77 conv2d_26
# 78 batch_normalization_20
# 79 batch_normalization_22
# 80 batch_normalization_25
# 81 batch_normalization_26
# 82 activation_20
# 83 activation_22
# 84 activation_25
# 85 activation_26
# 86 mixed2
# 87 conv2d_28
# 88 batch_normalization_28
# 89 activation_28
# 90 conv2d_29
# 91 batch_normalization_29
# 92 activation_29
# 93 conv2d_27
# 94 conv2d_30
# 95 batch_normalization_27
# 96 batch_normalization_30
# 97 activation_27
# 98 activation_30
# 99 max_pooling2d_3
# 100 mixed3
# 101 conv2d_35
# 102 batch_normalization_35
# 103 activation_35
# 104 conv2d_36
# 105 batch_normalization_36
# 106 activation_36
# 107 conv2d_32
# 108 conv2d_37
# 109 batch_normalization_32
# 110 batch_normalization_37
# 111 activation_32
# 112 activation_37
# 113 conv2d_33
# 114 conv2d_38
# 115 batch_normalization_33
# 116 batch_normalization_38
# 117 activation_33
# 118 activation_38
# 119 average_pooling2d_4
# 120 conv2d_31
# 121 conv2d_34
# 122 conv2d_39
# 123 conv2d_40
# 124 batch_normalization_31
# 125 batch_normalization_34
# 126 batch_normalization_39
# 127 batch_normalization_40
# 128 activation_31
# 129 activation_34
# 130 activation_39
# 131 activation_40
# 132 mixed4
# 133 conv2d_45
# 134 batch_normalization_45
# 135 activation_45
# 136 conv2d_46
# 137 batch_normalization_46
# 138 activation_46
# 139 conv2d_42
# 140 conv2d_47
# 141 batch_normalization_42
# 142 batch_normalization_47
# 143 activation_42
# 144 activation_47
# 145 conv2d_43
# 146 conv2d_48
# 147 batch_normalization_43
# 148 batch_normalization_48
# 149 activation_43
# 150 activation_48
# 151 average_pooling2d_5
# 152 conv2d_41
# 153 conv2d_44
# 154 conv2d_49
# 155 conv2d_50
# 156 batch_normalization_41
# 157 batch_normalization_44
# 158 batch_normalization_49
# 159 batch_normalization_50
# 160 activation_41
# 161 activation_44
# 162 activation_49
# 163 activation_50
# 164 mixed5
# 165 conv2d_55
# 166 batch_normalization_55
# 167 activation_55
# 168 conv2d_56
# 169 batch_normalization_56
# 170 activation_56
# 171 conv2d_52
# 172 conv2d_57
# 173 batch_normalization_52
# 174 batch_normalization_57
# 175 activation_52
# 176 activation_57
# 177 conv2d_53
# 178 conv2d_58
# 179 batch_normalization_53
# 180 batch_normalization_58
# 181 activation_53
# 182 activation_58
# 183 average_pooling2d_6
# 184 conv2d_51
# 185 conv2d_54
# 186 conv2d_59
# 187 conv2d_60
# 188 batch_normalization_51
# 189 batch_normalization_54
# 190 batch_normalization_59
# 191 batch_normalization_60
# 192 activation_51
# 193 activation_54
# 194 activation_59
# 195 activation_60
# 196 mixed6
# 197 conv2d_65
# 198 batch_normalization_65
# 199 activation_65
# 200 conv2d_66
# 201 batch_normalization_66
# 202 activation_66
# 203 conv2d_62
# 204 conv2d_67
# 205 batch_normalization_62
# 206 batch_normalization_67
# 207 activation_62
# 208 activation_67
# 209 conv2d_63
# 210 conv2d_68
# 211 batch_normalization_63
# 212 batch_normalization_68
# 213 activation_63
# 214 activation_68
# 215 average_pooling2d_7
# 216 conv2d_61
# 217 conv2d_64
# 218 conv2d_69
# 219 conv2d_70
# 220 batch_normalization_61
# 221 batch_normalization_64
# 222 batch_normalization_69
# 223 batch_normalization_70
# 224 activation_61
# 225 activation_64
# 226 activation_69
# 227 activation_70
# 228 mixed7
# 229 conv2d_73
# 230 batch_normalization_73
# 231 activation_73
# 232 conv2d_74
# 233 batch_normalization_74
# 234 activation_74
# 235 conv2d_71
# 236 conv2d_75
# 237 batch_normalization_71
# 238 batch_normalization_75
# 239 activation_71
# 240 activation_75
# 241 conv2d_72
# 242 conv2d_76
# 243 batch_normalization_72
# 244 batch_normalization_76
# 245 activation_72
# 246 activation_76
# 247 max_pooling2d_4
# 248 mixed8
# 249 conv2d_81
# 250 batch_normalization_81
# 251 activation_81
# 252 conv2d_78
# 253 conv2d_82
# 254 batch_normalization_78
# 255 batch_normalization_82
# 256 activation_78
# 257 activation_82
# 258 conv2d_79
# 259 conv2d_80
# 260 conv2d_83
# 261 conv2d_84
# 262 average_pooling2d_8
# 263 conv2d_77
# 264 batch_normalization_79
# 265 batch_normalization_80
# 266 batch_normalization_83
# 267 batch_normalization_84
# 268 conv2d_85
# 269 batch_normalization_77
# 270 activation_79
# 271 activation_80
# 272 activation_83
# 273 activation_84
# 274 batch_normalization_85
# 275 activation_77
# 276 mixed9_0
# 277 concatenate_1
# 278 activation_85
# 279 mixed9
# 280 conv2d_90
# 281 batch_normalization_90
# 282 activation_90
# 283 conv2d_87
# 284 conv2d_91
# 285 batch_normalization_87
# 286 batch_normalization_91
# 287 activation_87
# 288 activation_91
# 289 conv2d_88
# 290 conv2d_89
# 291 conv2d_92
# 292 conv2d_93
# 293 average_pooling2d_9
# 294 conv2d_86
# 295 batch_normalization_88
# 296 batch_normalization_89
# 297 batch_normalization_92
# 298 batch_normalization_93
# 299 conv2d_94
# 300 batch_normalization_86
# 301 activation_88
# 302 activation_89
# 303 activation_92
# 304 activation_93
# 305 batch_normalization_94
# 306 activation_86
# 307 mixed9_1
# 308 concatenate_2
# 309 activation_94
# 310 mixed10
# 311 global_average_pooling2d_1
# 312 dense_1
# 313 dropout_1
# 314 dense_2

# %% [markdown]
# ## Resultados
#
# ### Transfer Learning

# %%
def plot_training2(history):
    #% matplotlib inline

    df = pd.DataFrame(history.history)
    # display(df)

    plot = df.plot(y=['loss', 'val_loss'], figsize=(8, 4), title='Training and validation loss', legend=True)
    plot.set_xlabel('Epochs')
    plot.set_ylabel('Loss binary_crossentropy')    
    fig = plot.get_figure()
    fig.savefig('loss_graph_t_cancer_t:'+str(nb_train_samples)+'smp_v:'+str(nb_validation_samples)+'smp_'+str(nb_epoch)+'epc.png')

    plot = df.plot(y=['acc', 'val_acc'], figsize=(8, 4), title='Training and validation accuracy', legend=True)
    plot.set_xlabel('Epochs')
    plot.set_ylabel('Accuracy')
    fig = plot.get_figure()
    fig.savefig('acc_graph_t_cancer_t:'+str(nb_train_samples)+'smp_v:'+str(nb_validation_samples)+'smp_'+str(nb_epoch)+'epc.png')
    
    plt.show()

#Transfer Learning    
plot_training2(hist_tl)
# Out:
# /home/grupoavatar/.local/lib/python3.5/site-packages/pandas/plotting/_core.py:1714: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   series.name = label
# /home/grupoavatar/.local/lib/python3.5/site-packages/pandas/plotting/_core.py:1714: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   series.name = label

# %% [markdown]
# ## Resultados
#
# ### Fine Tune

# %%
#Finetune
plot_training2(hist_ft)
# Out:
# /home/grupoavatar/.local/lib/python3.5/site-packages/pandas/plotting/_core.py:1714: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   series.name = label

# %% [markdown]
# ## Cierre

# %%
# release memory
k.clear_session()
