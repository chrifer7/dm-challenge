# %%
import sys
import numpy as np
import tensorflow as tf
#import matplotlib.pyplot as plt
# Generacion del grafico de metricas de Perdidas y Accuracy
import pandas as pd
import matplotlib.pyplot as plt
#ML
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import GlobalAveragePooling2D
from keras.layers import Dropout, Dense
from keras.applications import *
from keras.optimizers import SGD
from keras.callbacks import ModelCheckpoint
from keras import backend as k
from keras.models import Model
# Out:
# Using TensorFlow backend.

# %%
# fix seed for reproducible results (only works on CPU, not GPU)
#seed = 9
#np.random.seed(seed=seed)
#tf.set_random_seed(seed=seed)

# parameters dependent on your dataset: modified to your example
nb_train_samples = 690  # Total number of train samples. NOT including augmented images
nb_validation_samples = 346  # Total number of train samples. NOT including augmented images.
img_width, img_height = 299, 299  # change based on the shape/structure of your images

# hyper parameters for model
based_model_last_block_layer_number = 172  # value is based on based model selected.
batch_size = 64#8  # try 4, 8, 16, 32, 64, 128, 256 dependent on CPU/GPU memory capacity (powers of 2 values).
nb_epoch = 100#100  # number of iteration the algorithm gets trained.
learn_rate = 1e-4  # sgd learning rate
momentum = .9  # sgd momentum to avoid local minimum

#Dataset
data_dir = './data/DDSM Images'
#data_dir = './data/DM images'
train_dir = data_dir + '/train'  # change to your train path. Inside, each class should have it's own folder
validation_dir = data_dir + '/validation'  # validation path. Inside, each class should have it's own folder

# %%
def train(train_data_dir, validation_data_dir):
    # Pre-Trained CNN Model using imagenet dataset for pre-trained weights
    base_model = InceptionV3(weights='imagenet', include_top=False)  # select from keras pre-built models library

    # Top Model Block
    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x = Dense(256, activation='relu')(x)
    x = Dropout(0.5)(x)
    predictions = Dense(1, activation='sigmoid')(x)  # softmax if multi-class classifiers
    #predictions = Dense(nb_classes, activation='softmax')(x) #new softmax layer

    # add your top layer block to your base model
    model = Model(base_model.input, predictions)

    # first: train only the top layers (which were randomly initialized)
    # i.e. freeze all convolution layers
    for layer in base_model.layers:
        layer.trainable = False

    # Read Data and Augment it: Make sure to select augmentations that are appropriate to your images.
    # To save augmentations un-comment save lines and add to your flow parameters.
    train_datagen = ImageDataGenerator(rescale=1. / 255,
                                       #rotation_range=10,
                                       shear_range=.1,
                                       zoom_range=.1,
                                       cval=.1,
                                       horizontal_flip=True)
                                       #vertical_flip=True)

    validation_datagen = ImageDataGenerator(rescale=1. / 255)

    train_generator = train_datagen.flow_from_directory(train_data_dir,
                                                        target_size=(img_height, img_width),
                                                        batch_size=batch_size,
                                                        class_mode='binary')
                                                        #save_to_dir=data_dir + '/preview',
                                                        #save_prefix='aug')#,
                                                        #save_format='jpeg')
    # use the above 3 commented lines if you want to save and look at how the data augmentations look like

    validation_generator = validation_datagen.flow_from_directory(validation_data_dir,
                                                            target_size=(img_height, img_width),
                                                            batch_size=batch_size,
                                                            class_mode='binary')

    model.compile(optimizer='rmsprop',
                  loss='binary_crossentropy',  # categorical_crossentropy if multi-class classifier
                  metrics=['accuracy'])
    #  model.compile(optimizer=SGD(lr=0.0001, momentum=0.9), loss='categorical_crossentropy', metrics=['accuracy'])

    # save weights of best training epoch: monitor either val_loss or val_acc
    top_weights_path = 'model/top_model_weights.h5'
    checkpoint = ModelCheckpoint(top_weights_path, monitor='val_acc', verbose=1, save_best_only=True, mode='auto')
    callbacks_list = [checkpoint]

    # Train Simple CNN
    history_tl = model.fit_generator(train_generator,
                        samples_per_epoch=nb_train_samples,
                        nb_epoch=nb_epoch / 5,
                        validation_data=validation_generator,
                        nb_val_samples=nb_validation_samples,
                        callbacks=callbacks_list)

    # add the best weights from the train top model
    # at this point we have the pre-train weights of the base model and the trained weight of the new/added top model
    # we re-load model weights to ensure the best epoch is selected and not the last one.
    model.load_weights(top_weights_path)

    # verbose
    print("\nStarting to Fine Tune Model\n")

    # based_model_last_block_layer_number points to the layer in your model you want to train.
    # For example if you want to train the last block of a 19 layer VGG16 model this should be 15
    # If you want to train the last TWO blocks of an Inception model it should be 172
    # layers before this number will used the pre-trained weights, layers above and including this number
    # will be re-trained based on the new data.
    for layer in model.layers[:based_model_last_block_layer_number]:
        layer.trainable = False
    for layer in model.layers[based_model_last_block_layer_number:]:
        layer.trainable = True

    # compile the model with a SGD/momentum optimizer
    # and a very slow learning rate.
    model.compile(loss='binary_crossentropy',
                  optimizer=SGD(lr=learn_rate, momentum=momentum),
                  metrics=['accuracy'])

    # save weights of best training epoch: monitor either val_loss or val_acc
    path_dir = data_dir.split('/')
    name_dir = path_dir[len(path_dir)-1]
    final_weights_path = 'model/model_weights_'+name_dir+'.h5'
    checkpoint = ModelCheckpoint(final_weights_path, monitor='val_loss', verbose=1, save_best_only=True, mode='mode')
    callbacks_list = [checkpoint]

    # fine-tune the model
    history_ft = model.fit_generator(train_generator,
                        samples_per_epoch=nb_train_samples,
                        nb_epoch=nb_epoch,
                        validation_data=validation_generator,
                        nb_val_samples=nb_validation_samples,
                        callbacks=callbacks_list)
    
    # save model
    model_json = model.to_json()
    with open('model/model'+name_dir+'.json', 'w') as json_file:
        json_file.write(model_json)
        
    return history_tl, history_ft, model.layers


hist_tl, hist_ft, model_layers = train(train_dir, validation_dir)  # train model
# Out:
# Found 690 images belonging to 2 classes.
# Found 346 images belonging to 2 classes.
# /home/grupoavatar/.local/lib/python3.5/site-packages/ipykernel_launcher.py:63: UserWarning: The semantics of the Keras 2 argument `steps_per_epoch` is not the same as the Keras 1 argument `samples_per_epoch`. `steps_per_epoch` is the number of batches to draw from the generator at each epoch. Basically steps_per_epoch = samples_per_epoch/batch_size. Similarly `nb_val_samples`->`validation_steps` and `val_samples`->`steps` arguments have changed. Update your method calls accordingly.
# /home/grupoavatar/.local/lib/python3.5/site-packages/ipykernel_launcher.py:63: UserWarning: Update your `fit_generator` call to the Keras 2 API: `fit_generator(<keras.pre..., epochs=20.0, validation_data=<keras.pre..., steps_per_epoch=10, validation_steps=346, callbacks=[<keras.ca...)`
# Epoch 1/20
#  9/10 [==========================>...] - ETA: 0s - loss: 0.9384 - acc: 0.7774Epoch 00001: val_acc improved from -inf to 0.85549, saving model to model/top_model_weights.h5
# 10/10 [==============================] - 139s 14s/step - loss: 0.8854 - acc: 0.7870 - val_loss: 0.4554 - val_acc: 0.8555
# Epoch 2/20
#  9/10 [==========================>...] - ETA: 0s - loss: 0.4021 - acc: 0.8299Epoch 00002: val_acc did not improve
# 10/10 [==============================] - 131s 13s/step - loss: 0.3983 - acc: 0.8309 - val_loss: 0.4069 - val_acc: 0.8554
# Epoch 3/20
#  9/10 [==========================>...] - ETA: 0s - loss: 0.3187 - acc: 0.8773Epoch 00003: val_acc did not improve
# 10/10 [==============================] - 131s 13s/step - loss: 0.3265 - acc: 0.8692 - val_loss: 0.3472 - val_acc: 0.8553
# Epoch 4/20
#  9/10 [==========================>...] - ETA: 0s - loss: 0.2606 - acc: 0.8926Epoch 00004: val_acc improved from 0.85549 to 0.88988, saving model to model/top_model_weights.h5
# 10/10 [==============================] - 132s 13s/step - loss: 0.2682 - acc: 0.8892 - val_loss: 0.2920 - val_acc: 0.8899
# Epoch 5/20
#  9/10 [==========================>...] - ETA: 0s - loss: 0.3004 - acc: 0.8889Epoch 00005: val_acc did not improve
# 10/10 [==============================] - 132s 13s/step - loss: 0.2857 - acc: 0.8906 - val_loss: 0.3483 - val_acc: 0.8554
# Epoch 6/20
#  9/10 [==========================>...] - ETA: 0s - loss: 0.2280 - acc: 0.9040Epoch 00006: val_acc did not improve
# 10/10 [==============================] - 132s 13s/step - loss: 0.2243 - acc: 0.9041 - val_loss: 0.2766 - val_acc: 0.8670
# Epoch 7/20
#  9/10 [==========================>...] - ETA: 0s - loss: 0.3030 - acc: 0.8535Epoch 00007: val_acc did not improve
# 10/10 [==============================] - 132s 13s/step - loss: 0.2867 - acc: 0.8634 - val_loss: 0.3399 - val_acc: 0.8586
# Epoch 8/20
#  9/10 [==========================>...] - ETA: 0s - loss: 0.2022 - acc: 0.9174Epoch 00008: val_acc improved from 0.88988 to 0.93638, saving model to model/top_model_weights.h5
# 10/10 [==============================] - 132s 13s/step - loss: 0.2127 - acc: 0.9084 - val_loss: 0.2302 - val_acc: 0.9364
# Epoch 9/20
#  9/10 [==========================>...] - ETA: 0s - loss: 0.2042 - acc: 0.9155Epoch 00009: val_acc did not improve
# 10/10 [==============================] - 132s 13s/step - loss: 0.1994 - acc: 0.9162 - val_loss: 0.2401 - val_acc: 0.8812
# Epoch 10/20
#  9/10 [==========================>...] - ETA: 0s - loss: 0.1950 - acc: 0.9278Epoch 00010: val_acc did not improve
# 10/10 [==============================] - 132s 13s/step - loss: 0.1860 - acc: 0.9334 - val_loss: 0.2581 - val_acc: 0.8784
# Epoch 11/20
#  9/10 [==========================>...] - ETA: 0s - loss: 0.2072 - acc: 0.9066Epoch 00011: val_acc did not improve
# 10/10 [==============================] - 132s 13s/step - loss: 0.1980 - acc: 0.9099 - val_loss: 0.2336 - val_acc: 0.8872
# Epoch 12/20
#  9/10 [==========================>...] - ETA: 0s - loss: 0.1412 - acc: 0.9462Epoch 00012: val_acc improved from 0.93638 to 0.93638, saving model to model/top_model_weights.h5
# 10/10 [==============================] - 133s 13s/step - loss: 0.1422 - acc: 0.9452 - val_loss: 0.1807 - val_acc: 0.9364
# Epoch 13/20
#  9/10 [==========================>...] - ETA: 0s - loss: 0.1498 - acc: 0.9514Epoch 00013: val_acc did not improve
# 10/10 [==============================] - 132s 13s/step - loss: 0.1470 - acc: 0.9522 - val_loss: 0.1722 - val_acc: 0.9304
# Epoch 14/20
#  9/10 [==========================>...] - ETA: 0s - loss: 0.1585 - acc: 0.9288Epoch 00014: val_acc did not improve
# 10/10 [==============================] - 132s 13s/step - loss: 0.1537 - acc: 0.9299 - val_loss: 0.1679 - val_acc: 0.9308
# Epoch 15/20
#  9/10 [==========================>...] - ETA: 0s - loss: 0.1453 - acc: 0.9462Epoch 00015: val_acc did not improve
# 10/10 [==============================] - 132s 13s/step - loss: 0.1688 - acc: 0.9358 - val_loss: 0.2491 - val_acc: 0.9071
# Epoch 16/20
#  9/10 [==========================>...] - ETA: 0s - loss: 0.1375 - acc: 0.9504Epoch 00016: val_acc improved from 0.93638 to 0.94234, saving model to model/top_model_weights.h5
# 10/10 [==============================] - 132s 13s/step - loss: 0.1322 - acc: 0.9522 - val_loss: 0.1598 - val_acc: 0.9423
# Epoch 17/20
#  9/10 [==========================>...] - ETA: 0s - loss: 0.1505 - acc: 0.9375Epoch 00017: val_acc did not improve
# 10/10 [==============================] - 132s 13s/step - loss: 0.1724 - acc: 0.9266 - val_loss: 0.1878 - val_acc: 0.9363
# Epoch 18/20
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0910 - acc: 0.9782Epoch 00018: val_acc improved from 0.94234 to 0.95946, saving model to model/top_model_weights.h5
# 10/10 [==============================] - 132s 13s/step - loss: 0.0882 - acc: 0.9804 - val_loss: 0.1438 - val_acc: 0.9595
# Epoch 19/20
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0768 - acc: 0.9774Epoch 00019: val_acc did not improve
# 10/10 [==============================] - 132s 13s/step - loss: 0.0910 - acc: 0.9688 - val_loss: 0.7535 - val_acc: 0.5811
# Epoch 20/20
#  9/10 [==========================>...] - ETA: 0s - loss: 0.1531 - acc: 0.9331Epoch 00020: val_acc did not improve
# 10/10 [==============================] - 132s 13s/step - loss: 0.1431 - acc: 0.9397 - val_loss: 0.1666 - val_acc: 0.9309
#
# Starting to Fine Tune Model
# /home/grupoavatar/.local/lib/python3.5/site-packages/keras/callbacks.py:375: RuntimeWarning: ModelCheckpoint mode mode is unknown, fallback to auto mode.
#   RuntimeWarning)
# /home/grupoavatar/.local/lib/python3.5/site-packages/ipykernel_launcher.py:102: UserWarning: The semantics of the Keras 2 argument `steps_per_epoch` is not the same as the Keras 1 argument `samples_per_epoch`. `steps_per_epoch` is the number of batches to draw from the generator at each epoch. Basically steps_per_epoch = samples_per_epoch/batch_size. Similarly `nb_val_samples`->`validation_steps` and `val_samples`->`steps` arguments have changed. Update your method calls accordingly.
# /home/grupoavatar/.local/lib/python3.5/site-packages/ipykernel_launcher.py:102: UserWarning: Update your `fit_generator` call to the Keras 2 API: `fit_generator(<keras.pre..., epochs=100, validation_data=<keras.pre..., steps_per_epoch=10, validation_steps=346, callbacks=[<keras.ca...)`
# Epoch 1/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0784 - acc: 0.9792Epoch 00001: val_loss improved from inf to 0.14472, saving model to model/model_weights_DDSM Images.h5
# 10/10 [==============================] - 137s 14s/step - loss: 0.0820 - acc: 0.9734 - val_loss: 0.1447 - val_acc: 0.9535
# Epoch 2/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0860 - acc: 0.9708Epoch 00002: val_loss improved from 0.14472 to 0.14427, saving model to model/model_weights_DDSM Images.h5
# 10/10 [==============================] - 134s 13s/step - loss: 0.0835 - acc: 0.9721 - val_loss: 0.1443 - val_acc: 0.9509
# Epoch 3/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0752 - acc: 0.9826Epoch 00003: val_loss improved from 0.14427 to 0.14383, saving model to model/model_weights_DDSM Images.h5
# 10/10 [==============================] - 134s 13s/step - loss: 0.0749 - acc: 0.9828 - val_loss: 0.1438 - val_acc: 0.9536
# Epoch 4/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0914 - acc: 0.9715Epoch 00004: val_loss improved from 0.14383 to 0.14279, saving model to model/model_weights_DDSM Images.h5
# 10/10 [==============================] - 134s 13s/step - loss: 0.0927 - acc: 0.9698 - val_loss: 0.1428 - val_acc: 0.9568
# Epoch 5/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0816 - acc: 0.9705Epoch 00005: val_loss improved from 0.14279 to 0.14206, saving model to model/model_weights_DDSM Images.h5
# 10/10 [==============================] - 134s 13s/step - loss: 0.0811 - acc: 0.9703 - val_loss: 0.1421 - val_acc: 0.9508
# Epoch 6/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0775 - acc: 0.9792Epoch 00006: val_loss improved from 0.14206 to 0.14061, saving model to model/model_weights_DDSM Images.h5
# 10/10 [==============================] - 134s 13s/step - loss: 0.0771 - acc: 0.9796 - val_loss: 0.1406 - val_acc: 0.9540
# Epoch 7/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0785 - acc: 0.9755Epoch 00007: val_loss improved from 0.14061 to 0.13988, saving model to model/model_weights_DDSM Images.h5
# 10/10 [==============================] - 134s 13s/step - loss: 0.0818 - acc: 0.9718 - val_loss: 0.1399 - val_acc: 0.9479
# Epoch 8/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.1026 - acc: 0.9626Epoch 00008: val_loss improved from 0.13988 to 0.13791, saving model to model/model_weights_DDSM Images.h5
# 10/10 [==============================] - 135s 14s/step - loss: 0.1029 - acc: 0.9632 - val_loss: 0.1379 - val_acc: 0.9477
# Epoch 9/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0712 - acc: 0.9822Epoch 00009: val_loss improved from 0.13791 to 0.13604, saving model to model/model_weights_DDSM Images.h5
# 10/10 [==============================] - 134s 13s/step - loss: 0.0769 - acc: 0.9800 - val_loss: 0.1360 - val_acc: 0.9481
# Epoch 10/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0867 - acc: 0.9722Epoch 00010: val_loss improved from 0.13604 to 0.13549, saving model to model/model_weights_DDSM Images.h5
# 10/10 [==============================] - 135s 14s/step - loss: 0.0855 - acc: 0.9719 - val_loss: 0.1355 - val_acc: 0.9595
# Epoch 11/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0746 - acc: 0.9735Epoch 00011: val_loss improved from 0.13549 to 0.13488, saving model to model/model_weights_DDSM Images.h5
# 10/10 [==============================] - 134s 13s/step - loss: 0.0735 - acc: 0.9746 - val_loss: 0.1349 - val_acc: 0.9566
# Epoch 12/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0702 - acc: 0.9792Epoch 00012: val_loss improved from 0.13488 to 0.13349, saving model to model/model_weights_DDSM Images.h5
# 10/10 [==============================] - 134s 13s/step - loss: 0.0700 - acc: 0.9796 - val_loss: 0.1335 - val_acc: 0.9568
# Epoch 13/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0685 - acc: 0.9809Epoch 00013: val_loss improved from 0.13349 to 0.13099, saving model to model/model_weights_DDSM Images.h5
# 10/10 [==============================] - 134s 13s/step - loss: 0.0664 - acc: 0.9812 - val_loss: 0.1310 - val_acc: 0.9538
# Epoch 14/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0729 - acc: 0.9809Epoch 00014: val_loss improved from 0.13099 to 0.12871, saving model to model/model_weights_DDSM Images.h5
# 10/10 [==============================] - 135s 13s/step - loss: 0.0734 - acc: 0.9812 - val_loss: 0.1287 - val_acc: 0.9567
# Epoch 15/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0662 - acc: 0.9782Epoch 00015: val_loss improved from 0.12871 to 0.12689, saving model to model/model_weights_DDSM Images.h5
# 10/10 [==============================] - 134s 13s/step - loss: 0.0647 - acc: 0.9804 - val_loss: 0.1269 - val_acc: 0.9594
# Epoch 16/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0620 - acc: 0.9839Epoch 00016: val_loss improved from 0.12689 to 0.12549, saving model to model/model_weights_DDSM Images.h5
# 10/10 [==============================] - 134s 13s/step - loss: 0.0632 - acc: 0.9839 - val_loss: 0.1255 - val_acc: 0.9654
# Epoch 17/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0735 - acc: 0.9740Epoch 00017: val_loss improved from 0.12549 to 0.12539, saving model to model/model_weights_DDSM Images.h5
# 10/10 [==============================] - 134s 13s/step - loss: 0.0712 - acc: 0.9766 - val_loss: 0.1254 - val_acc: 0.9650
# Epoch 18/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0656 - acc: 0.9809Epoch 00018: val_loss improved from 0.12539 to 0.12511, saving model to model/model_weights_DDSM Images.h5
# 10/10 [==============================] - 134s 13s/step - loss: 0.0636 - acc: 0.9828 - val_loss: 0.1251 - val_acc: 0.9624
# Epoch 19/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0607 - acc: 0.9787Epoch 00019: val_loss improved from 0.12511 to 0.12465, saving model to model/model_weights_DDSM Images.h5
# 10/10 [==============================] - 135s 13s/step - loss: 0.0620 - acc: 0.9761 - val_loss: 0.1247 - val_acc: 0.9653
# Epoch 20/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0476 - acc: 0.9878Epoch 00020: val_loss improved from 0.12465 to 0.12320, saving model to model/model_weights_DDSM Images.h5
# 10/10 [==============================] - 134s 13s/step - loss: 0.0511 - acc: 0.9843 - val_loss: 0.1232 - val_acc: 0.9595
# Epoch 21/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0520 - acc: 0.9896Epoch 00021: val_loss improved from 0.12320 to 0.12123, saving model to model/model_weights_DDSM Images.h5
# 10/10 [==============================] - 134s 13s/step - loss: 0.0533 - acc: 0.9886 - val_loss: 0.1212 - val_acc: 0.9625
# Epoch 22/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0706 - acc: 0.9757Epoch 00022: val_loss improved from 0.12123 to 0.12011, saving model to model/model_weights_DDSM Images.h5
# 10/10 [==============================] - 134s 13s/step - loss: 0.0697 - acc: 0.9750 - val_loss: 0.1201 - val_acc: 0.9623
# Epoch 23/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0572 - acc: 0.9839Epoch 00023: val_loss improved from 0.12011 to 0.11907, saving model to model/model_weights_DDSM Images.h5
# 10/10 [==============================] - 135s 14s/step - loss: 0.0552 - acc: 0.9855 - val_loss: 0.1191 - val_acc: 0.9623
# Epoch 24/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0657 - acc: 0.9851Epoch 00024: val_loss improved from 0.11907 to 0.11753, saving model to model/model_weights_DDSM Images.h5
# 10/10 [==============================] - 134s 13s/step - loss: 0.0663 - acc: 0.9835 - val_loss: 0.1175 - val_acc: 0.9623
# Epoch 25/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0550 - acc: 0.9856Epoch 00025: val_loss improved from 0.11753 to 0.11666, saving model to model/model_weights_DDSM Images.h5
# 10/10 [==============================] - 135s 13s/step - loss: 0.0550 - acc: 0.9855 - val_loss: 0.1167 - val_acc: 0.9626
# Epoch 26/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0583 - acc: 0.9826Epoch 00026: val_loss did not improve
# 10/10 [==============================] - 134s 13s/step - loss: 0.0656 - acc: 0.9765 - val_loss: 0.1169 - val_acc: 0.9654
# Epoch 27/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0559 - acc: 0.9856Epoch 00027: val_loss improved from 0.11666 to 0.11619, saving model to model/model_weights_DDSM Images.h5
# 10/10 [==============================] - 134s 13s/step - loss: 0.0559 - acc: 0.9871 - val_loss: 0.1162 - val_acc: 0.9626
# Epoch 28/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0499 - acc: 0.9864Epoch 00028: val_loss did not improve
# 10/10 [==============================] - 134s 13s/step - loss: 0.0491 - acc: 0.9878 - val_loss: 0.1167 - val_acc: 0.9565
# Epoch 29/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0637 - acc: 0.9826Epoch 00029: val_loss did not improve
# 10/10 [==============================] - 134s 13s/step - loss: 0.0603 - acc: 0.9844 - val_loss: 0.1172 - val_acc: 0.9508
# Epoch 30/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0486 - acc: 0.9931Epoch 00030: val_loss did not improve
# 10/10 [==============================] - 134s 13s/step - loss: 0.0465 - acc: 0.9937 - val_loss: 0.1180 - val_acc: 0.9507
# Epoch 31/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0610 - acc: 0.9809Epoch 00031: val_loss did not improve
# 10/10 [==============================] - 134s 13s/step - loss: 0.0589 - acc: 0.9812 - val_loss: 0.1167 - val_acc: 0.9508
# Epoch 32/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0552 - acc: 0.9839Epoch 00032: val_loss improved from 0.11619 to 0.11610, saving model to model/model_weights_DDSM Images.h5
# 10/10 [==============================] - 134s 13s/step - loss: 0.0564 - acc: 0.9839 - val_loss: 0.1161 - val_acc: 0.9510
# Epoch 33/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0519 - acc: 0.9891Epoch 00033: val_loss improved from 0.11610 to 0.11494, saving model to model/model_weights_DDSM Images.h5
# 10/10 [==============================] - 135s 13s/step - loss: 0.0514 - acc: 0.9871 - val_loss: 0.1149 - val_acc: 0.9480
# Epoch 34/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0449 - acc: 0.9869Epoch 00034: val_loss improved from 0.11494 to 0.11343, saving model to model/model_weights_DDSM Images.h5
# 10/10 [==============================] - 134s 13s/step - loss: 0.0430 - acc: 0.9882 - val_loss: 0.1134 - val_acc: 0.9481
# Epoch 35/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0563 - acc: 0.9844Epoch 00035: val_loss improved from 0.11343 to 0.11150, saving model to model/model_weights_DDSM Images.h5
# 10/10 [==============================] - 134s 13s/step - loss: 0.0579 - acc: 0.9839 - val_loss: 0.1115 - val_acc: 0.9453
# Epoch 36/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0506 - acc: 0.9908Epoch 00036: val_loss improved from 0.11150 to 0.10959, saving model to model/model_weights_DDSM Images.h5
# 10/10 [==============================] - 134s 13s/step - loss: 0.0505 - acc: 0.9918 - val_loss: 0.1096 - val_acc: 0.9478
# Epoch 37/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0429 - acc: 0.9913Epoch 00037: val_loss improved from 0.10959 to 0.10756, saving model to model/model_weights_DDSM Images.h5
# 10/10 [==============================] - 134s 13s/step - loss: 0.0427 - acc: 0.9906 - val_loss: 0.1076 - val_acc: 0.9506
# Epoch 38/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0388 - acc: 0.9965Epoch 00038: val_loss improved from 0.10756 to 0.10406, saving model to model/model_weights_DDSM Images.h5
# 10/10 [==============================] - 135s 13s/step - loss: 0.0380 - acc: 0.9969 - val_loss: 0.1041 - val_acc: 0.9510
# Epoch 39/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0575 - acc: 0.9774Epoch 00039: val_loss improved from 0.10406 to 0.10051, saving model to model/model_weights_DDSM Images.h5
# 10/10 [==============================] - 135s 13s/step - loss: 0.0553 - acc: 0.9796 - val_loss: 0.1005 - val_acc: 0.9594
# Epoch 40/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0455 - acc: 0.9948Epoch 00040: val_loss improved from 0.10051 to 0.09720, saving model to model/model_weights_DDSM Images.h5
# 10/10 [==============================] - 134s 13s/step - loss: 0.0441 - acc: 0.9953 - val_loss: 0.0972 - val_acc: 0.9653
# Epoch 41/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0554 - acc: 0.9834Epoch 00041: val_loss improved from 0.09720 to 0.09478, saving model to model/model_weights_DDSM Images.h5
# 10/10 [==============================] - 134s 13s/step - loss: 0.0528 - acc: 0.9851 - val_loss: 0.0948 - val_acc: 0.9626
# Epoch 42/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0415 - acc: 0.9948Epoch 00042: val_loss improved from 0.09478 to 0.09299, saving model to model/model_weights_DDSM Images.h5
# 10/10 [==============================] - 134s 13s/step - loss: 0.0433 - acc: 0.9937 - val_loss: 0.0930 - val_acc: 0.9622
# Epoch 43/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0511 - acc: 0.9856Epoch 00043: val_loss improved from 0.09299 to 0.09013, saving model to model/model_weights_DDSM Images.h5
# 10/10 [==============================] - 134s 13s/step - loss: 0.0498 - acc: 0.9855 - val_loss: 0.0901 - val_acc: 0.9623
# Epoch 44/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0421 - acc: 0.9913Epoch 00044: val_loss improved from 0.09013 to 0.08763, saving model to model/model_weights_DDSM Images.h5
# 10/10 [==============================] - 135s 13s/step - loss: 0.0403 - acc: 0.9922 - val_loss: 0.0876 - val_acc: 0.9651
# Epoch 45/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0419 - acc: 0.9896Epoch 00045: val_loss improved from 0.08763 to 0.08520, saving model to model/model_weights_DDSM Images.h5
# 10/10 [==============================] - 134s 13s/step - loss: 0.0437 - acc: 0.9891 - val_loss: 0.0852 - val_acc: 0.9625
# Epoch 46/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0377 - acc: 0.9983Epoch 00046: val_loss improved from 0.08520 to 0.08321, saving model to model/model_weights_DDSM Images.h5
# 10/10 [==============================] - 134s 13s/step - loss: 0.0369 - acc: 0.9984 - val_loss: 0.0832 - val_acc: 0.9652
# Epoch 47/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0383 - acc: 0.9913Epoch 00047: val_loss improved from 0.08321 to 0.08114, saving model to model/model_weights_DDSM Images.h5
# 10/10 [==============================] - 134s 13s/step - loss: 0.0369 - acc: 0.9922 - val_loss: 0.0811 - val_acc: 0.9684
# Epoch 48/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0380 - acc: 0.9943Epoch 00048: val_loss improved from 0.08114 to 0.07984, saving model to model/model_weights_DDSM Images.h5
# 10/10 [==============================] - 134s 13s/step - loss: 0.0394 - acc: 0.9949 - val_loss: 0.0798 - val_acc: 0.9682
# Epoch 49/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0432 - acc: 0.9908Epoch 00049: val_loss improved from 0.07984 to 0.07807, saving model to model/model_weights_DDSM Images.h5
# 10/10 [==============================] - 134s 13s/step - loss: 0.0423 - acc: 0.9902 - val_loss: 0.0781 - val_acc: 0.9681
# Epoch 50/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0313 - acc: 0.9948Epoch 00050: val_loss improved from 0.07807 to 0.07639, saving model to model/model_weights_DDSM Images.h5
# 10/10 [==============================] - 134s 13s/step - loss: 0.0357 - acc: 0.9922 - val_loss: 0.0764 - val_acc: 0.9710
# Epoch 51/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0350 - acc: 0.9983Epoch 00051: val_loss improved from 0.07639 to 0.07507, saving model to model/model_weights_DDSM Images.h5
# 10/10 [==============================] - 134s 13s/step - loss: 0.0380 - acc: 0.9969 - val_loss: 0.0751 - val_acc: 0.9711
# Epoch 52/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0381 - acc: 0.9913Epoch 00052: val_loss improved from 0.07507 to 0.07434, saving model to model/model_weights_DDSM Images.h5
# 10/10 [==============================] - 134s 13s/step - loss: 0.0375 - acc: 0.9922 - val_loss: 0.0743 - val_acc: 0.9709
# Epoch 53/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0351 - acc: 0.9948Epoch 00053: val_loss improved from 0.07434 to 0.07353, saving model to model/model_weights_DDSM Images.h5
# 10/10 [==============================] - 134s 13s/step - loss: 0.0348 - acc: 0.9953 - val_loss: 0.0735 - val_acc: 0.9711
# Epoch 54/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0514 - acc: 0.9799Epoch 00054: val_loss did not improve
# 10/10 [==============================] - 134s 13s/step - loss: 0.0520 - acc: 0.9789 - val_loss: 0.0738 - val_acc: 0.9740
# Epoch 55/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0426 - acc: 0.9878Epoch 00055: val_loss did not improve
# 10/10 [==============================] - 134s 13s/step - loss: 0.0446 - acc: 0.9875 - val_loss: 0.0745 - val_acc: 0.9739
# Epoch 56/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0384 - acc: 0.9874Epoch 00056: val_loss did not improve
# 10/10 [==============================] - 134s 13s/step - loss: 0.0387 - acc: 0.9886 - val_loss: 0.0748 - val_acc: 0.9740
# Epoch 57/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0333 - acc: 0.9943Epoch 00057: val_loss did not improve
# 10/10 [==============================] - 134s 13s/step - loss: 0.0319 - acc: 0.9949 - val_loss: 0.0749 - val_acc: 0.9739
# Epoch 58/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0363 - acc: 0.9931Epoch 00058: val_loss did not improve
# 10/10 [==============================] - 134s 13s/step - loss: 0.0387 - acc: 0.9906 - val_loss: 0.0748 - val_acc: 0.9741
# Epoch 59/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0413 - acc: 0.9913Epoch 00059: val_loss did not improve
# 10/10 [==============================] - 134s 13s/step - loss: 0.0416 - acc: 0.9922 - val_loss: 0.0751 - val_acc: 0.9739
# Epoch 60/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0374 - acc: 0.9913Epoch 00060: val_loss did not improve
# 10/10 [==============================] - 134s 13s/step - loss: 0.0359 - acc: 0.9922 - val_loss: 0.0748 - val_acc: 0.9739
# Epoch 61/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0438 - acc: 0.9913Epoch 00061: val_loss did not improve
# 10/10 [==============================] - 134s 13s/step - loss: 0.0411 - acc: 0.9922 - val_loss: 0.0745 - val_acc: 0.9741
# Epoch 62/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0445 - acc: 0.9844Epoch 00062: val_loss did not improve
# 10/10 [==============================] - 134s 13s/step - loss: 0.0428 - acc: 0.9859 - val_loss: 0.0746 - val_acc: 0.9741
# Epoch 63/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0348 - acc: 0.9913Epoch 00063: val_loss did not improve
# 10/10 [==============================] - 134s 13s/step - loss: 0.0369 - acc: 0.9906 - val_loss: 0.0746 - val_acc: 0.9743
# Epoch 64/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0387 - acc: 0.9960Epoch 00064: val_loss did not improve
# 10/10 [==============================] - 134s 13s/step - loss: 0.0375 - acc: 0.9949 - val_loss: 0.0750 - val_acc: 0.9740
# Epoch 65/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0358 - acc: 0.9913Epoch 00065: val_loss did not improve
# 10/10 [==============================] - 134s 13s/step - loss: 0.0400 - acc: 0.9906 - val_loss: 0.0746 - val_acc: 0.9740
# Epoch 66/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0312 - acc: 0.9965Epoch 00066: val_loss did not improve
# 10/10 [==============================] - 134s 13s/step - loss: 0.0321 - acc: 0.9953 - val_loss: 0.0745 - val_acc: 0.9740
# Epoch 67/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0417 - acc: 0.9913Epoch 00067: val_loss did not improve
# 10/10 [==============================] - 134s 13s/step - loss: 0.0406 - acc: 0.9922 - val_loss: 0.0745 - val_acc: 0.9740
# Epoch 68/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0339 - acc: 0.9931Epoch 00068: val_loss did not improve
# 10/10 [==============================] - 134s 13s/step - loss: 0.0332 - acc: 0.9937 - val_loss: 0.0750 - val_acc: 0.9739
# Epoch 69/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0318 - acc: 0.9948Epoch 00069: val_loss did not improve
# 10/10 [==============================] - 134s 13s/step - loss: 0.0323 - acc: 0.9937 - val_loss: 0.0744 - val_acc: 0.9741
# Epoch 70/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0337 - acc: 0.9913Epoch 00070: val_loss did not improve
# 10/10 [==============================] - 134s 13s/step - loss: 0.0318 - acc: 0.9922 - val_loss: 0.0743 - val_acc: 0.9739
# Epoch 71/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0326 - acc: 0.9948Epoch 00071: val_loss did not improve
# 10/10 [==============================] - 134s 13s/step - loss: 0.0370 - acc: 0.9938 - val_loss: 0.0742 - val_acc: 0.9740
# Epoch 72/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0331 - acc: 0.9931Epoch 00072: val_loss did not improve
# 10/10 [==============================] - 134s 13s/step - loss: 0.0318 - acc: 0.9937 - val_loss: 0.0740 - val_acc: 0.9739
# Epoch 73/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0294 - acc: 0.9965Epoch 00073: val_loss did not improve
# 10/10 [==============================] - 134s 13s/step - loss: 0.0300 - acc: 0.9953 - val_loss: 0.0740 - val_acc: 0.9740
# Epoch 74/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0270 - acc: 0.9983Epoch 00074: val_loss did not improve
# 10/10 [==============================] - 134s 13s/step - loss: 0.0282 - acc: 0.9984 - val_loss: 0.0752 - val_acc: 0.9739
# Epoch 75/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0267 - acc: 0.9965Epoch 00075: val_loss did not improve
# 10/10 [==============================] - 134s 13s/step - loss: 0.0341 - acc: 0.9922 - val_loss: 0.0753 - val_acc: 0.9739
# Epoch 76/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0316 - acc: 0.9965Epoch 00076: val_loss did not improve
# 10/10 [==============================] - 134s 13s/step - loss: 0.0313 - acc: 0.9969 - val_loss: 0.0740 - val_acc: 0.9741
# Epoch 77/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0208 - acc: 1.0000Epoch 00077: val_loss improved from 0.07353 to 0.07339, saving model to model/model_weights_DDSM Images.h5
# 10/10 [==============================] - 134s 13s/step - loss: 0.0207 - acc: 1.0000 - val_loss: 0.0734 - val_acc: 0.9741
# Epoch 78/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0312 - acc: 0.9943Epoch 00078: val_loss did not improve
# 10/10 [==============================] - 134s 13s/step - loss: 0.0307 - acc: 0.9949 - val_loss: 0.0734 - val_acc: 0.9740
# Epoch 79/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0356 - acc: 0.9896Epoch 00079: val_loss improved from 0.07339 to 0.07325, saving model to model/model_weights_DDSM Images.h5
# 10/10 [==============================] - 134s 13s/step - loss: 0.0375 - acc: 0.9875 - val_loss: 0.0732 - val_acc: 0.9741
# Epoch 80/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0280 - acc: 0.9926Epoch 00080: val_loss improved from 0.07325 to 0.07312, saving model to model/model_weights_DDSM Images.h5
# 10/10 [==============================] - 134s 13s/step - loss: 0.0274 - acc: 0.9918 - val_loss: 0.0731 - val_acc: 0.9740
# Epoch 81/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0255 - acc: 0.9960Epoch 00081: val_loss improved from 0.07312 to 0.07233, saving model to model/model_weights_DDSM Images.h5
# 10/10 [==============================] - 134s 13s/step - loss: 0.0249 - acc: 0.9965 - val_loss: 0.0723 - val_acc: 0.9740
# Epoch 82/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0301 - acc: 0.9948Epoch 00082: val_loss did not improve
# 10/10 [==============================] - 134s 13s/step - loss: 0.0336 - acc: 0.9922 - val_loss: 0.0727 - val_acc: 0.9739
# Epoch 83/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0338 - acc: 0.9896Epoch 00083: val_loss improved from 0.07233 to 0.07158, saving model to model/model_weights_DDSM Images.h5
# 10/10 [==============================] - 134s 13s/step - loss: 0.0342 - acc: 0.9906 - val_loss: 0.0716 - val_acc: 0.9740
# Epoch 84/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0277 - acc: 0.9965Epoch 00084: val_loss did not improve
# 10/10 [==============================] - 134s 13s/step - loss: 0.0289 - acc: 0.9953 - val_loss: 0.0716 - val_acc: 0.9738
# Epoch 85/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0225 - acc: 0.9960Epoch 00085: val_loss improved from 0.07158 to 0.07064, saving model to model/model_weights_DDSM Images.h5
# 10/10 [==============================] - 134s 13s/step - loss: 0.0220 - acc: 0.9965 - val_loss: 0.0706 - val_acc: 0.9739
# Epoch 86/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0373 - acc: 0.9913Epoch 00086: val_loss improved from 0.07064 to 0.07029, saving model to model/model_weights_DDSM Images.h5
# 10/10 [==============================] - 134s 13s/step - loss: 0.0359 - acc: 0.9922 - val_loss: 0.0703 - val_acc: 0.9740
# Epoch 87/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0262 - acc: 0.9948Epoch 00087: val_loss improved from 0.07029 to 0.07010, saving model to model/model_weights_DDSM Images.h5
# 10/10 [==============================] - 134s 13s/step - loss: 0.0249 - acc: 0.9953 - val_loss: 0.0701 - val_acc: 0.9740
# Epoch 88/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0269 - acc: 0.9948Epoch 00088: val_loss improved from 0.07010 to 0.06947, saving model to model/model_weights_DDSM Images.h5
# 10/10 [==============================] - 134s 13s/step - loss: 0.0258 - acc: 0.9953 - val_loss: 0.0695 - val_acc: 0.9742
# Epoch 89/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0301 - acc: 0.9891Epoch 00089: val_loss improved from 0.06947 to 0.06932, saving model to model/model_weights_DDSM Images.h5
# 10/10 [==============================] - 134s 13s/step - loss: 0.0310 - acc: 0.9886 - val_loss: 0.0693 - val_acc: 0.9739
# Epoch 90/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0354 - acc: 0.9874Epoch 00090: val_loss improved from 0.06932 to 0.06931, saving model to model/model_weights_DDSM Images.h5
# 10/10 [==============================] - 134s 13s/step - loss: 0.0351 - acc: 0.9886 - val_loss: 0.0693 - val_acc: 0.9738
# Epoch 91/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0268 - acc: 0.9948Epoch 00091: val_loss improved from 0.06931 to 0.06919, saving model to model/model_weights_DDSM Images.h5
# 10/10 [==============================] - 135s 13s/step - loss: 0.0266 - acc: 0.9953 - val_loss: 0.0692 - val_acc: 0.9739
# Epoch 92/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0279 - acc: 0.9948Epoch 00092: val_loss improved from 0.06919 to 0.06813, saving model to model/model_weights_DDSM Images.h5
# 10/10 [==============================] - 134s 13s/step - loss: 0.0278 - acc: 0.9953 - val_loss: 0.0681 - val_acc: 0.9742
# Epoch 93/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0261 - acc: 0.9948Epoch 00093: val_loss did not improve
# 10/10 [==============================] - 133s 13s/step - loss: 0.0261 - acc: 0.9953 - val_loss: 0.0693 - val_acc: 0.9738
# Epoch 94/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0329 - acc: 0.9908Epoch 00094: val_loss did not improve
# 10/10 [==============================] - 133s 13s/step - loss: 0.0321 - acc: 0.9918 - val_loss: 0.0684 - val_acc: 0.9741
# Epoch 95/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0302 - acc: 0.9896Epoch 00095: val_loss did not improve
# 10/10 [==============================] - 134s 13s/step - loss: 0.0287 - acc: 0.9906 - val_loss: 0.0683 - val_acc: 0.9741
# Epoch 96/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0228 - acc: 0.9983Epoch 00096: val_loss improved from 0.06813 to 0.06768, saving model to model/model_weights_DDSM Images.h5
# 10/10 [==============================] - 134s 13s/step - loss: 0.0282 - acc: 0.9969 - val_loss: 0.0677 - val_acc: 0.9741
# Epoch 97/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0291 - acc: 0.9926Epoch 00097: val_loss improved from 0.06768 to 0.06661, saving model to model/model_weights_DDSM Images.h5
# 10/10 [==============================] - 134s 13s/step - loss: 0.0274 - acc: 0.9933 - val_loss: 0.0666 - val_acc: 0.9740
# Epoch 98/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0209 - acc: 1.0000Epoch 00098: val_loss improved from 0.06661 to 0.06610, saving model to model/model_weights_DDSM Images.h5
# 10/10 [==============================] - 135s 13s/step - loss: 0.0243 - acc: 0.9969 - val_loss: 0.0661 - val_acc: 0.9739
# Epoch 99/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0285 - acc: 0.9965Epoch 00099: val_loss improved from 0.06610 to 0.06510, saving model to model/model_weights_DDSM Images.h5
# 10/10 [==============================] - 134s 13s/step - loss: 0.0286 - acc: 0.9969 - val_loss: 0.0651 - val_acc: 0.9742
# Epoch 100/100
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0331 - acc: 0.9908Epoch 00100: val_loss did not improve
# 10/10 [==============================] - 134s 13s/step - loss: 0.0315 - acc: 0.9918 - val_loss: 0.0653 - val_acc: 0.9739

# %%
# let's visualize layer names and layer indices to see how many layers
# we should freeze: this is used to define based_model_last_block_layer_number
for i, layer in enumerate(model_layers):  # comment these two lines once the correct based_model_last_block_layer
    print(i, layer.name)  # has been selected
# Out:
# 0 input_1
# 1 conv2d_1
# 2 batch_normalization_1
# 3 activation_1
# 4 conv2d_2
# 5 batch_normalization_2
# 6 activation_2
# 7 conv2d_3
# 8 batch_normalization_3
# 9 activation_3
# 10 max_pooling2d_1
# 11 conv2d_4
# 12 batch_normalization_4
# 13 activation_4
# 14 conv2d_5
# 15 batch_normalization_5
# 16 activation_5
# 17 max_pooling2d_2
# 18 conv2d_9
# 19 batch_normalization_9
# 20 activation_9
# 21 conv2d_7
# 22 conv2d_10
# 23 batch_normalization_7
# 24 batch_normalization_10
# 25 activation_7
# 26 activation_10
# 27 average_pooling2d_1
# 28 conv2d_6
# 29 conv2d_8
# 30 conv2d_11
# 31 conv2d_12
# 32 batch_normalization_6
# 33 batch_normalization_8
# 34 batch_normalization_11
# 35 batch_normalization_12
# 36 activation_6
# 37 activation_8
# 38 activation_11
# 39 activation_12
# 40 mixed0
# 41 conv2d_16
# 42 batch_normalization_16
# 43 activation_16
# 44 conv2d_14
# 45 conv2d_17
# 46 batch_normalization_14
# 47 batch_normalization_17
# 48 activation_14
# 49 activation_17
# 50 average_pooling2d_2
# 51 conv2d_13
# 52 conv2d_15
# 53 conv2d_18
# 54 conv2d_19
# 55 batch_normalization_13
# 56 batch_normalization_15
# 57 batch_normalization_18
# 58 batch_normalization_19
# 59 activation_13
# 60 activation_15
# 61 activation_18
# 62 activation_19
# 63 mixed1
# 64 conv2d_23
# 65 batch_normalization_23
# 66 activation_23
# 67 conv2d_21
# 68 conv2d_24
# 69 batch_normalization_21
# 70 batch_normalization_24
# 71 activation_21
# 72 activation_24
# 73 average_pooling2d_3
# 74 conv2d_20
# 75 conv2d_22
# 76 conv2d_25
# 77 conv2d_26
# 78 batch_normalization_20
# 79 batch_normalization_22
# 80 batch_normalization_25
# 81 batch_normalization_26
# 82 activation_20
# 83 activation_22
# 84 activation_25
# 85 activation_26
# 86 mixed2
# 87 conv2d_28
# 88 batch_normalization_28
# 89 activation_28
# 90 conv2d_29
# 91 batch_normalization_29
# 92 activation_29
# 93 conv2d_27
# 94 conv2d_30
# 95 batch_normalization_27
# 96 batch_normalization_30
# 97 activation_27
# 98 activation_30
# 99 max_pooling2d_3
# 100 mixed3
# 101 conv2d_35
# 102 batch_normalization_35
# 103 activation_35
# 104 conv2d_36
# 105 batch_normalization_36
# 106 activation_36
# 107 conv2d_32
# 108 conv2d_37
# 109 batch_normalization_32
# 110 batch_normalization_37
# 111 activation_32
# 112 activation_37
# 113 conv2d_33
# 114 conv2d_38
# 115 batch_normalization_33
# 116 batch_normalization_38
# 117 activation_33
# 118 activation_38
# 119 average_pooling2d_4
# 120 conv2d_31
# 121 conv2d_34
# 122 conv2d_39
# 123 conv2d_40
# 124 batch_normalization_31
# 125 batch_normalization_34
# 126 batch_normalization_39
# 127 batch_normalization_40
# 128 activation_31
# 129 activation_34
# 130 activation_39
# 131 activation_40
# 132 mixed4
# 133 conv2d_45
# 134 batch_normalization_45
# 135 activation_45
# 136 conv2d_46
# 137 batch_normalization_46
# 138 activation_46
# 139 conv2d_42
# 140 conv2d_47
# 141 batch_normalization_42
# 142 batch_normalization_47
# 143 activation_42
# 144 activation_47
# 145 conv2d_43
# 146 conv2d_48
# 147 batch_normalization_43
# 148 batch_normalization_48
# 149 activation_43
# 150 activation_48
# 151 average_pooling2d_5
# 152 conv2d_41
# 153 conv2d_44
# 154 conv2d_49
# 155 conv2d_50
# 156 batch_normalization_41
# 157 batch_normalization_44
# 158 batch_normalization_49
# 159 batch_normalization_50
# 160 activation_41
# 161 activation_44
# 162 activation_49
# 163 activation_50
# 164 mixed5
# 165 conv2d_55
# 166 batch_normalization_55
# 167 activation_55
# 168 conv2d_56
# 169 batch_normalization_56
# 170 activation_56
# 171 conv2d_52
# 172 conv2d_57
# 173 batch_normalization_52
# 174 batch_normalization_57
# 175 activation_52
# 176 activation_57
# 177 conv2d_53
# 178 conv2d_58
# 179 batch_normalization_53
# 180 batch_normalization_58
# 181 activation_53
# 182 activation_58
# 183 average_pooling2d_6
# 184 conv2d_51
# 185 conv2d_54
# 186 conv2d_59
# 187 conv2d_60
# 188 batch_normalization_51
# 189 batch_normalization_54
# 190 batch_normalization_59
# 191 batch_normalization_60
# 192 activation_51
# 193 activation_54
# 194 activation_59
# 195 activation_60
# 196 mixed6
# 197 conv2d_65
# 198 batch_normalization_65
# 199 activation_65
# 200 conv2d_66
# 201 batch_normalization_66
# 202 activation_66
# 203 conv2d_62
# 204 conv2d_67
# 205 batch_normalization_62
# 206 batch_normalization_67
# 207 activation_62
# 208 activation_67
# 209 conv2d_63
# 210 conv2d_68
# 211 batch_normalization_63
# 212 batch_normalization_68
# 213 activation_63
# 214 activation_68
# 215 average_pooling2d_7
# 216 conv2d_61
# 217 conv2d_64
# 218 conv2d_69
# 219 conv2d_70
# 220 batch_normalization_61
# 221 batch_normalization_64
# 222 batch_normalization_69
# 223 batch_normalization_70
# 224 activation_61
# 225 activation_64
# 226 activation_69
# 227 activation_70
# 228 mixed7
# 229 conv2d_73
# 230 batch_normalization_73
# 231 activation_73
# 232 conv2d_74
# 233 batch_normalization_74
# 234 activation_74
# 235 conv2d_71
# 236 conv2d_75
# 237 batch_normalization_71
# 238 batch_normalization_75
# 239 activation_71
# 240 activation_75
# 241 conv2d_72
# 242 conv2d_76
# 243 batch_normalization_72
# 244 batch_normalization_76
# 245 activation_72
# 246 activation_76
# 247 max_pooling2d_4
# 248 mixed8
# 249 conv2d_81
# 250 batch_normalization_81
# 251 activation_81
# 252 conv2d_78
# 253 conv2d_82
# 254 batch_normalization_78
# 255 batch_normalization_82
# 256 activation_78
# 257 activation_82
# 258 conv2d_79
# 259 conv2d_80
# 260 conv2d_83
# 261 conv2d_84
# 262 average_pooling2d_8
# 263 conv2d_77
# 264 batch_normalization_79
# 265 batch_normalization_80
# 266 batch_normalization_83
# 267 batch_normalization_84
# 268 conv2d_85
# 269 batch_normalization_77
# 270 activation_79
# 271 activation_80
# 272 activation_83
# 273 activation_84
# 274 batch_normalization_85
# 275 activation_77
# 276 mixed9_0
# 277 concatenate_1
# 278 activation_85
# 279 mixed9
# 280 conv2d_90
# 281 batch_normalization_90
# 282 activation_90
# 283 conv2d_87
# 284 conv2d_91
# 285 batch_normalization_87
# 286 batch_normalization_91
# 287 activation_87
# 288 activation_91
# 289 conv2d_88
# 290 conv2d_89
# 291 conv2d_92
# 292 conv2d_93
# 293 average_pooling2d_9
# 294 conv2d_86
# 295 batch_normalization_88
# 296 batch_normalization_89
# 297 batch_normalization_92
# 298 batch_normalization_93
# 299 conv2d_94
# 300 batch_normalization_86
# 301 activation_88
# 302 activation_89
# 303 activation_92
# 304 activation_93
# 305 batch_normalization_94
# 306 activation_86
# 307 mixed9_1
# 308 concatenate_2
# 309 activation_94
# 310 mixed10
# 311 global_average_pooling2d_1
# 312 dense_1
# 313 dropout_1
# 314 dense_2

# %%
def plot_training2(history):
    #% matplotlib inline

    df = pd.DataFrame(history.history)
    # display(df)

    plot = df.plot(y=['loss', 'val_loss'], figsize=(8, 4), title='Training and validation loss', legend=True)
    plot.set_xlabel('Epochs')
    plot.set_ylabel('Loss binary_crossentropy')    
    fig = plot.get_figure()
    fig.savefig('loss_graph_t_cancer_t:'+str(nb_train_samples)+'smp_v:'+str(nb_validation_samples)+'smp_'+str(nb_epoch)+'epc.png')

    plot = df.plot(y=['acc', 'val_acc'], figsize=(8, 4), title='Training and validation accuracy', legend=True)
    plot.set_xlabel('Epochs')
    plot.set_ylabel('Accuracy')
    fig = plot.get_figure()
    fig.savefig('acc_graph_t_cancer_t:'+str(nb_train_samples)+'smp_v:'+str(nb_validation_samples)+'smp_'+str(nb_epoch)+'epc.png')
    
    plt.show()

#Transfer Learning    
plot_training2(hist_tl)
# Out:
# /home/grupoavatar/.local/lib/python3.5/site-packages/pandas/plotting/_core.py:1714: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   series.name = label
# /home/grupoavatar/.local/lib/python3.5/site-packages/pandas/plotting/_core.py:1714: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   series.name = label

# %%
#Finetune
plot_training2(hist_ft)
# Out:
# /home/grupoavatar/.local/lib/python3.5/site-packages/pandas/plotting/_core.py:1714: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   series.name = label

# %%
# release memory
k.clear_session()
